# %% [markdown]
# **Autores:**
# - David Moreno Vituri
# - Ricardo Sánchez Olivares
# - Íñigo Alegre Jiménez
#
# # Objetivos: MODELO DE PROPENSIÓN A COMPRA
#
# ---
# ## Propuesta de valor
# El objetivo de este ejercicio es estimar la probabilidad de que una cliente compre cierto producto o no, es decir, realizar un modelo de propensión a compra
#
# ## Motivaciones para resolverlo
# La creación de un modelo predictivo podría ayudar a la empresa en:
#
# - **Optimización de campañas de marketing**: Permite identificar a los clientes más propensos a comprar, optimizando el gasto en marketing al dirigir las campañas hacia aquellos con mayores probabilidades de conversión. Esto reduce los costos y aumenta la efectividad.
#
# - **Segmentación de clientes**: Ayuda a clasificar a los clientes según su probabilidad de compra, permitiendo una personalización más efectiva de las ofertas, promociones y recomendaciones.
#
# - **Retención de clientes**: El modelo puede identificar a aquellos clientes con menor propensión a comprar, lo que facilita la implementación de estrategias de retención o de recompra para evitar la pérdida de estos clientes.
#
# - **Previsión de ingresos**: Al predecir qué clientes realizarán compras, las empresas pueden estimar los ingresos futuros y ajustar sus estrategias comerciales y operativas.
#
# - **Asignación de recursos**: Ayuda a la toma de decisiones respecto a la asignación de recursos, priorizando la atención a los clientes con mayor probabilidad de compra.
#
# ---
# ## Orígenes de datos
# Los datos usados en este ejercicio se obtienen tras realizar un procesado de las tablas proporcionadas por Frank, el director de IT. El procesamiento se puede seguir en el jupyter notebook llamado CAPSTONE. Cada fila del dataset corresponde a un cliente único, identificada por el campo **cid**. El *target* es la variable **Compra_producto**, que indica si el cliente ha comprado o no el producto X.
#
# ---
#
# ## Tarea de ML
# El problema de estimar la probabilidad de que cliente compre o no cierto producto corresponde a una tarea de clasificación binaria supervisada.
#
# - Supervisada: Porque tenemos un conjunto de datos etiquetados donde sabemos si cliente ha comprado cierto producto o no, y utilizamos esta información para entrenar el modelo.
#
# - Clasificación binaria: Porque el resultado deseado es una categoría (compra o no compra) en lugar de un valor continuo o numerosas categorías.
#
# ## Algoritmos posibles
#
# Para la resolución de esta tarea de clasificación supervisada vamos a implementar cuatro modelos de clasificación: LightGBM, XGBoost, CatBoost y LogisticRegression.
#
# Compararemos los resultados obtenidos por los cuatro y nos quedaremos con aquel que sea más eficiente en la tarea que nos incumbe (ser capaces de identificar aquellos potenciales compradores del producto).
#
# ---

# %% [markdown]
# <a id='index'></a>
# ## Índice
#
# [Importación de librerías](#importacion_librerias)<br>
#
#
# ## Data Understanding
# [EDA](#eda)<br>
# [Análisis Univariante](#analisis_univariante)<br>
# [Análisis Multivariante](#analisis_multivariante)<br>
#
#
# ## Data Preparation
# [Creación de dataframe a predecir](#dataframe_predecir)<br>
# [Transformación de atributos](#transformacion)<br>
#
# ## Modelling
# [Partición y muestreo del dataset](#particionymuestreo)<br>
# [XGBoost](#XGB)<br>
# [LightGBM](#LightGBM)<br>
# [CatBoost](#CatBoost)<br>
# [Logistic Regression](#logistic)<br>

# %% [markdown]
# <a id='importacion_librerias'></a>
# # Importación de librerías
# [Volver al índice](#index)
#
# En este apartado hacemos la importación de las principales librerías y métodos que usaremos a lo largo del dataset.

# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100


# librerías para crear gráficas
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# módulos de sklearn 
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn import metrics

# pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# otros modelos
import xgboost as xgb
import lightgbm as lgb
import catboost as cat

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# <a id='eda'></a>
# ## Data Understanding - EDA
# [Volver al índice](#index)
#
# En este apartado importamos los datasets necesarios para construir el dataset que finalmente usaremos para entrenar nuestro modelo. Una vez creado, observamos el tamaño del mismo, el tipo de variables disponibles (numéricos, categóricos), los estadísticos descriptivos más relevantes de cada variable(valores medios, dispersión, percentiles, etc.) y el número de valores nulos.

# %%
# importación de los datasets
producto = 'debit_card'

df = pd.read_pickle(producto+'.pkl')
info_clientes = pd.read_pickle('info_clientes.pkl')

df.head()
# Out:
#        cid pk_partition country_id  region_code gender  age deceased  \
# 0  1517558   2019-01-01         ES           23      V   41        N
# 1  1161959   2019-01-01         ES           12      H   26        N
# 2  1100492   2019-01-01         ES           28      H   23        N
# 3  1391462   2019-01-01         ES           24      V   48        N
# 4  1391434   2019-01-01         ES            8      V   56        N
#
#      salary entry_date entry_channel  active_customer             segment  \
# 0       NaN 2018-12-01           KHN              1.0   02 - PARTICULARES
# 1  39287.91 2016-08-01           KAT              0.0  03 - UNIVERSITARIO
# 2  35177.97 2015-11-01           KHE              0.0  03 - UNIVERSITARIO
# 3  69824.28 2018-04-01           KHN              0.0            01 - TOP
# 4       NaN 2018-04-01           KHK              1.0   02 - PARTICULARES
#
#    entry_date_year  entry_date_month  pk_partition_year  pk_partition_month  \
# 0             2018                12               2019                   1
# 1             2016                 8               2019                   1
# 2             2015                11               2019                   1
# 3             2018                 4               2019                   1
# 4             2018                 4               2019                   1
#
#         tipo_cliente  Compra_debit_card
# 0  Cliente_existente                  1
# 1  Cliente_existente                  0
# 2  Cliente_existente                  0
# 3  Cliente_existente                  1
# 4  Cliente_existente                  1

# %%
# realizamos una copia para así en un futuro poder hacer merge que sean útiles
df_fechas = df.copy()
info_clientes_2 = info_clientes.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22653 entries, 0 to 22652
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cid                 22653 non-null  int64
#  1   pk_partition        22653 non-null  datetime64[ns]
#  2   country_id          22653 non-null  object
#  3   region_code         22653 non-null  int32
#  4   gender              22653 non-null  object
#  5   age                 22653 non-null  int64
#  6   deceased            22653 non-null  object
#  7   salary              11650 non-null  float64
#  8   entry_date          22653 non-null  datetime64[ns]
#  9   entry_channel       22653 non-null  object
#  10  active_customer     22653 non-null  float64
#  11  segment             22653 non-null  object
#  12  entry_date_year     22653 non-null  int32
#  13  entry_date_month    22653 non-null  int32
#  14  pk_partition_year   22653 non-null  int32
#  15  pk_partition_month  22653 non-null  int32
#  16  tipo_cliente        22653 non-null  object
#  17  Compra_debit_card   22653 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int32(5), int64(3), object(6)
# memory usage: 2.7+ MB

# %%
info_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177407 entries, 0 to 2177406
# Data columns (total 64 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   pk_cid                                 int64
#  1   pk_partition                           datetime64[ns]
#  2   country_id                             object
#  3   region_code                            int32
#  4   gender                                 object
#  5   age                                    int64
#  6   deceased                               object
#  7   salary                                 float64
#  8   age_group                              object
#  9   salary_bracket                         category
#  10  em_acount_consecutive_months           int64
#  11  debit_card_consecutive_months          int64
#  12  pension_plan_consecutive_months        int64
#  13  payroll_consecutive_months             int64
#  14  payroll_account_consecutive_months     int64
#  15  emc_account_consecutive_months         int64
#  16  credit_card_consecutive_months         int64
#  17  short_term_deposit_consecutive_months  int64
#  18  long_term_deposit_consecutive_months   int64
#  19  securities_consecutive_months          int64
#  20  funds_consecutive_months               int64
#  21  loans_consecutive_months               int64
#  22  mortgage_consecutive_months            int64
#  23  short_term_deposit                     int64
#  24  loans                                  int64
#  25  mortgage                               int64
#  26  funds                                  int64
#  27  securities                             int64
#  28  long_term_deposit                      int64
#  29  em_account_pp                          int64
#  30  credit_card                            int64
#  31  payroll                                int32
#  32  pension_plan                           int32
#  33  payroll_account                        int64
#  34  emc_account                            int64
#  35  debit_card                             int64
#  36  em_account_p                           int64
#  37  em_acount                              int64
#  38  total_products                         int64
#  39  total_products_no_account              int64
#  40  spent_on_account                       float64
#  41  spent_on_payment_card                  float64
#  42  spent_on_pension_plan                  float64
#  43  spent_on_investment                    float64
#  44  spent_on_loan                          float64
#  45  has_account                            int64
#  46  has_payment_card                       int64
#  47  has_pension_plan                       int32
#  48  has_investment                         int64
#  49  has_loan                               int64
#  50  has_credit_card_debt                   int64
#  51  num_accounts                           int64
#  52  num_debt_products                      int64
#  53  entry_date                             datetime64[ns]
#  54  entry_channel                          object
#  55  active_customer                        float64
#  56  segment                                object
#  57  meses_antigüedad                       int64
#  58  total_spend                            float64
#  59  ultima_compra                          datetime64[ns]
#  60  days_since_last_purchase               int64
#  61  months_since_last_purchase             int64
#  62  product_posesion                       bool
#  63  max_products                           int64
# dtypes: bool(1), category(1), datetime64[ns](3), float64(8), int32(4), int64(41), object(6)
# memory usage: 1000.9+ MB

# %% [markdown]
# Para analizar mejor aquellas columnas de info_clientes que queremos incorporar a nuestro dataset vamos a comenzar eliminando del mismo aquellas columnas que ya tenemos en df.

# %%
# debido a que no se encuentran en la intersección
lista_productos = ['em_acount', 'debit_card', 'pension_plan', 'payroll',
       'payroll_account', 'emc_account', 'credit_card',
       'short_term_deposit', 'long_term_deposit', 'securities', 'funds',
       'loans', 'mortgage']

# %%
columns_to_drop = df.columns.intersection(info_clientes.columns).difference(['pk_partition'])
info_clientes= info_clientes.drop(columns=columns_to_drop)
info_clientes= info_clientes.drop(columns=lista_productos)

# en este último drop incluir aquellas columnas que puedan provocar dataleakage 
# ojo con las columnas (ver si en su construcción se ha usado el target)
#   has_account -> ['payroll', 'payroll_account', 'em_acount','emc_account','em_account_p', 'em_account_pp']
#   has_payment_card -> ['credit_card', 'debit_card']
#   has_pension_plan -> ['pension_plan']
#   has_investment -> ['short_term_deposit', 'long_term_deposit', 'securities', 'funds']
#   has_loan -> ['loans', 'mortgage']
#   has_credit_card_debt -> ['credit_card', 'loans', 'mortgage']
#   num_accounts -> ['em_account_p', 'em_account_pp', 'em_acount', 'emc_account', 'payroll_account','payroll']
#   num_debt_products -> ['credit_card', 'loans', 'mortgage']

info_clientes= info_clientes.drop(columns=[producto+'_consecutive_months','total_products','has_payment_card','total_spend'])

# %%
columns_to_drop
# Out:
# Index(['active_customer', 'age', 'country_id', 'deceased', 'entry_channel',
#        'entry_date', 'gender', 'region_code', 'salary', 'segment'],
#       dtype='object')

# %%
info_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177407 entries, 0 to 2177406
# Data columns (total 37 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   pk_cid                                 int64
#  1   pk_partition                           datetime64[ns]
#  2   age_group                              object
#  3   salary_bracket                         category
#  4   em_acount_consecutive_months           int64
#  5   pension_plan_consecutive_months        int64
#  6   payroll_consecutive_months             int64
#  7   payroll_account_consecutive_months     int64
#  8   emc_account_consecutive_months         int64
#  9   credit_card_consecutive_months         int64
#  10  short_term_deposit_consecutive_months  int64
#  11  long_term_deposit_consecutive_months   int64
#  12  securities_consecutive_months          int64
#  13  funds_consecutive_months               int64
#  14  loans_consecutive_months               int64
#  15  mortgage_consecutive_months            int64
#  16  em_account_pp                          int64
#  17  em_account_p                           int64
#  18  total_products_no_account              int64
#  19  spent_on_account                       float64
#  20  spent_on_payment_card                  float64
#  21  spent_on_pension_plan                  float64
#  22  spent_on_investment                    float64
#  23  spent_on_loan                          float64
#  24  has_account                            int64
#  25  has_pension_plan                       int32
#  26  has_investment                         int64
#  27  has_loan                               int64
#  28  has_credit_card_debt                   int64
#  29  num_accounts                           int64
#  30  num_debt_products                      int64
#  31  meses_antigüedad                       int64
#  32  ultima_compra                          datetime64[ns]
#  33  days_since_last_purchase               int64
#  34  months_since_last_purchase             int64
#  35  product_posesion                       bool
#  36  max_products                           int64
# dtypes: bool(1), category(1), datetime64[ns](2), float64(5), int32(1), int64(26), object(1)
# memory usage: 577.3+ MB

# %% [markdown]
# Una vez que tenemos listo el sub-dataframe creado a partir de info_clientes nos disponemos a unir ambos dataframes.

# %%
df = pd.merge(df,info_clientes,how='left',left_on=['cid','pk_partition'],right_on=['pk_cid','pk_partition'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22653 entries, 0 to 22652
# Data columns (total 54 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   cid                                    22653 non-null  int64
#  1   pk_partition                           22653 non-null  datetime64[ns]
#  2   country_id                             22653 non-null  object
#  3   region_code                            22653 non-null  int32
#  4   gender                                 22653 non-null  object
#  5   age                                    22653 non-null  int64
#  6   deceased                               22653 non-null  object
#  7   salary                                 11650 non-null  float64
#  8   entry_date                             22653 non-null  datetime64[ns]
#  9   entry_channel                          22653 non-null  object
#  10  active_customer                        22653 non-null  float64
#  11  segment                                22653 non-null  object
#  12  entry_date_year                        22653 non-null  int32
#  13  entry_date_month                       22653 non-null  int32
#  14  pk_partition_year                      22653 non-null  int32
#  15  pk_partition_month                     22653 non-null  int32
#  16  tipo_cliente                           22653 non-null  object
#  17  Compra_debit_card                      22653 non-null  int64
#  18  pk_cid                                 22653 non-null  int64
#  19  age_group                              22653 non-null  object
#  20  salary_bracket                         11650 non-null  category
#  21  em_acount_consecutive_months           22653 non-null  int64
#  22  pension_plan_consecutive_months        22653 non-null  int64
#  23  payroll_consecutive_months             22653 non-null  int64
#  24  payroll_account_consecutive_months     22653 non-null  int64
#  25  emc_account_consecutive_months         22653 non-null  int64
#  26  credit_card_consecutive_months         22653 non-null  int64
#  27  short_term_deposit_consecutive_months  22653 non-null  int64
#  28  long_term_deposit_consecutive_months   22653 non-null  int64
#  29  securities_consecutive_months          22653 non-null  int64
#  30  funds_consecutive_months               22653 non-null  int64
#  31  loans_consecutive_months               22653 non-null  int64
#  32  mortgage_consecutive_months            22653 non-null  int64
#  33  em_account_pp                          22653 non-null  int64
#  34  em_account_p                           22653 non-null  int64
#  35  total_products_no_account              22653 non-null  int64
#  36  spent_on_account                       22653 non-null  float64
#  37  spent_on_payment_card                  22653 non-null  float64
#  38  spent_on_pension_plan                  22653 non-null  float64
#  39  spent_on_investment                    22653 non-null  float64
#  40  spent_on_loan                          22653 non-null  float64
#  41  has_account                            22653 non-null  int64
#  42  has_pension_plan                       22653 non-null  int32
#  43  has_investment                         22653 non-null  int64
#  44  has_loan                               22653 non-null  int64
#  45  has_credit_card_debt                   22653 non-null  int64
#  46  num_accounts                           22653 non-null  int64
#  47  num_debt_products                      22653 non-null  int64
#  48  meses_antigüedad                       22653 non-null  int64
#  49  ultima_compra                          22653 non-null  datetime64[ns]
#  50  days_since_last_purchase               22653 non-null  int64
#  51  months_since_last_purchase             22653 non-null  int64
#  52  product_posesion                       22653 non-null  bool
#  53  max_products                           22653 non-null  int64
# dtypes: bool(1), category(1), datetime64[ns](3), float64(7), int32(6), int64(29), object(7)
# memory usage: 8.5+ MB

# %% [markdown]
# Pasamos finalmente a eliminar todas las columnas cuya información ya no es relevante o ya está incluida en otras columnas.

# %%
# comenzamos eliminando columnas repetidas tras el merge (pk_cid) y columnas cuya información está incluida en otras columnas del modelo como son
# age,salary,pk_partition,'entry_date'
df = df.drop(columns=['pk_cid','age_group','salary_bracket','pk_partition','entry_date','ultima_compra','total_products_no_account',
'months_since_last_purchase','product_posesion','max_products'])
df = df.drop(columns = ['spent_on_account','spent_on_payment_card','spent_on_pension_plan','spent_on_investment','spent_on_loan'])
# eliminamos aquellas columnas CONSTANTES (únicamente poseen un valor/categoría, por lo que no aportan nada al modelo)
columns_to_drop = df.columns[df.nunique() == 1]
print(f'Las columnas constantes que eliminamos del dataframe son: {columns_to_drop}','\n')

# Elimina esas columnas del DataFrame
df = df.drop(columns=columns_to_drop)
# establecemos el id único de cada cliente como índice
df.set_index('cid', inplace=True)
df.info()
# Out:
# Las columnas constantes que eliminamos del dataframe son: Index(['pk_partition_year', 'em_account_pp', 'em_account_p'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 22653 entries, 1517558 to 1546388
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   country_id                             22653 non-null  object
#  1   region_code                            22653 non-null  int32
#  2   gender                                 22653 non-null  object
#  3   age                                    22653 non-null  int64
#  4   deceased                               22653 non-null  object
#  5   salary                                 11650 non-null  float64
#  6   entry_channel                          22653 non-null  object
#  7   active_customer                        22653 non-null  float64
#  8   segment                                22653 non-null  object
#  9   entry_date_year                        22653 non-null  int32
#  10  entry_date_month                       22653 non-null  int32
#  11  pk_partition_month                     22653 non-null  int32
#  12  tipo_cliente                           22653 non-null  object
#  13  Compra_debit_card                      22653 non-null  int64
#  14  em_acount_consecutive_months           22653 non-null  int64
#  15  pension_plan_consecutive_months        22653 non-null  int64
#  16  payroll_consecutive_months             22653 non-null  int64
#  17  payroll_account_consecutive_months     22653 non-null  int64
#  18  emc_account_consecutive_months         22653 non-null  int64
#  19  credit_card_consecutive_months         22653 non-null  int64
#  20  short_term_deposit_consecutive_months  22653 non-null  int64
#  21  long_term_deposit_consecutive_months   22653 non-null  int64
#  22  securities_consecutive_months          22653 non-null  int64
#  23  funds_consecutive_months               22653 non-null  int64
#  24  loans_consecutive_months               22653 non-null  int64
#  25  mortgage_consecutive_months            22653 non-null  int64
#  26  has_account                            22653 non-null  int64
#  27  has_pension_plan                       22653 non-null  int32
#  28  has_investment                         22653 non-null  int64
#  29  has_loan                               22653 non-null  int64
#  30  has_credit_card_debt                   22653 non-null  int64
#  31  num_accounts                           22653 non-null  int64
#  32  num_debt_products                      22653 non-null  int64
#  33  meses_antigüedad                       22653 non-null  int64
#  34  days_since_last_purchase               22653 non-null  int64
# dtypes: float64(2), int32(5), int64(22), object(6)
# memory usage: 5.8+ MB

# %% [markdown]
# Observamos que debemos de cambiar de *Dtype* algunas variables:
# - **region_code** debemos de pasarlo a tipo object
# - **active_customer** debemos de pasarlo a tipo int

# %%
df['region_code'] = df['region_code'].astype('object')
df['active_customer'] = df['active_customer'].astype('int')

# %%
df.describe(include=np.number).T
# Out:
#                                          count           mean            std  \
# age                                    22653.0      33.033991      12.592413
# salary                                 11650.0  118622.839396  264028.710775
# active_customer                        22653.0       0.642740       0.479203
# entry_date_year                        22653.0    2017.282126       1.300442
# entry_date_month                       22653.0       7.343575       3.560326
# pk_partition_month                     22653.0       2.998941       1.396939
# Compra_debit_card                      22653.0       0.506114       0.499974
# em_acount_consecutive_months           22653.0       6.487662       6.317654
# pension_plan_consecutive_months        22653.0       0.287158       1.385118
# payroll_consecutive_months             22653.0       0.281022       1.376646
# payroll_account_consecutive_months     22653.0       0.613385       2.334700
# emc_account_consecutive_months         22653.0       0.539090       2.568578
# credit_card_consecutive_months         22653.0       0.054915       0.749527
# short_term_deposit_consecutive_months  22653.0       0.000353       0.053153
# long_term_deposit_consecutive_months   22653.0       0.139672       1.280949
# securities_consecutive_months          22653.0       0.028826       0.571413
# funds_consecutive_months               22653.0       0.029797       0.623743
# loans_consecutive_months               22653.0       0.000044       0.006644
# mortgage_consecutive_months            22653.0       0.000132       0.014856
# has_account                            22653.0       0.841169       0.365527
# has_pension_plan                       22653.0       0.083962       0.277338
# has_investment                         22653.0       0.020704       0.142394
# has_loan                               22653.0       0.000132       0.011507
# has_credit_card_debt                   22653.0       0.011213       0.105297
# num_accounts                           22653.0       0.977707       0.564557
# num_debt_products                      22653.0       0.011213       0.105297
# meses_antigüedad                       22653.0      16.269854      14.483170
# days_since_last_purchase               22653.0     244.938507     182.585816
#
#                                            min        25%      50%  \
# age                                       2.00     23.000     30.0
# salary                                 5163.75  62277.675  89399.4
# active_customer                           0.00      0.000      1.0
# entry_date_year                        2015.00   2016.000   2018.0
# entry_date_month                          1.00      4.000      8.0
# pk_partition_month                        1.00      2.000      3.0
# Compra_debit_card                         0.00      0.000      1.0
# em_acount_consecutive_months              0.00      0.000      4.0
# pension_plan_consecutive_months           0.00      0.000      0.0
# payroll_consecutive_months                0.00      0.000      0.0
# payroll_account_consecutive_months        0.00      0.000      0.0
# emc_account_consecutive_months            0.00      0.000      0.0
# credit_card_consecutive_months            0.00      0.000      0.0
# short_term_deposit_consecutive_months     0.00      0.000      0.0
# long_term_deposit_consecutive_months      0.00      0.000      0.0
# securities_consecutive_months             0.00      0.000      0.0
# funds_consecutive_months                  0.00      0.000      0.0
# loans_consecutive_months                  0.00      0.000      0.0
# mortgage_consecutive_months               0.00      0.000      0.0
# has_account                               0.00      1.000      1.0
# has_pension_plan                          0.00      0.000      0.0
# has_investment                            0.00      0.000      0.0
# has_loan                                  0.00      0.000      0.0
# has_credit_card_debt                      0.00      0.000      0.0
# num_accounts                              0.00      1.000      1.0
# num_debt_products                         0.00      0.000      0.0
# meses_antigüedad                          0.00      3.000     12.0
# days_since_last_purchase                 31.00     92.000    151.0
#
#                                                75%          max
# age                                        39.0000       105.00
# salary                                 132085.4325  22034738.76
# active_customer                             1.0000         1.00
# entry_date_year                          2018.0000      2019.00
# entry_date_month                           10.0000        12.00
# pk_partition_month                          4.0000         5.00
# Compra_debit_card                           1.0000         1.00
# em_acount_consecutive_months               13.0000        17.00
# pension_plan_consecutive_months             0.0000        17.00
# payroll_consecutive_months                  0.0000        17.00
# payroll_account_consecutive_months          0.0000        17.00
# emc_account_consecutive_months              0.0000        17.00
# credit_card_consecutive_months              0.0000        17.00
# short_term_deposit_consecutive_months       0.0000         8.00
# long_term_deposit_consecutive_months        0.0000        17.00
# securities_consecutive_months               0.0000        17.00
# funds_consecutive_months                    0.0000        17.00
# loans_consecutive_months                    0.0000         1.00
# mortgage_consecutive_months                 0.0000         2.00
# has_account                                 1.0000         1.00
# has_pension_plan                            0.0000         1.00
# has_investment                              0.0000         1.00
# has_loan                                    0.0000         1.00
# has_credit_card_debt                        0.0000         1.00
# num_accounts                                1.0000         4.00
# num_debt_products                           0.0000         1.00
# meses_antigüedad                           28.0000        52.00
# days_since_last_purchase                  457.0000       516.00

# %%
df.describe(exclude=np.number)[:4].T
# Out:
#                count unique                top   freq
# country_id     22653      7                 ES  22644
# region_code    22653     53                 28   5519
# gender         22653      2                  V  11773
# deceased       22653      2                  N  22651
# entry_channel  22653     26                KHE   6485
# segment        22653      4  02 - PARTICULARES  10832
# tipo_cliente   22653      2  Cliente_existente  22003

# %%
# procedemos a ver aquellas columnas con nulos y el número de nulos que tiene cada una de ellas

col_null = df.isna().sum()
col_withnull = col_null[col_null > 0]

print(f'Tenemos {len(col_null[col_null > 0])} columnas con nulos las cuales son: \n\n{col_withnull}')
# Out:
# Tenemos 1 columnas con nulos las cuales son:
#
# salary    11003
# dtype: int64

# %% [markdown]
# Observamos que tenemos una columna con nulos:
#
# - salary: se desconoce el salario de dichos clientes
#
# Para poder observar la distribución de los nulos les asignaremos un valor de -1.

# %%
df['salary'] = np.where(df['salary'].isna(),-1,df['salary'])

# %% [markdown]
# <a id='analisis_univariante'></a>
# ## Análisis Univariante
# [Volver al índice](#index)
#
# En este apartado analizamos cada variable de forma concreta (identificamos outliers, nulos, datos erróneos) y realizamos gráficas que nos ayudan a entender la distribución de cada una. A su vez, analizamos el TARGET y la relación que este guarda con los distintos atributos del dataset.

# %% [markdown]
# Para eliminar aquellas variables que veamos que no son explicativas vamos a crear una lista a la cual iremos añadiendo dichas variables. De este modo, luego en el procesamiento de las mismas podremos eliminarlas todas al mismo tiempo.

# %%
no_explicativas = []

# %% [markdown]
# ### Análisis del Target y clasificación de variables

# %%
df['Compra_'+producto].value_counts(dropna=False)
# Out:
# Compra_debit_card
# 1    11465
# 0    11188
# Name: count, dtype: int64

# %%
TARGET = 'Compra_'+producto
porcentaje_target = df[TARGET].mean()
print(f'Porcentaje de clientes que compran {producto}: {porcentaje_target}')
# Out:
# Porcentaje de clientes que compran debit_card: 0.5061139804882355

# %%
df[TARGET].value_counts().plot(kind="pie", figsize=(6,4), colormap="coolwarm");

# %% [markdown]
# Observamos que la columna **'Compra_'+producto** se trata del target, una variable booleana tipo int64 que nos indica si la el cliente ha comprado el producto o no. Cabe destacar que se trata de un target balanceado (porcentaje de prácticamente el 50%) y sin nulos por lo que en principio no deberemos de realizar ningún tipo de rebalanceo de los datos ni eliminación o imputación de filas con nulos.

# %% [markdown]
# Comenzamos clasificando las variables según si son categóricas, numéricas o booleanas con la ayuda de una función.

# %%
def obtener_lista_variables(dataset):
    lista_numericas = []
    lista_categoricas = []
    lista_booleanas = []

    for i in dataset:
        if (dataset[i].dtype.kind == 'f' or dataset[i].dtype.kind == 'i') and len(dataset[i].unique())!= 2 and (i not in TARGET):
            lista_numericas.append(i)
        if (dataset[i].dtype.kind == 'f' or dataset[i].dtype.kind == 'i') and len(dataset[i].unique()) == 2 and (i not in TARGET):
            lista_booleanas.append(i)
        if (dataset[i].dtype.kind == 'O') and (i not in TARGET):
            lista_categoricas.append(i)

    return lista_numericas,lista_categoricas,lista_booleanas

numericas,categoricas,booleanas = obtener_lista_variables(df)
print(f'Variables numéricas ({len(numericas)}): {numericas}')
print(f'Variables categóricas ({len(categoricas)}):{categoricas}')
print(f'Variables booleanas ({len(booleanas)}):{booleanas}')
# Out:
# Variables numéricas (18): ['age', 'salary', 'entry_date_year', 'entry_date_month', 'pk_partition_month', 'em_acount_consecutive_months', 'pension_plan_consecutive_months', 'payroll_consecutive_months', 'payroll_account_consecutive_months', 'emc_account_consecutive_months', 'credit_card_consecutive_months', 'long_term_deposit_consecutive_months', 'securities_consecutive_months', 'funds_consecutive_months', 'mortgage_consecutive_months', 'num_accounts', 'meses_antigüedad', 'days_since_last_purchase']
# Variables categóricas (7):['country_id', 'region_code', 'gender', 'deceased', 'entry_channel', 'segment', 'tipo_cliente']
# Variables booleanas (9):['active_customer', 'short_term_deposit_consecutive_months', 'loans_consecutive_months', 'has_account', 'has_pension_plan', 'has_investment', 'has_loan', 'has_credit_card_debt', 'num_debt_products']

# %% [markdown]
# ### Análisis categóricas

# %% [markdown]
# Al mismo tiempo que identificamos nulos, outliers y datos erróneos vamos a estimar si cada variable es explicativa o no. Para ello, nos enfocaremos en el análisis de una pivot_table que nos aporta los siguientes datos estadísticos:
#
# - el número total de clientes en cada categoría dentro de una variable
# - el número de clientes que ha comprado el producto en cada categoría
# - el porcentaje de compra asociado a cada categoría
#
# En función del número de clientes de cada categoría y lo mucho que su porcentaje de compra se distingue de la media del target (50%), determinaremos si la variable es explicativa o no.

# %%
categoricas
# Out:
# ['country_id',
#  'region_code',
#  'gender',
#  'deceased',
#  'entry_channel',
#  'segment',
#  'tipo_cliente']

# %% [markdown]
# A continuación vamos a definir las tres funciones que nos van a ayudar a analizar cada variable categórica y la relación que guarda cada una de ellas con el target.
#
#
# - **explore_cat_values** --> nos indica el número de nulos de una columna categórica específica y genera una pivot_table la cual proporciona un resumen estadístico sobre dicha columna y su relación con el Target a través de 3 columnas: ['Num_clientes','Num_compras','Porcentaje_compra']
#
#
# - **plot_cat_values** --> nos genera dos gráficas que nos ayudan a analizar tanto la distribución de las distintas categorías dentro de la variable como la distribución del Target dentro de cada una de esas categorías.
#
#
# - **analisis_cat** --> incorpora las dos funciones anteriores y realiza un análisis exploratorio de una columna categórica específica en un dataframe, incluyendo visualización y resumen estadístico.

# %%
def explore_cat_values(dataframe, column, target_col):
    """
    Genera un resumen estadístico sobre una columna categórica específica del dataframe y su relación con el Target.

    Parámetros:
    dataframe (pd.DataFrame): El dataframe que contiene los datos.
    column (str): El nombre de la columna categórica a explorar.
    target_col (str): El nombre de la columna Target que se analizará en relación con la columna categórica.

    Retorna:
    pd.DataFrame: Un dataframe que contiene el resumen de la columna categórica, incluyendo:
                  - 'Num_clientes': El número de ocurrencias de cada categoría.
                  - 'Num_compras': La suma de los valores en la columna objetivo para cada categoría.
                  - 'Porcentaje_compra': El promedio de los valores en la columna objetivo para cada categoría, indicando el porcentaje de compra.
    """

    resumen_df = dataframe.pivot_table(index=column, values=target_col, aggfunc=[len,'sum','mean'],observed=False)
    resumen_df.columns = ['Num_clientes', 'Num_compras','Porcentaje_compra']
    resumen_df = resumen_df.sort_values(by='Num_clientes',ascending=False)
    return resumen_df

# %%
def plot_cat_values(dataframe, column, target_column):
    """
    Genera un gráfico de barras para visualizar la relación entre una variable categórica y el Target.

    Parámetros:
    dataframe (pd.DataFrame): El dataframe que contiene los datos.
    column (str): El nombre de la columna categórica a explorar.
    target_column (str): El nombre de la columna Target que se analizará en relación con la columna categórica.

    Retorna:
    None: La función muestra un gráfico de barras y no devuelve ningún valor.
    """
    plt.figure(figsize=(10,4))
    
    # Gráfico que muestra la distribución del target en cada categoría de la variable categórica
    ax1 = sns.countplot(data=dataframe, x=column, hue=target_column, order=list(dataframe[column].unique()))
    ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)

    plt.tight_layout()
    plt.show();

# %%
def analisis_cat(dataframe, column, target_column):

    """
    Realiza un análisis exploratorio de una columna categórica específica en un dataframe, incluyendo visualización y resumen estadístico.

    Parámetros:
    dataframe (pd.DataFrame): El dataframe que contiene los datos.
    column (str): El nombre de la columna categórica a explorar.
    target_column (str): El nombre de la columna Target que se analizará en relación con la columna categórica.

    Retorna:
    pd.DataFrame: Un dataframe que contiene el resumen de la columna categórica, incluyendo:
                  - 'Num_clientes': El número de ocurrencias de cada categoría.
                  - 'Num_compras': La suma de los valores en la columna objetivo para cada categoría.
                  - 'Porcentaje_compra': El promedio de los valores en la columna objetivo para cada categoría, indicando el porcentaje de compra.
    """
    
    plot_cat_values(dataframe, column, target_column)
    return explore_cat_values(dataframe, column, target_column)

# %% [markdown]
# #### country_id

# %%
analisis_cat(df, 'country_id', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#             Num_clientes  Num_compras  Porcentaje_compra
# country_id
# ES                 22644        11458           0.506006
# GB                     3            3           1.000000
# DE                     2            2           1.000000
# CH                     1            0           0.000000
# CL                     1            0           0.000000
# ET                     1            1           1.000000
# FR                     1            1           1.000000

# %%
# la consideramos no explicativa debido a la poca varianza de la misma respecto del target, a parte su contenido está intrínseco en su
# mayoría en region_code

no_explicativas.append('country_id')

# %% [markdown]
# #### region_code

# %%
analisis_cat(df, 'region_code', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#              Num_clientes  Num_compras  Porcentaje_compra
# region_code
#  28                  5519         3208           0.581265
#  8                   1992          862           0.432731
#  46                  1279          602           0.470680
#  41                  1113          617           0.554358
#  30                   987          424           0.429585
#  15                   823          316           0.383961
#  3                    757          419           0.553501
#  29                   733          398           0.542974
#  11                   598          334           0.558528
#  36                   555          230           0.414414
#  33                   507          238           0.469428
#  35                   477          250           0.524109
#  50                   448          174           0.388393
#  18                   417          224           0.537170
#  45                   406          218           0.536946
#  47                   376          194           0.515957
#  6                    336           95           0.282738
#  37                   323          150           0.464396
#  14                   301          161           0.534884
#  39                   283          179           0.632509
#  2                    266          130           0.488722
#  7                    260          132           0.507692
#  12                   240          118           0.491667
#  13                   239          100           0.418410
#  10                   235           91           0.387234
#  43                   230          106           0.460870
#  21                   224          112           0.500000
#  9                    179           85           0.474860
#  38                   173          121           0.699422
#  24                   173          100           0.578035
#  23                   171          113           0.660819
#  4                    170          108           0.635294
#  32                   159           59           0.371069
#  17                   155           57           0.367742
#  48                   145           87           0.600000
#  27                   143           59           0.412587
#  25                   135           46           0.340741
#  19                   124           59           0.475806
#  49                   115           61           0.530435
#  31                   110           55           0.500000
#  26                   110           48           0.436364
#  16                    99           39           0.393939
#  34                    95           52           0.547368
#  5                     95           51           0.536842
#  20                    82           47           0.573171
#  40                    73           40           0.547945
#  1                     73           37           0.506849
#  22                    65           18           0.276923
#  44                    27           10           0.370370
#  42                    24           13           0.541667
#  52                    13            3           0.230769
#  51                    12            8           0.666667
# -1                      9            7           0.777778

# %% [markdown]
# Debido al gran número de categorías vamos a realizar lo que se conoce como un target_encoding. Esto consiste en reemplazar los valores categóricos de la variable por un valor numérico, en este caso, el porcentaje de compra asociado a cada región. Esto mantiene la relación directa entre la región y el target sin aumentar mucho la dimensionalidad del modelo (no hay necesidad de aplicar OHE a la variable)

# %%
# Cálculo de la tasa de compra por región
region_target_mean = df.groupby('region_code')[TARGET].mean()

# Reemplaza la variable de región con la tasa media de compra por región
df['region_encoded'] = df['region_code'].map(region_target_mean)

# añadimos la variable original a la lista de variables no explicativas
no_explicativas.append('region_code')

# %% [markdown]
# #### gender

# %%
analisis_cat(df, 'gender', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#         Num_clientes  Num_compras  Porcentaje_compra
# gender
# V              11773         6451           0.547949
# H              10880         5014           0.460846

# %% [markdown]
# #### deceased

# %%
analisis_cat(df, 'deceased', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#           Num_clientes  Num_compras  Porcentaje_compra
# deceased
# N                22651        11465           0.506159
# S                    2            0           0.000000

# %%
# tenemos solo dos fallecidos por lo que la consideramos variable no explicativa

no_explicativas.append('deceased')

# %% [markdown]
# #### segment

# %%
analisis_cat(df, 'segment', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                     Num_clientes  Num_compras  Porcentaje_compra
# segment
# 02 - PARTICULARES          10832         7717           0.712426
# 03 - UNIVERSITARIO         10590         3029           0.286025
# Unknown                      677          340           0.502216
# 01 - TOP                     554          379           0.684116

# %%
# ponemos la variable más bonita

df['segment'] = np.where(df['segment']=='03 - UNIVERSITARIO','Universitario',df['segment'])
df['segment'] = np.where(df['segment']=='02 - PARTICULARES','Particulares',df['segment'])
df['segment'] = np.where(df['segment']=='01 - TOP','Top',df['segment'])

df['segment'].value_counts()
# Out:
# segment
# Particulares     10832
# Universitario    10590
# Unknown            677
# Top                554
# Name: count, dtype: int64

# %% [markdown]
# #### entry_channel

# %%
analisis_cat(df, 'entry_channel', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                Num_clientes  Num_compras  Porcentaje_compra
# entry_channel
# KHE                    6485         1274           0.196453
# KHM                    4241         3696           0.871493
# KHQ                    2855          802           0.280911
# KHN                    2557         2259           0.883457
# KFC                    2409         1118           0.464093
# KAT                    1147          536           0.467306
# KHK                     950          591           0.622105
# Unknown                 669          336           0.502242
# RED                     503          414           0.823062
# KFA                     261          144           0.551724
# KHO                     173          151           0.872832
# KHL                     160           97           0.606250
# KHD                     147           16           0.108844
# KHF                      55           18           0.327273
# KHC                      15            6           0.400000
# KAZ                      12            1           0.083333
# KHP                       4            0           0.000000
# 013                       2            2           1.000000
# KEH                       1            1           1.000000
# KCI                       1            1           1.000000
# KBG                       1            0           0.000000
# KAY                       1            1           1.000000
# KAS                       1            1           1.000000
# KAG                       1            0           0.000000
# KAB                       1            0           0.000000
# 007                       1            0           0.000000

# %%
# agrupamos aquellos canales con menos de 200 clientes bajo el nombre de Others

def setOthers(dataframe, column, min_count):
    """
    Esta función toma una columna categórica en un DataFrame y reemplaza aquellas categorías cuya frecuencia es 
    menor que un umbral especificado (`min_count`) con la categoría 'Others'. Luego, la columna se convierte en 
    un tipo categórico con las categorías filtradas y 'Others'. Finalmente, las categorías no especificadas 
    explícitamente son reemplazadas por 'Others'.

    Parámetros:
    df (pd.DataFrame): El DataFrame que contiene la columna a transformar.
    columna (str): El nombre de la columna en el DataFrame que queremos transformar.
    min_count (int): El umbral de frecuencia mínima, es decir, el número mínimo de máquinas que una categoría debe tener para no ser agrupada en 'Others'.
    
    Retorna:
    pd.Series: Una Serie con la columna transformada, donde las categorías con frecuencia menor que `min_count` se han agrupado bajo 'Others'.
    """
    # Obtener el recuento de valores de la columna
    value_counts = dataframe[column].value_counts()
    # Filtrar las categorías que superan el umbral (min_count)
    top_categories = value_counts[value_counts >= min_count].index.to_list()
    # Añadir la categoría 'Others' al listado
    top_categories.append('Others')
    dataframe[column] = pd.Categorical(dataframe[column], categories=top_categories)
    # asignar a los nulos (categorías que no se encuentran en el top_categories) la categoría Others
    dataframe[column] = dataframe[column].fillna('Others')
    return dataframe[column]

setOthers(df, 'entry_channel', 200)
explore_cat_values(df,'entry_channel',TARGET)
# Out:
#                Num_clientes  Num_compras  Porcentaje_compra
# entry_channel
# KHE                    6485         1274           0.196453
# KHM                    4241         3696           0.871493
# KHQ                    2855          802           0.280911
# KHN                    2557         2259           0.883457
# KFC                    2409         1118           0.464093
# KAT                    1147          536           0.467306
# KHK                     950          591           0.622105
# Unknown                 669          336           0.502242
# Others                  576          295           0.512153
# RED                     503          414           0.823062
# KFA                     261          144           0.551724

# %% [markdown]
# #### tipo_cliente

# %%
analisis_cat(df, 'tipo_cliente', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                    Num_clientes  Num_compras  Porcentaje_compra
# tipo_cliente
# Cliente_existente         22003        11142           0.506385
# Cliente_nuevo               650          323           0.496923

# %%
no_explicativas.append('tipo_cliente')

# %% [markdown]
# ### Análisis numéricas

# %%
numericas
# Out:
# ['age',
#  'salary',
#  'entry_date_year',
#  'entry_date_month',
#  'pk_partition_month',
#  'em_acount_consecutive_months',
#  'pension_plan_consecutive_months',
#  'payroll_consecutive_months',
#  'payroll_account_consecutive_months',
#  'emc_account_consecutive_months',
#  'credit_card_consecutive_months',
#  'long_term_deposit_consecutive_months',
#  'securities_consecutive_months',
#  'funds_consecutive_months',
#  'mortgage_consecutive_months',
#  'num_accounts',
#  'meses_antigüedad',
#  'days_since_last_purchase']

# %% [markdown]
# Creamos una fución que nos permite plotear un histograma, un boxplot y un violinplot que nos ayudaran a obtener información útil sobre la distribución de las variables numéricas y su relación con el target. El boxplot indica la distribución de la variable numérica y el violinplot nos muestra la distribución de dicha variable en relación con el target.

# %%
def plot_num(dataframe, column, target_column):
    """
    Genera tres gráficos para visualizar la distribución de una variable numérica y su relación con una variable objetivo.

    Parámetros:
    dataframe (pd.DataFrame): El dataframe que contiene los datos.
    column (str): El nombre de la columna numérica a explorar.
    target_column (str): El nombre de la columna objetivo que se analizará en relación con la columna numérica.

    Retorna:
    None: La función muestra tres gráficos y no devuelve ningún valor.

    Descripción:
    La función genera una figura con tres subplots:
    - El primer subplot muestra un histograma de la distribución de la variable numérica.
    - El segundo subplot muestra un diagrama de cajas (boxplot) de la variable numérica.
    - El tercer subplot muestra un diagrama de violines (violinplot) de la variable objetivo en relación con la variable numérica.
    """
    plt.figure(figsize=(22,9))
    
    # Primer gráfico: Histograma de la distribución de la variable numérica
    ax1 = plt.subplot(3,1,1)
    sns.histplot(data=dataframe, x=column, bins=30, ax=ax1)
    ax1.set_xlabel('')
    
    # Segundo gráfico: Boxplot de la variable numérica
    ax2 = plt.subplot(3,1,2)
    sns.boxplot(data=dataframe, x=column, ax=ax2)
    ax2.set_xlabel('')
    
    # Tercer gráfico: Boxplot de la variable objetivo en relación con la variable numérica
    ax3 = plt.subplot(3,1,3)
    sns.violinplot(data=dataframe, x=target_column, y=column, ax=ax3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### age

# %%
plot_num(df, 'age', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### salary

# %%
plot_num(df[df['salary']<2e6], 'salary', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### entry_date_year

# %%
plot_num(df, 'entry_date_year', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### entry_date_month

# %%
plot_num(df, 'entry_date_month', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### pk_partition_month

# %%
plot_num(df, 'pk_partition_month', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# vemos que los violinplots no se diferencian mucho lo que indica que el mes no influye mucho en el TARGET

no_explicativas.append('pk_partition_month')

# %% [markdown]
# #### em_acount_consecutive_months

# %%
plot_num(df, 'em_acount_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### pension_plan_consecutive_months

# %%
plot_num(df, 'pension_plan_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df['pension_plan_consecutive_months'].value_counts()
# Out:
# pension_plan_consecutive_months
# 0     20751
# 1       678
# 2       447
# 3       230
# 4       127
# 5        80
# 6        67
# 7        55
# 8        47
# 13       36
# 9        24
# 10       23
# 14       20
# 15       19
# 17       15
# 12       14
# 11       10
# 16       10
# Name: count, dtype: int64

# %% [markdown]
# #### payroll_consecutive_months

# %%
plot_num(df, 'payroll_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### payroll_account_consecutive_months

# %%
plot_num(df, 'payroll_account_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### emc_account_consecutive_months

# %%
plot_num(df, 'emc_account_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### credit_card_consecutive_months

# %%
plot_num(df, 'credit_card_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
no_explicativas.append('credit_card_consecutive_months')

# %% [markdown]
# #### long_term_deposit_consecutive_months

# %%
plot_num(df, 'long_term_deposit_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
no_explicativas.append('long_term_deposit_consecutive_months')

# %% [markdown]
# #### securities_consecutive_months

# %%
plot_num(df, 'securities_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
no_explicativas.append('securities_consecutive_months')

# %% [markdown]
# #### funds_consecutive_months

# %%
plot_num(df, 'funds_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
no_explicativas.append('funds_consecutive_months')

# %% [markdown]
# #### mortgage_consecutive_months

# %%
plot_num(df, 'mortgage_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
no_explicativas.append('mortgage_consecutive_months')

# %% [markdown]
# #### num_accounts

# %%
plot_num(df, 'num_accounts', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### meses_antigüedad

# %%
plot_num(df, 'meses_antigüedad', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### days_since_last_purchase

# %%
plot_num(df, 'days_since_last_purchase', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#no_explicativas.append('days_since_last_purchase')

# %% [markdown]
# ### Booleanas

# %%
booleanas
# Out:
# ['active_customer',
#  'short_term_deposit_consecutive_months',
#  'loans_consecutive_months',
#  'has_account',
#  'has_pension_plan',
#  'has_investment',
#  'has_loan',
#  'has_credit_card_debt',
#  'num_debt_products']

# %% [markdown]
# Todas las variables que vamos a analizar a continuación son variables booleanas, lo que significa que no hace falta aplicar el OneHotEncoding y unicamente vamos a discutir si se trata de variables relevantes para nuestro modelo o no.

# %% [markdown]
# #### active_customer

# %%
analisis_cat(df, 'active_customer', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                  Num_clientes  Num_compras  Porcentaje_compra
# active_customer
# 1                       14560        10925           0.750343
# 0                        8093          540           0.066724

# %% [markdown]
# #### short_term_deposit_consecutive_months

# %%
analisis_cat(df, 'short_term_deposit_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                                        Num_clientes  Num_compras  \
# short_term_deposit_consecutive_months
# 0                                             22652        11465
# 8                                                 1            0
#
#                                        Porcentaje_compra
# short_term_deposit_consecutive_months
# 0                                               0.506136
# 8                                               0.000000

# %%
no_explicativas.append('short_term_deposit_consecutive_months')

# %% [markdown]
# #### loans_consecutive_months

# %%
analisis_cat(df, 'loans_consecutive_months', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                           Num_clientes  Num_compras  Porcentaje_compra
# loans_consecutive_months
# 0                                22652        11464           0.506092
# 1                                    1            1           1.000000

# %%
no_explicativas.append('loans_consecutive_months')

# %% [markdown]
# #### has_account

# %%
analisis_cat(df, 'has_account', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#              Num_clientes  Num_compras  Porcentaje_compra
# has_account
# 1                   19055        11123           0.583731
# 0                    3598          342           0.095053

# %% [markdown]
# #### has_pension_plan

# %%
analisis_cat(df, 'has_pension_plan', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                   Num_clientes  Num_compras  Porcentaje_compra
# has_pension_plan
# 0                        20751         9719           0.468363
# 1                         1902         1746           0.917981

# %% [markdown]
# #### has_investment

# %%
analisis_cat(df, 'has_investment', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                 Num_clientes  Num_compras  Porcentaje_compra
# has_investment
# 0                      22184        11195           0.504643
# 1                        469          270           0.575693

# %%
no_explicativas.append('has_investment')

# %% [markdown]
# #### has_loan

# %%
analisis_cat(df, 'has_loan', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#           Num_clientes  Num_compras  Porcentaje_compra
# has_loan
# 0                22650        11462           0.506049
# 1                    3            3           1.000000

# %%
no_explicativas.append('has_loan')

# %% [markdown]
# #### has_credit_card_debt

# %%
analisis_cat(df, 'has_credit_card_debt', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                       Num_clientes  Num_compras  Porcentaje_compra
# has_credit_card_debt
# 0                            22399        11266           0.502969
# 1                              254          199           0.783465

# %%
no_explicativas.append('has_credit_card_debt')

# %% [markdown]
# #### num_debt_products

# %%
analisis_cat(df, 'num_debt_products', TARGET)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_3120\138647495.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=70)
#                    Num_clientes  Num_compras  Porcentaje_compra
# num_debt_products
# 0                         22399        11266           0.502969
# 1                           254          199           0.783465

# %%
no_explicativas.append('num_debt_products')

# %% [markdown]
# <a id='analisis_multivariante'></a>
# ## Análisis Multivariante
# [Volver al índice](#index)
#
# En este apartado analizamos la distribución de variables 2 a 2 y analizamos la correlación que puede existir entre ellas.

# %% [markdown]
# Pero antes eliminamos aquellas variables que hemos considerado no explicativas.

# %%
no_explicativas
# Out:
# ['country_id',
#  'region_code',
#  'deceased',
#  'tipo_cliente',
#  'pk_partition_month',
#  'credit_card_consecutive_months',
#  'long_term_deposit_consecutive_months',
#  'securities_consecutive_months',
#  'funds_consecutive_months',
#  'mortgage_consecutive_months',
#  'short_term_deposit_consecutive_months',
#  'loans_consecutive_months',
#  'has_investment',
#  'has_loan',
#  'has_credit_card_debt',
#  'num_debt_products']

# %%
df = df.drop(columns=no_explicativas)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22653 entries, 1517558 to 1546388
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gender                              22653 non-null  object
#  1   age                                 22653 non-null  int64
#  2   salary                              22653 non-null  float64
#  3   entry_channel                       22653 non-null  category
#  4   active_customer                     22653 non-null  int32
#  5   segment                             22653 non-null  object
#  6   entry_date_year                     22653 non-null  int32
#  7   entry_date_month                    22653 non-null  int32
#  8   Compra_debit_card                   22653 non-null  int64
#  9   em_acount_consecutive_months        22653 non-null  int64
#  10  pension_plan_consecutive_months     22653 non-null  int64
#  11  payroll_consecutive_months          22653 non-null  int64
#  12  payroll_account_consecutive_months  22653 non-null  int64
#  13  emc_account_consecutive_months      22653 non-null  int64
#  14  has_account                         22653 non-null  int64
#  15  has_pension_plan                    22653 non-null  int32
#  16  num_accounts                        22653 non-null  int64
#  17  meses_antigüedad                    22653 non-null  int64
#  18  days_since_last_purchase            22653 non-null  int64
#  19  region_encoded                      22653 non-null  float64
# dtypes: category(1), float64(2), int32(4), int64(11), object(2)
# memory usage: 3.1+ MB

# %%
numericas,categoricas,booleanas = obtener_lista_variables(df)
print(f'Variables numéricas ({len(numericas)}): {numericas}')
print(f'Variables categóricas ({len(categoricas)}):{categoricas}')
print(f'Variables booleanas ({len(booleanas)}):{booleanas}')
# Out:
# Variables numéricas (13): ['age', 'salary', 'entry_date_year', 'entry_date_month', 'em_acount_consecutive_months', 'pension_plan_consecutive_months', 'payroll_consecutive_months', 'payroll_account_consecutive_months', 'emc_account_consecutive_months', 'num_accounts', 'meses_antigüedad', 'days_since_last_purchase', 'region_encoded']
# Variables categóricas (3):['gender', 'entry_channel', 'segment']
# Variables booleanas (3):['active_customer', 'has_account', 'has_pension_plan']

# %%
from scipy.stats import chi2_contingency

def relacion_categoricas(col_1,col_2):
    """
    Calcula y muestra el coeficiente de Cramér V para medir la asociación entre dos variables categóricas.

    Parámetros:
    col_1 (str): El nombre de la primera columna categórica.
    col_2 (str): El nombre de la segunda columna categórica.

    Retorna:
    None: La función imprime el coeficiente de Cramér V, una medida de asociación entre las dos variables categóricas.
    """
    tabla_contingencia = pd.crosstab(df[col_1], df[col_2])
    chi2, p, dof, ex = chi2_contingency(tabla_contingencia)
    n = tabla_contingencia.sum().sum()
    cramers_v = np.sqrt(chi2 / (n * (min(tabla_contingencia.shape) - 1)))
    print(f'El coeficiente de Cramér V entre {col_1} y {col_2} es de: {cramers_v}')

# %% [markdown]
# Vamos a comenzar viendo si ciertas variables estudiadas anteriormente son independientes o no. Para ello hacemos uso de la función **relacion_categoricas** que nos permite calcular el coeficiente de Cramér, el cuál nos da una idea de la independencia entre dos variables categóricas.
#
# Si el coeficiente es igual a 1, las variables son dependientes entre sí, indicando que están fuertemente relacionadas. Por otro lado, cuanto más cercano a 0 sea el coeficiente, más independencia hay entre las dos variables, por lo que no están relacionadas entre sí.

# %%
categoricas
# Out:
# ['gender', 'entry_channel', 'segment']

# %%
print('\n','Relación entre distintas variables categóricas:','\n')
relacion_categoricas('gender','entry_channel')
relacion_categoricas('gender','segment')
relacion_categoricas('segment','entry_channel')
# Out:
#  Relación entre distintas variables categóricas:
#
# El coeficiente de Cramér V entre gender y entry_channel es de: 0.1371610307185526
# El coeficiente de Cramér V entre gender y segment es de: 0.10819287642352915
# El coeficiente de Cramér V entre segment y entry_channel es de: 0.7463175932912601

# %% [markdown]
# Por otro lado, para las variables numéricas, vamos a crear un dataset con aquellas variables que nos interesan y mediante un heatmap de la matriz de correlación vamos a ser capaces de visualizar la correlación entre las distintas variables.

# %%
todas_numericas = df[numericas+booleanas]
corr_numericas = todas_numericas.corr() 
corr_numericas.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_eebeb_row0_col0, #T_eebeb_row1_col1, #T_eebeb_row2_col2, #T_eebeb_row3_col3, #T_eebeb_row4_col4, #T_eebeb_row5_col5, #T_eebeb_row6_col6, #T_eebeb_row7_col7, #T_eebeb_row8_col8, #T_eebeb_row9_col9, #T_eebeb_row10_col10, #T_eebeb_row11_col11, #T_eebeb_row12_col12, #T_eebeb_row13_col13, #T_eebeb_row14_col14, #T_eebeb_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_eebeb_row0_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col4, #T_eebeb_row0_col5, #T_eebeb_row3_col7, #T_eebeb_row5_col8, #T_eebeb_row5_col14, #T_eebeb_row6_col8, #T_eebeb_row6_col12, #T_eebeb_row6_col14, #T_eebeb_row10_col5, #T_eebeb_row10_col6, #T_eebeb_row12_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col6, #T_eebeb_row9_col12 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col7, #T_eebeb_row4_col2, #T_eebeb_row7_col0, #T_eebeb_row8_col15, #T_eebeb_row14_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_eebeb_row0_col8, #T_eebeb_row10_col8, #T_eebeb_row13_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_eebeb_row0_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_eebeb_row0_col10, #T_eebeb_row8_col2 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_eebeb_row0_col11, #T_eebeb_row12_col4 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col12, #T_eebeb_row12_col11, #T_eebeb_row15_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_eebeb_row0_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_eebeb_row0_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_eebeb_row0_col15, #T_eebeb_row5_col3, #T_eebeb_row6_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_eebeb_row1_col0, #T_eebeb_row1_col9, #T_eebeb_row7_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col2, #T_eebeb_row1_col4 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_eebeb_row1_col3, #T_eebeb_row4_col9, #T_eebeb_row14_col15 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_eebeb_row1_col5, #T_eebeb_row1_col6, #T_eebeb_row2_col14, #T_eebeb_row3_col1, #T_eebeb_row8_col1, #T_eebeb_row11_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col7, #T_eebeb_row15_col14 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col8, #T_eebeb_row3_col15 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col10 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_eebeb_row1_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_eebeb_row1_col12, #T_eebeb_row10_col13, #T_eebeb_row11_col8, #T_eebeb_row15_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col13 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_eebeb_row1_col14 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_eebeb_row1_col15, #T_eebeb_row14_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_eebeb_row2_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_eebeb_row2_col1, #T_eebeb_row2_col3, #T_eebeb_row2_col4, #T_eebeb_row2_col8, #T_eebeb_row2_col10, #T_eebeb_row2_col11, #T_eebeb_row3_col0, #T_eebeb_row4_col5, #T_eebeb_row4_col6, #T_eebeb_row4_col7, #T_eebeb_row4_col15, #T_eebeb_row10_col2, #T_eebeb_row11_col9, #T_eebeb_row11_col12, #T_eebeb_row11_col13, #T_eebeb_row11_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_eebeb_row2_col5, #T_eebeb_row2_col6, #T_eebeb_row2_col7, #T_eebeb_row3_col5, #T_eebeb_row3_col6, #T_eebeb_row15_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_eebeb_row2_col9, #T_eebeb_row4_col1, #T_eebeb_row5_col0, #T_eebeb_row9_col3, #T_eebeb_row9_col11, #T_eebeb_row13_col8, #T_eebeb_row14_col0, #T_eebeb_row14_col6, #T_eebeb_row15_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_eebeb_row2_col12, #T_eebeb_row13_col12, #T_eebeb_row14_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_eebeb_row2_col13 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_eebeb_row2_col15, #T_eebeb_row4_col13, #T_eebeb_row7_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_eebeb_row3_col2, #T_eebeb_row10_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_eebeb_row3_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_eebeb_row3_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_eebeb_row3_col9 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_eebeb_row3_col10 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_eebeb_row3_col11 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_eebeb_row3_col12, #T_eebeb_row13_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_eebeb_row3_col13, #T_eebeb_row5_col4, #T_eebeb_row6_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_eebeb_row3_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_eebeb_row4_col0, #T_eebeb_row11_col15 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_eebeb_row4_col3, #T_eebeb_row8_col13, #T_eebeb_row10_col3, #T_eebeb_row12_col13 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_eebeb_row4_col8, #T_eebeb_row5_col1, #T_eebeb_row6_col1, #T_eebeb_row10_col15 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_eebeb_row4_col10, #T_eebeb_row6_col15 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_eebeb_row4_col11, #T_eebeb_row7_col6, #T_eebeb_row9_col13, #T_eebeb_row14_col13, #T_eebeb_row15_col9 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_eebeb_row4_col12, #T_eebeb_row11_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_eebeb_row4_col14, #T_eebeb_row5_col10, #T_eebeb_row6_col10 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_eebeb_row5_col2, #T_eebeb_row6_col2, #T_eebeb_row8_col9, #T_eebeb_row11_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_eebeb_row5_col6, #T_eebeb_row6_col5 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_eebeb_row5_col7 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_eebeb_row5_col9, #T_eebeb_row6_col9, #T_eebeb_row15_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_eebeb_row5_col11, #T_eebeb_row14_col7, #T_eebeb_row14_col11 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_eebeb_row5_col12, #T_eebeb_row7_col12, #T_eebeb_row8_col14 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_eebeb_row5_col13, #T_eebeb_row6_col13, #T_eebeb_row7_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_eebeb_row5_col15 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_eebeb_row6_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_eebeb_row6_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_eebeb_row6_col11, #T_eebeb_row9_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_eebeb_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_eebeb_row7_col5 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_eebeb_row7_col8, #T_eebeb_row8_col12, #T_eebeb_row15_col12 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_eebeb_row7_col9 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_eebeb_row7_col10 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_eebeb_row7_col11 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_eebeb_row7_col13 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_eebeb_row7_col14 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_eebeb_row7_col15 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_eebeb_row8_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_eebeb_row8_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_eebeb_row8_col4, #T_eebeb_row13_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_eebeb_row8_col5, #T_eebeb_row8_col6, #T_eebeb_row12_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_eebeb_row8_col7, #T_eebeb_row12_col15 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_eebeb_row8_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_eebeb_row8_col11, #T_eebeb_row13_col15 {
#   b

# %%
tabla_correlacion = corr_numericas.stack().reset_index()
tabla_correlacion.columns = ['Variable 1', 'Variable 2', 'Correlación']

# Filtrar los valores duplicados y las autocorrelaciones
tabla_correlacion = tabla_correlacion[tabla_correlacion['Variable 1'] != tabla_correlacion['Variable 2']]
tabla_correlacion['abs_Correlación'] = tabla_correlacion['Correlación'].abs()
tabla_correlacion = tabla_correlacion.drop_duplicates(subset=['Correlación'])

# Ordenar los valores por la correlación absoluta
tabla_correlacion = tabla_correlacion.sort_values(by='abs_Correlación', ascending=False)

# Mostrar las correlaciones más altas, tanto positivas como negativas
tabla_correlacion.head(10)
# Out:
#                           Variable 1                          Variable 2  \
# 86   pension_plan_consecutive_months          payroll_consecutive_months
# 42                   entry_date_year                    meses_antigüedad
# 158                     num_accounts                         has_account
# 95   pension_plan_consecutive_months                    has_pension_plan
# 111       payroll_consecutive_months                    has_pension_plan
# 87   pension_plan_consecutive_months  payroll_account_consecutive_months
# 103       payroll_consecutive_months  payroll_account_consecutive_months
# 43                   entry_date_year            days_since_last_purchase
# 159                     num_accounts                    has_pension_plan
# 171                 meses_antigüedad            days_since_last_purchase
#
#      Correlación  abs_Correlación
# 86      0.993882         0.993882
# 42     -0.967295         0.967295
# 158     0.752553         0.752553
# 95      0.684792         0.684792
# 111     0.674284         0.674284
# 87      0.617859         0.617859
# 103     0.611433         0.611433
# 43     -0.610062         0.610062
# 159     0.599264         0.599264
# 171     0.582962         0.582962

# %%
correlacion_alta = tabla_correlacion[tabla_correlacion['abs_Correlación']>0.90]['Variable 1'].to_list()
print(f'Se eliminan las siguientes variables debido a su alta correlación con otras columnas: {correlacion_alta}')
df = df.drop(columns= correlacion_alta)
# Out:
# Se eliminan las siguientes variables debido a su alta correlación con otras columnas: ['pension_plan_consecutive_months', 'entry_date_year']

# %% [markdown]
# # DATA PREPARATION

# %% [markdown]
# Una vez tenemos limpio el dataset y lo tenemos listo para preprocesar vamos a únicamente a estandarizar aquellas variables numéricas que lo requieren.
# Vamos a realizar este paso para tener un dataset de entrenamiento para los modelos de LightGBM y CatBoost que, pese a tratar con variables categóricas sin problema, se recomienda que las variables numéricas si se encuentren estandariazdas/normalizadas. Una vez estandarizadas las variables numéricas, vamos a aplicar un OHE a aquellas variables categóricas que lo necesiten, para tener los datasets preparados para aplicar tanto el modelo de Regresión Logística como el XGBoost.
#
# A su vez, vamos a crear el dataframe sobre el que aplicaremos el modelo final, es decir, aquellos clientes que tenemos en la base de datos del mes de junio y no poseen el producto. Este dataset no contará con el TARGET ya que es la columna a predecir del mismo.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22653 entries, 1517558 to 1546388
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gender                              22653 non-null  object
#  1   age                                 22653 non-null  int64
#  2   salary                              22653 non-null  float64
#  3   entry_channel                       22653 non-null  category
#  4   active_customer                     22653 non-null  int32
#  5   segment                             22653 non-null  object
#  6   entry_date_month                    22653 non-null  int32
#  7   Compra_debit_card                   22653 non-null  int64
#  8   em_acount_consecutive_months        22653 non-null  int64
#  9   payroll_consecutive_months          22653 non-null  int64
#  10  payroll_account_consecutive_months  22653 non-null  int64
#  11  emc_account_consecutive_months      22653 non-null  int64
#  12  has_account                         22653 non-null  int64
#  13  has_pension_plan                    22653 non-null  int32
#  14  num_accounts                        22653 non-null  int64
#  15  meses_antigüedad                    22653 non-null  int64
#  16  days_since_last_purchase            22653 non-null  int64
#  17  region_encoded                      22653 non-null  float64
# dtypes: category(1), float64(2), int32(3), int64(10), object(2)
# memory usage: 2.9+ MB

# %%
numericas,categoricas,booleanas = obtener_lista_variables(df)
print(f'Variables numéricas ({len(numericas)}): {numericas}')
print(f'Variables categóricas ({len(categoricas)}):{categoricas}')
print(f'Variables booleanas ({len(booleanas)}):{booleanas}')
# Out:
# Variables numéricas (11): ['age', 'salary', 'entry_date_month', 'em_acount_consecutive_months', 'payroll_consecutive_months', 'payroll_account_consecutive_months', 'emc_account_consecutive_months', 'num_accounts', 'meses_antigüedad', 'days_since_last_purchase', 'region_encoded']
# Variables categóricas (3):['gender', 'entry_channel', 'segment']
# Variables booleanas (3):['active_customer', 'has_account', 'has_pension_plan']

# %% [markdown]
# <a id='dataframe_predecir'></a>
# ## Creación del dataframe a predecir
# [Volver al índice](#index)
#
# En este apartado vamos a crear el dataframe con las fechas de junio. Para ello vamos a considerar que los clientes son los mismos que en mayo ya que nuestros modelos se basan en los datos que tenemos de los clientes el mes anterior. A su vez, de todos los clientes de mayo debemos eliminar aquellos que han comprado o tienen el producto ya que consideramos que el 100% de clientes mantienen el producto y no se dan de baja del mismo, por lo tanto no lo pueden volver a comprar. Una vez creado este dataframe seguirá el mismo procesamiento de las variables para poder aplicarle el modelo final una vez escogido.

# %%
info_clientes_2['entry_date'+'_year'] = info_clientes_2['entry_date'].dt.year
info_clientes_2['entry_date'+'_month'] = info_clientes_2['entry_date'].dt.month
info_clientes_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2177407 entries, 0 to 2177406
# Data columns (total 66 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   pk_cid                                 int64
#  1   pk_partition                           datetime64[ns]
#  2   country_id                             object
#  3   region_code                            int32
#  4   gender                                 object
#  5   age                                    int64
#  6   deceased                               object
#  7   salary                                 float64
#  8   age_group                              object
#  9   salary_bracket                         category
#  10  em_acount_consecutive_months           int64
#  11  debit_card_consecutive_months          int64
#  12  pension_plan_consecutive_months        int64
#  13  payroll_consecutive_months             int64
#  14  payroll_account_consecutive_months     int64
#  15  emc_account_consecutive_months         int64
#  16  credit_card_consecutive_months         int64
#  17  short_term_deposit_consecutive_months  int64
#  18  long_term_deposit_consecutive_months   int64
#  19  securities_consecutive_months          int64
#  20  funds_consecutive_months               int64
#  21  loans_consecutive_months               int64
#  22  mortgage_consecutive_months            int64
#  23  short_term_deposit                     int64
#  24  loans                                  int64
#  25  mortgage                               int64
#  26  funds                                  int64
#  27  securities                             int64
#  28  long_term_deposit                      int64
#  29  em_account_pp                          int64
#  30  credit_card                            int64
#  31  payroll                                int32
#  32  pension_plan                           int32
#  33  payroll_account                        int64
#  34  emc_account                            int64
#  35  debit_card                             int64
#  36  em_account_p                           int64
#  37  em_acount                              int64
#  38  total_products                         int64
#  39  total_products_no_account              int64
#  40  spent_on_account                       float64
#  41  spent_on_payment_card                  float64
#  42  spent_on_pension_plan                  float64
#  43  spent_on_investment                    float64
#  44  spent_on_loan                          float64
#  45  has_account                            int64
#  46  has_payment_card                       int64
#  47  has_pension_plan                       int32
#  48  has_investment                         int64
#  49  has_loan                               int64
#  50  has_credit_card_debt                   int64
#  51  num_accounts                           int64
#  52  num_debt_products                      int64
#  53  entry_date                             datetime64[ns]
#  54  entry_channel                          object
#  55  active_customer                        float64
#  56  segment                                object
#  57  meses_antigüedad                       int64
#  58  total_spend                            float64
#  59  ultima_compra                          datetime64[ns]
#  60  days_since_last_purchase               int64
#  61  months_since_last_purchase             int64
#  62  product_posesion                       bool
#  63  max_products                           int64
#  64  entry_date_year                        int32
#  65  entry_date_month                       int32
# dtypes: bool(1), category(1), datetime64[ns](3), float64(8), int32(6), int64(41), object(6)
# memory usage: 1017.5+ MB

# %%
# comenzamos escogiendo los datos de todos los clientes de mayo que no poseen el producto
clientes_junio = info_clientes_2[info_clientes_2['pk_partition']=='2019-05-01']
clientes_junio_con_producto = clientes_junio[clientes_junio[producto]==1]
clientes_junio_sin_producto = clientes_junio[clientes_junio[producto]==0]
print(f'En junio tenemos un total de {clientes_junio.shape[0]}','\n',
      f'de los cuales poseen el producto {clientes_junio_con_producto.shape[0]}','\n',
      f'y sin producto {clientes_junio_sin_producto.shape[0]}')
# Out:
# En junio tenemos un total de 442995
#  de los cuales poseen el producto 43261
#  y sin producto 399734

# %% [markdown]
# Sobre aquellos clientes que no poseen el producto es sobre los que vamos aplicar el modelo de propensión a compra definitivo. De este modo obtendremos aquellos clientes más propensos a obtener el producto.

# %%
# necesitamos que el dataset tenga las mismas columnas que el dataset que vamos a implementarle al modelo, por lo tanto 
# obtenemos las columnas en común
columnas_comunes = clientes_junio_sin_producto.columns.intersection(df.columns).to_list()

# nos quedamos unicamente con las columnas comunes a ambos
clientes_junio_sin_producto = clientes_junio_sin_producto[columnas_comunes+['pk_cid','region_code']]
clientes_junio_sin_producto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399734 entries, 1734412 to 2177406
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   gender                              399734 non-null  object
#  1   age                                 399734 non-null  int64
#  2   salary                              262717 non-null  float64
#  3   em_acount_consecutive_months        399734 non-null  int64
#  4   payroll_consecutive_months          399734 non-null  int64
#  5   payroll_account_consecutive_months  399734 non-null  int64
#  6   emc_account_consecutive_months      399734 non-null  int64
#  7   has_account                         399734 non-null  int64
#  8   has_pension_plan                    399734 non-null  int32
#  9   num_accounts                        399734 non-null  int64
#  10  entry_channel                       399734 non-null  object
#  11  active_customer                     399734 non-null  float64
#  12  segment                             399734 non-null  object
#  13  meses_antigüedad                    399734 non-null  int64
#  14  days_since_last_purchase            399734 non-null  int64
#  15  entry_date_month                    399734 non-null  int32
#  16  pk_cid                              399734 non-null  int64
#  17  region_code                         399734 non-null  int32
# dtypes: float64(2), int32(3), int64(10), object(3)
# memory usage: 53.4+ MB

# %%
# ahora debemos tratar cada columna de la misma manera que hemos tratado el resto de variables

# a los nulos le imputamos el valor -1
clientes_junio_sin_producto['salary'] = np.where(clientes_junio_sin_producto['salary'].isna(),-1,clientes_junio_sin_producto['salary'])
clientes_junio_sin_producto['days_since_last_purchase'] = np.where(clientes_junio_sin_producto['days_since_last_purchase'].isna(),-1,clientes_junio_sin_producto['days_since_last_purchase'])

# reemplazamos la variable de región con la tasa media de compra por región
clientes_junio_sin_producto['region_encoded'] = clientes_junio_sin_producto['region_code'].map(region_target_mean)
clientes_junio_sin_producto = clientes_junio_sin_producto.drop(columns=['region_code'])

# ponemos la variable más bonita

clientes_junio_sin_producto['segment'] = np.where(clientes_junio_sin_producto['segment']=='03 - UNIVERSITARIO','Universitario',clientes_junio_sin_producto['segment'])
clientes_junio_sin_producto['segment'] = np.where(clientes_junio_sin_producto['segment']=='02 - PARTICULARES','Particulares',clientes_junio_sin_producto['segment'])
clientes_junio_sin_producto['segment'] = np.where(clientes_junio_sin_producto['segment']=='01 - TOP','Top',clientes_junio_sin_producto['segment'])

# necesitamos tener los mismos canales que en el dataset procesado
allowed_categories = ['KHE', 'KHM', 'KHQ', 'KHN', 'KFC', 'KAT', 'KHK', 'Unknown', 'Others', 'RED', 'KFA']

# reemplazamos las categorías no permitidas por 'Others'
clientes_junio_sin_producto['entry_channel'] = clientes_junio_sin_producto['entry_channel'].apply(lambda x: x if x in allowed_categories else 'Others')

# por úlimo establecemos el pk_cid como el index
clientes_junio_sin_producto.set_index('pk_cid',inplace=True)

# %%
clientes_junio_sin_producto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399734 entries, 657826 to 1550586
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   gender                              399734 non-null  object
#  1   age                                 399734 non-null  int64
#  2   salary                              399734 non-null  float64
#  3   em_acount_consecutive_months        399734 non-null  int64
#  4   payroll_consecutive_months          399734 non-null  int64
#  5   payroll_account_consecutive_months  399734 non-null  int64
#  6   emc_account_consecutive_months      399734 non-null  int64
#  7   has_account                         399734 non-null  int64
#  8   has_pension_plan                    399734 non-null  int32
#  9   num_accounts                        399734 non-null  int64
#  10  entry_channel                       399734 non-null  object
#  11  active_customer                     399734 non-null  float64
#  12  segment                             399734 non-null  object
#  13  meses_antigüedad                    399734 non-null  int64
#  14  days_since_last_purchase            399734 non-null  int64
#  15  entry_date_month                    399734 non-null  int32
#  16  region_encoded                      399734 non-null  float64
# dtypes: float64(3), int32(2), int64(9), object(3)
# memory usage: 51.8+ MB

# %% [markdown]
# <a id='transformacion'></a>
# ## Transformación de atributos
# [Volver al índice](#index)
#
# En este apartado aplicamos el OneHotEncoding y el Ordinal Encoding sobre aquellas variables que lo requieran tanto en el dataset que usaremos para entrenar los modelos como en el dataset final sobre el que haremos la predicción.

# %%
categoricas
# Out:
# ['gender', 'entry_channel', 'segment']

# %%
numericas
# Out:
# ['age',
#  'salary',
#  'entry_date_month',
#  'em_acount_consecutive_months',
#  'payroll_consecutive_months',
#  'payroll_account_consecutive_months',
#  'emc_account_consecutive_months',
#  'num_accounts',
#  'meses_antigüedad',
#  'days_since_last_purchase',
#  'region_encoded']

# %%
# comenzamos aplicando StandardScaler a aquellas variables numéricas para que a los modelos les resulte más fácil encontrar patrones
scaler = StandardScaler()
# Aplicar el escalado solo a las columnas numéricas tanto del dataframe de 'entrenamiento' como el de junio
df[numericas] = scaler.fit_transform(df[numericas])
clientes_junio_sin_producto[numericas] = scaler.fit_transform(clientes_junio_sin_producto[numericas])

# %%
df.describe(include=np.number).T
# Out:
#                                       count          mean       std       min  \
# age                                 22653.0 -8.217993e-17  1.000022 -2.464554
# salary                              22653.0 -8.782588e-18  1.000022 -0.307488
# active_customer                     22653.0  6.427405e-01  0.479203  0.000000
# entry_date_month                    22653.0 -1.154283e-16  1.000022 -1.781779
# Compra_debit_card                   22653.0  5.061140e-01  0.499974  0.000000
# em_acount_consecutive_months        22653.0 -8.531657e-17  1.000022 -1.026933
# payroll_consecutive_months          22653.0  2.258380e-17  1.000022 -0.204140
# payroll_account_consecutive_months  22653.0 -2.383845e-17  1.000022 -0.262731
# emc_account_consecutive_months      22653.0 -4.767691e-17  1.000022 -0.209883
# has_account                         22653.0  8.411689e-01  0.365527  0.000000
# has_pension_plan                    22653.0  8.396239e-02  0.277338  0.000000
# num_accounts                        22653.0  7.527933e-18  1.000022 -1.731852
# meses_antigüedad                    22653.0 -8.029795e-17  1.000022 -1.123388
# days_since_last_purchase            22653.0  9.033519e-17  1.000022 -1.171741
# region_encoded                      22653.0  3.851792e-16  1.000022 -3.452713
#
#                                          25%       50%       75%         max
# age                                -0.796846 -0.240943  0.473789    5.715156
# salary                             -0.307488 -0.147866  0.152056  110.754005
# active_customer                     0.000000  1.000000  1.000000    1.000000
# entry_date_month                   -0.939141  0.184376  0.746135    1.307894
# Compra_debit_card                   0.000000  1.000000  1.000000    1.000000
# em_acount_consecutive_months       -1.026933 -0.393772  1.030839    1.663999
# payroll_consecutive_months         -0.204140 -0.204140 -0.204140   12.144989
# payroll_account_consecutive_months -0.262731 -0.262731 -0.262731    7.018880
# emc_account_consecutive_months     -0.209883 -0.209883 -0.209883    6.408712
# has_account                         1.000000  1.000000  1.000000    1.000000
# has_pension_plan                    0.000000  0.000000  0.000000    1.000000
# num_accounts                        0.039488  0.039488  0.039488    5.353509
# meses_antigüedad                   -0.916246 -0.294821  0.809934    2.467066
# days_since_last_purchase           -0.837644 -0.514501  1.161460    1.484603
# region_encoded                     -0.920194  0.360761  0.942360    3.406555

# %%
df.head()
# Out:
#         gender       age    salary entry_channel  active_customer  \
# cid
# 1517558      V  0.632618 -0.307488           KHN                1
# 1161959      H -0.558602 -0.109460           KAT                0
# 1100492      H -0.796846 -0.130175           KHE                0
# 1391462      V  1.188520  0.044452           KHN                0
# 1391434      V  1.823838 -0.307488           KHK                1
#
#                segment  entry_date_month  Compra_debit_card  \
# cid
# 1517558   Particulares          1.307894                  1
# 1161959  Universitario          0.184376                  0
# 1100492  Universitario          1.027014                  0
# 1391462            Top         -0.939141                  1
# 1391434   Particulares         -0.939141                  1
#
#          em_acount_consecutive_months  payroll_consecutive_months  \
# cid
# 1517558                     -0.710352                    -0.20414
# 1161959                      1.030839                    -0.20414
# 1100492                      1.030839                    -0.20414
# 1391462                     -1.026933                    -0.20414
# 1391434                     -1.026933                    -0.20414
#
#          payroll_account_consecutive_months  emc_account_consecutive_months  \
# cid
# 1517558                           -0.262731                       -0.209883
# 1161959                           -0.262731                       -0.209883
# 1100492                           -0.262731                       -0.209883
# 1391462                           -0.262731                       -0.209883
# 1391434                            0.165599                       -0.209883
#
#          has_account  has_pension_plan  num_accounts  meses_antigüedad  \
# cid
# 1517558            1                 0      0.039488         -1.054340
# 1161959            1                 0      0.039488          0.878981
# 1100492            1                 0      0.039488          1.500405
# 1391462            0                 0     -1.731852         -0.501963
# 1391434            1                 0      0.039488         -0.501963
#
#          days_since_last_purchase  region_encoded
# cid
# 1517558                 -1.007431        1.939935
# 1161959                  1.484603       -0.181164
# 1100492                  1.484603        0.942360
# 1391462                  0.153693        0.901857
# 1391434                 -0.344714       -0.920194

# %% [markdown]
# En este momento ya tenemos el dataframe procesado para los modelos que soportan categorías como son LightGBM y CatBoost. Por lo tanto realizaremos una copia de este dataframe para usarlo en el entrenamiento de dichos modelos.

# %%
df_cat_procesado = df.copy()
junio_procesado = clientes_junio_sin_producto.copy()

# %%
#df_cat_procesado.to_pickle('df_cat_procesado.pkl')

# %%
def dummie(dataframe, columnas, col_dummie=None):
    """
    Genera columnas dummies a partir de una o varias columnas categóricas en un DataFrame, añade las dummies generadas al DataFrame original y elimina las columnas originales.

    Parámetros:
    dataframe (pd.DataFrame): El DataFrame sobre el cual se va a aplicar la transformación. 
    columnas (str o list): El nombre de una columna o una lista de columnas categóricas que se van a transformar en dummies. 
    col_dummie (str, optional): El nombre de la columna dummy específica que se desea añadir al DataFrame. 
                                Si se especifica, solo esa columna dummy se añadirá al DataFrame.
                                Si no se especifica (None), se añadirán todas las columnas dummies generadas.
        
    Retorna:
    pd.DataFrame: Un nuevo DataFrame con las columnas dummies añadidas y las columnas originales eliminadas.
    """
    # Convertir 'columnas' a lista si no lo es
    if isinstance(columnas, str):
        columnas = [columnas]
    
    for columna in columnas:
        # Aplicamos el OneHotEncoding
        _dummy_dataset = pd.get_dummies(dataframe[columna], prefix=columna)

        # Si se especifica una columna en particular, seleccionamos solo esa
        if col_dummie is not None:
            _dummy_dataset = _dummy_dataset[[col_dummie]]

        # Añadimos las columnas dummies al dataframe original
        dataframe = pd.concat([dataframe, _dummy_dataset.astype(int)], axis=1)

        # Eliminamos la columna original
        dataframe = dataframe.drop(columns=[columna])
    
    return dataframe

# %% [markdown]
# Comenzamos aplicando el OneHotEncoding a través de la función *dummie* que nos transforma los valores de la columna a distintas columnas booleanas y elimina la variable original del dataset.

# %%
df = dummie(df,categoricas)
clientes_junio = dummie(clientes_junio_sin_producto,categoricas)

# %%
correlacion_final = df.corr() 
#correlacion_final.style.background_gradient(cmap='coolwarm')

# %%
corr_long = correlacion_final.stack().reset_index()
corr_long.columns = ['Variable 1', 'Variable 2', 'Correlación']

# Filtrar los valores duplicados y las autocorrelaciones
corr_long = corr_long[corr_long['Variable 1'] != corr_long['Variable 2']]
corr_long['abs_Correlación'] = corr_long['Correlación'].abs()
corr_long = corr_long.drop_duplicates(subset=['Correlación'])

# Ordenar los valores por la correlación absoluta
corr_long = corr_long.sort_values(by='abs_Correlación', ascending=False)

# Mostrar las correlaciones más altas, tanto positivas como negativas
corr_long.head(30)
# Out:
#                              Variable 1                          Variable 2  \
# 496                            gender_H                            gender_V
# 799               entry_channel_Unknown                     segment_Unknown
# 926                segment_Particulares               segment_Universitario
# 141                   Compra_debit_card            days_since_last_purchase
# 299                         has_account                        num_accounts
# 30                                  age               segment_Universitario
# 202          payroll_consecutive_months                    has_pension_plan
# 68                      active_customer                   Compra_debit_card
# 574                   entry_channel_KHE               segment_Universitario
# 199          payroll_consecutive_months  payroll_account_consecutive_months
# 331                    has_pension_plan                        num_accounts
# 397                    meses_antigüedad            days_since_last_purchase
# 401                    meses_antigüedad                   entry_channel_KHE
# 28                                  age                segment_Particulares
# 433            days_since_last_purchase                   entry_channel_KHE
# 572                   entry_channel_KHE                segment_Particulares
# 77                      active_customer            days_since_last_purchase
# 234  payroll_account_consecutive_months                    has_pension_plan
# 172        em_acount_consecutive_months                    meses_antigüedad
# 75                      active_customer                        num_accounts
# 73                      active_customer                         has_account
# 177        em_acount_consecutive_months                   entry_channel_KHE
# 173        em_acount_consecutive_months            days_since_last_purchase
# 169        em_acount_consecutive_months                         has_account
# 203          payroll_consecutive_months                        num_accounts
# 402                    meses_antigüedad                   entry_channel_KHM
# 446            days_since_last_purchase               segment_Universitario
# 158                   Compra_debit_card               segment_Universitario
# 139                   Compra_debit_card                        num_accounts
# 17                                  age                   entry_channel_KHE
#
#      Correlación  abs_Correlación
# 496    -1.000000         1.000000
# 799     0.986236         0.986236
# 926    -0.896907         0.896907
# 141    -0.768991         0.768991
# 299     0.752553         0.752553
# 30     -0.676553         0.676553
# 202     0.674284         0.674284
# 68      0.655219         0.655219
# 574     0.612715         0.612715
# 199     0.611433         0.611433
# 331     0.599264         0.599264
# 397     0.582962         0.582962
# 401     0.573889         0.573889
# 28      0.569594         0.569594
# 433     0.554241         0.554241
# 572    -0.543105         0.543105
# 77     -0.540557         0.540557
# 234     0.505983         0.505983
# 172     0.498984         0.498984
# 75      0.496488         0.496488
# 73      0.494632         0.494632
# 177     0.488036         0.488036
# 173     0.472097         0.472097
# 169     0.446240         0.446240
# 203     0.426181         0.426181
# 402    -0.421713         0.421713
# 446     0.419085         0.419085
# 158    -0.412460         0.412460
# 139     0.399070         0.399070
# 17     -0.398915         0.398915

# %% [markdown]
# Debido a el tratamiento realizado sobre las variables, las categorías que surgen tras realizar el OneHotEncoding pueden tener altas relaciones como es el caso de la variable gender. Es por ello que hemos realizado esta comprobación final, para asegurarnos de prescindir de estas variables con correlaciones tan altas.
#
# Pasamos por lo tanto a eliminar una de las dos variables en aquellas que poseen más de un 90% de correlación:

# %%
correlacion_alta = corr_long[corr_long['abs_Correlación']>0.90]['Variable 2'].to_list()
correlacion_alta
# Out:
# ['gender_V', 'segment_Unknown']

# %%
df = df.drop(columns= correlacion_alta)
clientes_junio = clientes_junio.drop(columns = correlacion_alta)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22653 entries, 1517558 to 1546388
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   age                                 22653 non-null  float64
#  1   salary                              22653 non-null  float64
#  2   active_customer                     22653 non-null  int32
#  3   entry_date_month                    22653 non-null  float64
#  4   Compra_debit_card                   22653 non-null  int64
#  5   em_acount_consecutive_months        22653 non-null  float64
#  6   payroll_consecutive_months          22653 non-null  float64
#  7   payroll_account_consecutive_months  22653 non-null  float64
#  8   emc_account_consecutive_months      22653 non-null  float64
#  9   has_account                         22653 non-null  int64
#  10  has_pension_plan                    22653 non-null  int32
#  11  num_accounts                        22653 non-null  float64
#  12  meses_antigüedad                    22653 non-null  float64
#  13  days_since_last_purchase            22653 non-null  float64
#  14  region_encoded                      22653 non-null  float64
#  15  gender_H                            22653 non-null  int32
#  16  entry_channel_KHE                   22653 non-null  int32
#  17  entry_channel_KHM                   22653 non-null  int32
#  18  entry_channel_KHQ                   22653 non-null  int32
#  19  entry_channel_KHN                   22653 non-null  int32
#  20  entry_channel_KFC                   22653 non-null  int32
#  21  entry_channel_KAT                   22653 non-null  int32
#  22  entry_channel_KHK                   22653 non-null  int32
#  23  entry_channel_Unknown               22653 non-null  int32
#  24  entry_channel_RED                   22653 non-null  int32
#  25  entry_channel_KFA                   22653 non-null  int32
#  26  entry_channel_Others                22653 non-null  int32
#  27  segment_Particulares                22653 non-null  int32
#  28  segment_Top                         22653 non-null  int32
#  29  segment_Universitario               22653 non-null  int32
# dtypes: float64(11), int32(17), int64(2)
# memory usage: 3.9 MB

# %%
df.head()
# Out:
#               age    salary  active_customer  entry_date_month  \
# cid
# 1517558  0.632618 -0.307488                1          1.307894
# 1161959 -0.558602 -0.109460                0          0.184376
# 1100492 -0.796846 -0.130175                0          1.027014
# 1391462  1.188520  0.044452                0         -0.939141
# 1391434  1.823838 -0.307488                1         -0.939141
#
#          Compra_debit_card  em_acount_consecutive_months  \
# cid
# 1517558                  1                     -0.710352
# 1161959                  0                      1.030839
# 1100492                  0                      1.030839
# 1391462                  1                     -1.026933
# 1391434                  1                     -1.026933
#
#          payroll_consecutive_months  payroll_account_consecutive_months  \
# cid
# 1517558                    -0.20414                           -0.262731
# 1161959                    -0.20414                           -0.262731
# 1100492                    -0.20414                           -0.262731
# 1391462                    -0.20414                           -0.262731
# 1391434                    -0.20414                            0.165599
#
#          emc_account_consecutive_months  has_account  has_pension_plan  \
# cid
# 1517558                       -0.209883            1                 0
# 1161959                       -0.209883            1                 0
# 1100492                       -0.209883            1                 0
# 1391462                       -0.209883            0                 0
# 1391434                       -0.209883            1                 0
#
#          num_accounts  meses_antigüedad  days_since_last_purchase  \
# cid
# 1517558      0.039488         -1.054340                 -1.007431
# 1161959      0.039488          0.878981                  1.484603
# 1100492      0.039488          1.500405                  1.484603
# 1391462     -1.731852         -0.501963                  0.153693
# 1391434      0.039488         -0.501963                 -0.344714
#
#          region_encoded  gender_H  entry_channel_KHE  entry_channel_KHM  \
# cid
# 1517558        1.939935         0                  0                  0
# 1161959       -0.181164         1                  0                  0
# 1100492        0.942360         1                  1                  0
# 1391462        0.901857         0                  0                  0
# 1391434       -0.920194         0                  0                  0
#
#          entry_channel_KHQ  entry_channel_KHN  entry_channel_KFC  \
# cid
# 1517558                  0                  1                  0
# 1161959                  0                  0                  0
# 1100492                  0                  0                  0
# 1391462                  0                  1                  0
# 1391434                  0                  0                  0
#
#          entry_channel_KAT  entry_channel_KHK  entry_channel_Unknown  \
# cid
# 1517558                  0                  0                      0
# 1161959                  1                  0                      0
# 1100492                  0                  0                      0
# 1391462                  0                  0                      0
# 1391434                  0                  1                      0
#
#          entry_channel_RED  entry_channel_KFA  entry_channel_Others  \
# cid
# 1517558                  0                  0                     0
# 1161959                  0                  0                     0
# 1100492                  0                  0                     0
# 1391462                  0                  0                     0
# 1391434                  0                  0                     0
#
#          segment_Particulares  segment_Top  segment_Universitario
# cid
# 1517558                     1            0                      0
# 1161959                     0            0                      1
# 1100492                     0            0                      1
# 1391462                     0            1                      0
# 1391434                     1            0                      0

# %%
clientes_junio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399734 entries, 657826 to 1550586
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 399734 non-null  float64
#  1   salary                              399734 non-null  float64
#  2   em_acount_consecutive_months        399734 non-null  float64
#  3   payroll_consecutive_months          399734 non-null  float64
#  4   payroll_account_consecutive_months  399734 non-null  float64
#  5   emc_account_consecutive_months      399734 non-null  float64
#  6   has_account                         399734 non-null  int64
#  7   has_pension_plan                    399734 non-null  int32
#  8   num_accounts                        399734 non-null  float64
#  9   active_customer                     399734 non-null  float64
#  10  meses_antigüedad                    399734 non-null  float64
#  11  days_since_last_purchase            399734 non-null  float64
#  12  entry_date_month                    399734 non-null  float64
#  13  region_encoded                      399734 non-null  float64
#  14  gender_H                            399734 non-null  int32
#  15  entry_channel_KAT                   399734 non-null  int32
#  16  entry_channel_KFA                   399734 non-null  int32
#  17  entry_channel_KFC                   399734 non-null  int32
#  18  entry_channel_KHE                   399734 non-null  int32
#  19  entry_channel_KHK                   399734 non-null  int32
#  20  entry_channel_KHM                   399734 non-null  int32
#  21  entry_channel_KHN                   399734 non-null  int32
#  22  entry_channel_KHQ                   399734 non-null  int32
#  23  entry_channel_Others                399734 non-null  int32
#  24  entry_channel_RED                   399734 non-null  int32
#  25  entry_channel_Unknown               399734 non-null  int32
#  26  segment_Particulares                399734 non-null  int32
#  27  segment_Top                         399734 non-null  int32
#  28  segment_Universitario               399734 non-null  int32
# dtypes: float64(12), int32(16), int64(1)
# memory usage: 67.1 MB

# %%
clientes_junio.head()
# Out:
#              age    salary  em_acount_consecutive_months  \
# pk_cid
# 657826  1.189784 -0.126656                      0.992378
# 657817  0.195291 -0.438003                     -1.251033
# 657905  4.587635  0.442201                      0.992378
# 657336  0.692537 -0.438003                     -0.987102
# 657147  2.681523  0.161232                     -1.251033
#
#         payroll_consecutive_months  payroll_account_consecutive_months  \
# pk_cid
# 657826                   -0.090326                           -0.146563
# 657817                   -0.090326                           -0.146563
# 657905                   -0.090326                           -0.146563
# 657336                   -0.090326                           -0.146563
# 657147                   -0.090326                           -0.146563
#
#         emc_account_consecutive_months  has_account  has_pension_plan  \
# pk_cid
# 657826                       -0.191497            1                 0
# 657817                       -0.191497            0                 0
# 657905                       -0.191497            1                 0
# 657336                       -0.191497            1                 0
# 657147                       -0.191497            0                 0
#
#         num_accounts  active_customer  meses_antigüedad  \
# pk_cid
# 657826      0.458189              1.0          1.692975
# 657817     -1.454284              0.0         -1.671511
# 657905      0.458189              1.0          0.221012
# 657336      0.458189              1.0         -1.531324
# 657147     -1.454284              0.0         -0.059361
#
#         days_since_last_purchase  entry_date_month  region_encoded  gender_H  \
# pk_cid
# 657826                  0.908987         -1.120762       -1.895918         1
# 657817                 -2.523732         -1.120762       -0.761834         0
# 657905                  0.908987         -2.179817        1.069337         1
# 657336                 -2.311398         -1.826799        1.069337         0
# 657147                 -0.372089         -0.767744        1.069337         1
#
#         entry_channel_KAT  entry_channel_KFA  entry_channel_KFC  \
# pk_cid
# 657826                  0                  0                  0
# 657817                  0                  0                  0
# 657905                  1                  0                  0
# 657336                  1                  0                  0
# 657147                  1                  0                  0
#
#         entry_channel_KHE  entry_channel_KHK  entry_channel_KHM  \
# pk_cid
# 657826                  0                  0                  0
# 657817                  0                  0                  0
# 657905                  0                  0                  0
# 657336                  0                  0                  0
# 657147                  0                  0                  0
#
#         entry_channel_KHN  entry_channel_KHQ  entry_channel_Others  \
# pk_cid
# 657826                  0                  0                     1
# 657817                  0                  0                     0
# 657905                  0                  0                     0
# 657336                  0                  0                     0
# 657147                  0                  0                     0
#
#         entry_channel_RED  entry_channel_Unknown  segment_Particulares  \
# pk_cid
# 657826                  0                      0                     1
# 657817                  0                      1                     0
# 657905                  0                      0                     0
# 657336                  0                      0                     1
# 657147                  0                      0                     1
#
#         segment_Top  segment_Universitario
# pk_cid
# 657826            0                      0
# 657817            0                      0
# 657905            1                      0
# 657336            0                      0
# 657147            0                      0

# %% [markdown]
# Por último, para no tener que correr todo el código en caso de modificaciones o errores en un futuro, procedemos a guardar el dataframe final como un pickle

# %%
#df.to_pickle('df_procesado_debit_card.pkl')

# %% [markdown]
# # MODELING

# %% [markdown]
# En este apartado vamos a preparar el dataset para aplicar distintos modelos que nos ayuden a resolver el problema de clasificación binaria al que nos enfrentamos. Para ello comenzaremos realizando la partición de datos en train, validation y test y finalmente implementaremos los modelos y evaluaremos su rendimiento para escoger el que mejor se adecúe a nuestro propósito.

# %% [markdown]
# Nos disponemos a crear una serie de funciones que nos ayuden a analizar cada uno de los modelos que usemos, su rendimiento y su eficacia a través de diferentes gráficas y métricas.

# %%
def grafica_perdidas(modelo,columna1,columna2,func_perdidas):
    """
    Genera una gráfica de las pérdidas (losses) de entrenamiento y validación a lo largo del entrenamiento del modelo.

    Parámetros:
    -----------
    modelo(object):El modelo ya entrenado que contiene los resultados de evaluación en el atributo 'evals_result_'.
    columna1(str): El nombre de la columna que contiene las pérdidas de entrenamiento.
    columna2(str): El nombre de la columna que contiene las pérdidas de validación.
    func_perdidas(str): La métrica de evaluación a graficar (por ejemplo, 'logloss').

    Retorna:
    --------
    Esta función no retorna ningún valor, solo muestra la gráfica de las pérdidas de entrenamiento y validación.

    """
    results = modelo.evals_result_

    # Graficar las pérdidas de entrenamiento y validación
    plt.figure(figsize=(8,5))
    plt.plot(results[columna1][func_perdidas], label="Training loss")
    plt.plot(results[columna2][func_perdidas], label="Validation loss")
    plt.xlabel("Number of trees")
    plt.ylabel("Logloss")
    plt.legend()
    plt.show()

# %%
def curva_roc_auc(Y_TEST,Y_PRED_PROBA,nombre_modelo):
    """
    Genera y muestra la curva ROC (Receiver Operating Characteristic) junto con el AUC (Area Under the Curve).

    Esta función calcula la curva ROC y el valor del AUC utilizando las etiquetas verdaderas y las probabilidades 
    predichas para la clase positiva. Luego, grafica la curva ROC para visualizar el rendimiento del modelo.

    Parámetros:
    -----------
    Y_TEST: dataframe -> Las etiquetas verdaderas del conjunto de prueba.
    Y_PRED_PROBA: dataframe -> Las probabilidades predichas de la clase positiva para el conjunto de prueba.

    Retorna:
    --------
    Esta función no retorna ningún valor, solo muestra la gráfica de la curva ROC con el AUC.

    """
    fpr, tpr, thresholds = metrics.roc_curve(Y_TEST, Y_PRED_PROBA)
    roc_auc = metrics.auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label=f'{nombre_modelo} ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc='lower right')
    plt.show()

# %%
def dataframe_resumen(Y_TEST,Y_TEST_PRED,Y_PRED_PROBA,product):
    """
    Crea un DataFrame que resume los resultados de las predicciones de compra de un producto, incluyendo el éxito de las predicciones y las probabilidades de compra.

    Esta función toma las etiquetas verdaderas, las predicciones y las probabilidades predichas, las combina en un solo DataFrame y calcula una columna de éxito, 
    que indica si la predicción fue correcta o no. También añade una columna con la probabilidad de compra del producto.

    Parámetros:
    -----------
    Y_TEST (DataFrame): DataFrame que contiene las etiquetas verdaderas de compra de los clientes.
    Y_TEST_PRED (DataFrame): DataFrame que contiene las predicciones del modelo (compra o no compra) para los clientes.
    Y_PRED_PROBA (DataFrame):DataFrame que contiene las probabilidades predichas de compra para el producto en cuestión.
    product (str): El nombre del producto para el cual se realizan las predicciones. Se utiliza para crear columnas específicas en el DataFrame de salida.

    Retorna:
    --------
    DataFrame: Un DataFrame que contiene las etiquetas verdaderas, las predicciones, una columna de éxito ('Success') y la probabilidad de compra para el producto dado.
    """
    results_df = Y_TEST.join(Y_TEST_PRED, how = 'inner')
    results_df['Success'] = (results_df['Compra_'+product] == results_df['Compra_predict']).astype(int)
    y_score = pd.DataFrame(Y_PRED_PROBA, index = Y_TEST.index, columns = ['Probabilidad_compra_'+product])
    results_df = results_df.join(y_score)
    return results_df

# %%
def resumen_metricas(modelo,Y_TEST,Y_TEST_PRED,X_TR,Y_TR,X_VAL,Y_VAL,X_TEST):
    """
    Muestra un resumen de las métricas de rendimiento del modelo, incluyendo la precisión y el informe de clasificación, 
    así como los scores en los conjuntos de entrenamiento, validación y prueba.

    Esta función calcula y muestra la precisión (accuracy) en el conjunto de prueba, imprime el informe de clasificación que incluye 
    precisión, recall y F1-score, y también muestra los scores del modelo en los conjuntos de entrenamiento, validación y prueba.

    Parámetros:
    -----------
    modelo (object):El modelo entrenado que se está evaluando, que debe implementar el método 'score()'.
    Y_TEST (DataFrame): DataFrame con las etiquetas verdaderas para el conjunto de prueba.
    Y_TEST_PRED (DataFrame): DataFrame con las predicciones realizadas por el modelo para el conjunto de prueba.
    X_TR (DataFrame): DataFrame con las características del conjunto de entrenamiento.
    Y_TR (DataFrame): DataFrame con las etiquetas verdaderas del conjunto de entrenamiento.
    X_VAL (DataFrame): DataFrame con las características del conjunto de validación.
    Y_VAL (DataFrame): DataFrame con las etiquetas verdaderas del conjunto de validación.
    X_TEST (DataFrame): DataFrame con las características del conjunto de prueba.

    Retorna:
    --------
    La función imprime las métricas de clasificación y los scores, pero no retorna ningún valor.
    """
    accuracy = metrics.accuracy_score(Y_TEST, Y_TEST_PRED)
    print(metrics.classification_report(Y_TEST, Y_TEST_PRED))

    print(f"Accuracy: {accuracy:.4f}",'\n')

    train_acc = modelo.score(X_TR, Y_TR)
    test_acc = modelo.score(X_TEST, Y_TEST)
    validation_acc = modelo.score(X_VAL,Y_VAL)

    print(f'El score en train es de: {train_acc}')
    print(f'El score en validation es de: {validation_acc}')
    print(f'El score en test es de: {test_acc}')

# %% [markdown]
# <a id='particionymuestreo'></a>
# ## Partición y muestreo del dataset
# [Volver al índice](#index)
#
# Sabemos que para entrenar un modelo debemos de dividir el dataset procesado en tres datasets diferentes:
#
# - **Train**: La muestra de datos utilizada para ajustar el modelo.
# - **Validation**: La muestra de datos utilizada para proporcionar una evaluación no sesgada del ajuste de un modelo en el conjunto de datos de entrenamiento mientras se ajustan los hiperparámetros del modelo. La evaluación se vuelve más sesgada a medida que la habilidad en el conjunto de datos de validación se incorpora a la configuración del modelo.
# - **Test**: La muestra de datos utilizada para proporcionar una evaluación imparcial del ajuste final de un modelo en el conjunto de datos de entrenamiento.

# %% [markdown]
# Nuestro objetivo es determinar como de propenso es un cliente a comprar cierto producto en el siguiente mes. Es por ello que vamos a crear los datasets de train, test y validación en base al tiempo. Nuestro dataset se comprende entre el 2019-01-01 y 2019-05-01. Por lo tanto entrenaremos el modelo con los datos de los tres primeros meses, validaremos el mismo con el cuarto mes y finalmente testearemos el rendimiento del mismo en el último mes del que poseemos información.

# %%
# comenzamos incorporando la columna pk_partition que nos permitirá dividir el dataframe en train, test y validation según los meses
df = df.reset_index()

incorporar_fechas = df_fechas[['cid','pk_partition']]
df_final = pd.merge(df,incorporar_fechas,on='cid',how='left')
df_final.set_index('cid', inplace=True)

df_final.head()
# Out:
#               age    salary  active_customer  entry_date_month  \
# cid
# 1517558  0.632618 -0.307488                1          1.307894
# 1161959 -0.558602 -0.109460                0          0.184376
# 1100492 -0.796846 -0.130175                0          1.027014
# 1391462  1.188520  0.044452                0         -0.939141
# 1391434  1.823838 -0.307488                1         -0.939141
#
#          Compra_debit_card  em_acount_consecutive_months  \
# cid
# 1517558                  1                     -0.710352
# 1161959                  0                      1.030839
# 1100492                  0                      1.030839
# 1391462                  1                     -1.026933
# 1391434                  1                     -1.026933
#
#          payroll_consecutive_months  payroll_account_consecutive_months  \
# cid
# 1517558                    -0.20414                           -0.262731
# 1161959                    -0.20414                           -0.262731
# 1100492                    -0.20414                           -0.262731
# 1391462                    -0.20414                           -0.262731
# 1391434                    -0.20414                            0.165599
#
#          emc_account_consecutive_months  has_account  has_pension_plan  \
# cid
# 1517558                       -0.209883            1                 0
# 1161959                       -0.209883            1                 0
# 1100492                       -0.209883            1                 0
# 1391462                       -0.209883            0                 0
# 1391434                       -0.209883            1                 0
#
#          num_accounts  meses_antigüedad  days_since_last_purchase  \
# cid
# 1517558      0.039488         -1.054340                 -1.007431
# 1161959      0.039488          0.878981                  1.484603
# 1100492      0.039488          1.500405                  1.484603
# 1391462     -1.731852         -0.501963                  0.153693
# 1391434      0.039488         -0.501963                 -0.344714
#
#          region_encoded  gender_H  entry_channel_KHE  entry_channel_KHM  \
# cid
# 1517558        1.939935         0                  0                  0
# 1161959       -0.181164         1                  0                  0
# 1100492        0.942360         1                  1                  0
# 1391462        0.901857         0                  0                  0
# 1391434       -0.920194         0                  0                  0
#
#          entry_channel_KHQ  entry_channel_KHN  entry_channel_KFC  \
# cid
# 1517558                  0                  1                  0
# 1161959                  0                  0                  0
# 1100492                  0                  0                  0
# 1391462                  0                  1                  0
# 1391434                  0                  0                  0
#
#          entry_channel_KAT  entry_channel_KHK  entry_channel_Unknown  \
# cid
# 1517558                  0                  0                      0
# 1161959                  1                  0                      0
# 1100492                  0                  0                      0
# 1391462                  0                  0                      0
# 1391434                  0                  1                      0
#
#          entry_channel_RED  entry_channel_KFA  entry_channel_Others  \
# cid
# 1517558                  0                  0                     0
# 1161959                  0                  0                     0
# 1100492                  0                  0                     0
# 1391462                  0                  0                     0
# 1391434                  0                  0                     0
#
#          segment_Particulares  segment_Top  segment_Universitario pk_partition
# cid
# 1517558                     1            0                      0   2019-01-01
# 1161959                     0            0                      1   2019-01-01
# 1100492                     0            0                      1   2019-01-01
# 1391462                     0            1                      0   2019-01-01
# 1391434                     1            0                      0   2019-01-01

# %%
print(f'Nuestro dataset va desde {df_final['pk_partition'].min()} hasta {df_final['pk_partition'].max()}')
# Out:
# Nuestro dataset va desde 2019-01-01 00:00:00 hasta 2019-05-01 00:00:00

# %%
def particion_dataset(dataframe,nombre,start_date,end_date):
    # train
    particion = dataframe[(dataframe['pk_partition']>=start_date)&(dataframe['pk_partition']<end_date)]
    print(f'Porcentaje de {nombre} sobre el dataset completo: {np.round((particion.shape[0]/dataframe.shape[0])*100,2)}%','\n')
    print(f'{nombre} va desde {particion['pk_partition'].min()} hasta {particion['pk_partition'].max()}','\n')

    #eliminamos la columna pk_partition y dividimos en columnas que son variables *X* y TARGET *y*
    particion = particion.drop(columns=['pk_partition'])

    X_particion = particion.drop(columns = [TARGET])
    y_particion = particion[[TARGET]]

    # nos aseguramos de que se han creado bien los datasets
    print('Tamaño de X_{nombre}: ', X_particion.shape)
    print('Tamaño de y_{nombre}: ', y_particion.shape)
    
    return X_particion,y_particion

# %%
X_train,y_train = particion_dataset(df_final,'train','2019-01-01','2019-04-01')
# Out:
# Porcentaje de train sobre el dataset completo: 60.87%
#
# train va desde 2019-01-01 00:00:00 hasta 2019-03-01 00:00:00
#
# Tamaño de X_{nombre}:  (13789, 29)
# Tamaño de y_{nombre}:  (13789, 1)

# %%
X_validation,y_validation = particion_dataset(df_final,'validation','2019-04-01','2019-05-01')
# Out:
# Porcentaje de validation sobre el dataset completo: 19.52%
#
# validation va desde 2019-04-01 00:00:00 hasta 2019-04-01 00:00:00
#
# Tamaño de X_{nombre}:  (4421, 29)
# Tamaño de y_{nombre}:  (4421, 1)

# %%
X_test,y_test = particion_dataset(df_final,'test','2019-05-01','2019-06-01')
# Out:
# Porcentaje de test sobre el dataset completo: 19.61%
#
# test va desde 2019-05-01 00:00:00 hasta 2019-05-01 00:00:00
#
# Tamaño de X_{nombre}:  (4443, 29)
# Tamaño de y_{nombre}:  (4443, 1)

# %% [markdown]
# <a id='XGB'></a>
# ## XGBoost
# [Volver al índice](#index)
#
# En este apartado utilizamos el modelo XGBClassifier, que se caracteriza por ser un algoritmo de boosting basado en árboles de decisión. Este modelo es particularmente eficiente en tareas de clasificación al combinar múltiples árboles débiles para mejorar la precisión de las predicciones. Se realiza un ajuste de hiperparámetros como el número de árboles, la profundidad máxima de los árboles y la tasa de aprendizaje, con el objetivo de optimizar su rendimiento. La evaluación del modelo se lleva a cabo observando métricas clave como el accuracy, la curva ROC-AUC, y la función de pérdidas (log loss), para asegurar que el modelo generalice adecuadamente en los datos de validación.

# %%
modelo_xgb = xgb.XGBClassifier(eval_metric='logloss',objective ="binary:logistic",seed = 44)

# %%
# Ajustar los parámetros para el Grid Search
params_xgb = {
    "learning_rate": [0.008,0.01, 0.03], 
    "max_depth": [3, 5, 7],          
    #"colsample_bytree": [0.8, 0.9, 1],   
    "n_estimators": [200,250,300]           
}

# Configurar Grid Search con Validación Cruzada
grid_search_xgb = model_selection.GridSearchCV(estimator=modelo_xgb, 
                                           param_grid=params_xgb, 
                                           cv=5, scoring='accuracy', 
                                           n_jobs=-1, verbose=1)

# Entrenar usando Grid Search
grid_search_xgb.fit(X_train, y_train)

# Mejor combinación de parámetros
print("Best parameters found: ", grid_search_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 4 fits failed out of a total of 135.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1512, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 596, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1003, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1573, in __init__
#     self._init(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1632, in _init
#     it.reraise()
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 569, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#     ^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 550, in _handle_exception
#     return fn()
#            ^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 637, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#                                           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1416, in next
#     input_data(**self.kwargs)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 626, in input_data
#     self.proxy.set_info(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 954, in set_info
#     self.set_label(label)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1092, in set_label
#     dispatch_meta_backend(self, label, "label", "float")
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1359, in dispatch_meta_backend
#     _meta_from_pandas_df(data, name, dtype=dtype, handle=handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 628, in _meta_from_pandas_df
#     _meta_from_numpy(array, name, dtype, handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1295, in _meta_from_numpy
#     _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [23:04:10] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\data\array_interface.cu:44: Check failed: err == cudaGetLastError() (0 vs. 46) :
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1512, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 596, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1003, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1573, in __init__
#     self._init(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1632, in _init
#     it.reraise()
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 569, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#     ^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 550, in _handle_exception
#     return fn()
#            ^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 637, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#                                           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1416, in next
#     input_data(**self.kwargs)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 626, in input_data
#     self.proxy.set_info(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 954, in set_info
#     self.set_label(label)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1092, in set_label
#     dispatch_meta_backend(self, label, "label", "float")
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1359, in dispatch_meta_backend
#     _meta_from_pandas_df(data, name, dtype=dtype, handle=handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 628, in _meta_from_pandas_df
#     _meta_from_numpy(array, name, dtype, handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1295, in _meta_from_numpy
#     _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [23:04:05] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\data\array_interface.cu:44: Check failed: err == cudaGetLastError() (0 vs. 46) :
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1512, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 596, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#                     ^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\sklearn.py", line 1003, in _create_dmatrix
#     return QuantileDMatrix(
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1573, in __init__
#     self._init(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1632, in _init
#     it.reraise()
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 569, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#     ^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 550, in _handle_exception
#     return fn()
#            ^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 637, in <lambda>
#     return self._handle_exception(lambda: self.next(input_data), 0)
#                                           ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1416, in next
#     input_data(**self.kwargs)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 626, in input_data
#     self.proxy.set_info(
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 726, in inner_f
#     return func(**kwargs)
#            ^^^^^^^^^^^^^^
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 954, in set_info
#     self.set_label(label)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 1092, in set_label
#     dispatch_meta_backend(self, label, "label", "float")
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1359, in dispatch_meta_backend
#     _meta_from_pandas_df(data, name, dtype=dtype, handle=handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 628, in _meta_from_pandas_df
#     _meta_from_numpy(array, name, dtype, handle)
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\data.py", line 1295, in _meta_from_numpy
#     _check_call(_LIB.XGDMatrixSetInfoFromInterface(handle, c_str(field), interface_str))
#   File "c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [23:04:07] C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\data\array_interface.cu:44: Check failed: err == cudaGetLastError() (0 vs. 46) :
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.95365936 0.94959685 0.94930681 0.95177347
#  0.94452065 0.94640623 0.94742159 0.95286161 0.9538044  0.95467462
#  0.94930681 0.95242622 0.95271631 0.94676879 0.94727651 0.94792921
#  0.9531518  0.94909081 0.94749543 0.94843735 0.94336118 0.94162076
#  0.94220052 0.93900978 0.93806707]
#   warnings.warn(
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300}

# %%
print("Mejor score: ",grid_search_xgb.best_score_)
# Out:
# Mejor score:  0.9546746195260637

# %%
model_XGBoost = grid_search_xgb.best_estimator_

# %%
model_XGBoost.fit(
    X_train, 
    y_train, 
    eval_set = [(X_train, y_train), (X_validation, y_validation)],
    verbose = False
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
# Importancia de las variables
xgb.plot_importance(model_XGBoost, max_num_features=10)
plt.show()

# %%
grafica_perdidas(model_XGBoost,"validation_0","validation_1","logloss")

# %%
# obtenemos las probabilidades y las predicciones de compra a partir del mejor modelo tras el grid search cross validation

y_test_pred_xgb = pd.DataFrame(model_XGBoost.predict(X_test), index = y_test.index, columns = ['Compra_predict'])
y_pred_proba_xgb = model_XGBoost.predict_proba(X_test)[:,1]

# %%
curva_roc_auc(y_test,y_pred_proba_xgb,'XGBoost')

# %%
resumen_xgb = dataframe_resumen(y_test,y_test_pred_xgb,y_pred_proba_xgb,producto)
resumen_xgb
# Out:
#          Compra_debit_card  Compra_predict  Success  \
# cid
# 1451798                  1               1        1
# 1104047                  1               1        1
# 1443548                  1               1        1
# 1443226                  1               1        1
# 866793                   1               1        1
# ...                    ...             ...      ...
# 1540186                  1               1        1
# 1540192                  1               1        1
# 1540238                  1               1        1
# 1553394                  0               0        1
# 1546388                  1               1        1
#
#          Probabilidad_compra_debit_card
# cid
# 1451798                        0.941695
# 1104047                        0.941695
# 1443548                        0.941695
# 1443226                        0.941695
# 866793                         0.954118
# ...                                 ...
# 1540186                        0.940303
# 1540192                        0.940303
# 1540238                        0.940303
# 1553394                        0.247502
# 1546388                        0.941695
#
# [4443 rows x 4 columns]

# %%
resumen_metricas(model_XGBoost,y_test,y_test_pred_xgb,X_train,y_train,X_validation,y_validation,X_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      2394
#            1       0.91      0.96      0.93      2049
#
#     accuracy                           0.94      4443
#    macro avg       0.94      0.94      0.94      4443
# weighted avg       0.94      0.94      0.94      4443
#
# Accuracy: 0.9372
#
# El score en train es de: 0.9571397490753499
# El score en validation es de: 0.9466184121239538
# El score en test es de: 0.937204591492235

# %% [markdown]
# <a id='LightGBM'></a>
# ## LightGBM
# [Volver al índice](#index)
#
# En este apartado utilizamos el modelo LightGBM, que se caracteriza por ser un algoritmo de boosting basado en gradientes, diseñado para entrenar de manera rápida y eficiente, incluso en datasets grandes. Su ventaja radica en la forma en que divide los datos, lo que acelera el proceso de entrenamiento sin perder precisión. Se ajustan hiperparámetros como el número de iteraciones, la tasa de aprendizaje, el número de hojas y la profundidad para mejorar su rendimiento. El modelo es evaluado a través de métricas como el accuracy, la curva ROC-AUC, y la gráfica de pérdidas, asegurando así un equilibrio entre la precisión y la eficiencia del modelo.

# %%
modelo_lgb = lgb.LGBMClassifier(objective="binary", random_state=44)

# %%
# Ajustar los parámetros para el Grid Search
params_lgb = {
    "num_leaves": [20, 31, 40],
    "max_depth": [5, 7, 10],
    "learning_rate": [0.01, 0.03, 0.1],
    "n_estimators": [100, 200, 300],
}

# Configurar Grid Search con Validación Cruzada
grid_search_lgb = model_selection.GridSearchCV(estimator=modelo_lgb, 
                                           param_grid=params_lgb, 
                                           cv=5, scoring='accuracy', 
                                           n_jobs=-1, verbose=1)

# Entrenar usando Grid Search
grid_search_lgb.fit(X_train, y_train)

# Mejor combinación de parámetros
print("Best parameters found: ", grid_search_lgb.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 7287, number of negative: 6502
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000576 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 588
# [LightGBM] [Info] Number of data points in the train set: 13789, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528465 -> initscore=0.113982
# [LightGBM] [Info] Start training from score 0.113982
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 300, 'num_leaves': 20}

# %%
model_LGB = grid_search_lgb.best_estimator_

# %%
model_LGB.fit(
    X_train, 
    y_train, 
    eval_set = [(X_train, y_train), (X_validation, y_validation)]
)
# Out:
# [LightGBM] [Info] Number of positive: 7287, number of negative: 6502
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 588
# [LightGBM] [Info] Number of data points in the train set: 13789, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.528465 -> initscore=0.113982
# [LightGBM] [Info] Start training from score 0.113982
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# LGBMClassifier(learning_rate=0.01, max_depth=10, n_estimators=300,
#                num_leaves=20, objective='binary', random_state=44)

# %%
# Importancia de las variables
lgb.plot_importance(model_LGB, max_num_features=10)
plt.title("Importancia de las características")
plt.show()

# %%
grafica_perdidas(model_LGB,'training','valid_1','binary_logloss')

# %%
# obtenemos las probabilidades y las predicciones de compra a partir del mejor modelo tras el grid search cross validation

y_test_pred_lgb = pd.DataFrame(model_LGB.predict(X_test), index = y_test.index, columns = ['Compra_predict'])
y_pred_proba_lgb = model_LGB.predict_proba(X_test)[:,1]

# %%
curva_roc_auc(y_test,y_pred_proba_lgb,'LightGBM')

# %%
resumen_lgb = dataframe_resumen(y_test,y_test_pred_lgb,y_pred_proba_lgb,producto)
resumen_lgb
# Out:
#          Compra_debit_card  Compra_predict  Success  \
# cid
# 1451798                  1               1        1
# 1104047                  1               1        1
# 1443548                  1               1        1
# 1443226                  1               1        1
# 866793                   1               1        1
# ...                    ...             ...      ...
# 1540186                  1               1        1
# 1540192                  1               1        1
# 1540238                  1               1        1
# 1553394                  0               0        1
# 1546388                  1               1        1
#
#          Probabilidad_compra_debit_card
# cid
# 1451798                        0.892547
# 1104047                        0.889163
# 1443548                        0.888983
# 1443226                        0.918111
# 866793                         0.914777
# ...                                 ...
# 1540186                        0.945102
# 1540192                        0.945102
# 1540238                        0.945102
# 1553394                        0.209990
# 1546388                        0.944253
#
# [4443 rows x 4 columns]

# %%
resumen_metricas(model_LGB,y_test,y_test_pred_lgb,X_train,y_train,X_validation,y_validation,X_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      2394
#            1       0.91      0.96      0.93      2049
#
#     accuracy                           0.94      4443
#    macro avg       0.94      0.94      0.94      4443
# weighted avg       0.94      0.94      0.94      4443
#
# Accuracy: 0.9379
#
# El score en train es de: 0.9586627021538908
# El score en validation es de: 0.9459398326170549
# El score en test es de: 0.937879810938555

# %% [markdown]
# <a id='CatBoost'></a>
# ## CatBoost
# [Volver al índice](#index)
#
# En este apartado utilizamos el modelo CatBoost, que se caracteriza por ser especialmente adecuado para trabajar con variables categóricas, lo que lo convierte en una excelente opción cuando se trabaja con este tipo de datos sin necesidad de preprocesamiento intensivo. Es por ello que realizamos un muestreo diferente al resto de modelos.
#
# Los hiperparámetros ajustados incluyen tasa de aprendizaje, la profundidad y early_stopping_rounds que son claves para lograr un buen rendimiento. La evaluación se realiza observando el accuracy, la curva ROC-AUC y la función de pérdidas, asegurando que el modelo no solo sea preciso, sino también eficiente en términos de manejo de datos categóricos.

# %%
df_cat_procesado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22653 entries, 1517558 to 1546388
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   gender                              22653 non-null  object
#  1   age                                 22653 non-null  float64
#  2   salary                              22653 non-null  float64
#  3   entry_channel                       22653 non-null  category
#  4   active_customer                     22653 non-null  int32
#  5   segment                             22653 non-null  object
#  6   entry_date_month                    22653 non-null  float64
#  7   Compra_debit_card                   22653 non-null  int64
#  8   em_acount_consecutive_months        22653 non-null  float64
#  9   payroll_consecutive_months          22653 non-null  float64
#  10  payroll_account_consecutive_months  22653 non-null  float64
#  11  emc_account_consecutive_months      22653 non-null  float64
#  12  has_account                         22653 non-null  int64
#  13  has_pension_plan                    22653 non-null  int32
#  14  num_accounts                        22653 non-null  float64
#  15  meses_antigüedad                    22653 non-null  float64
#  16  days_since_last_purchase            22653 non-null  float64
#  17  region_encoded                      22653 non-null  float64
# dtypes: category(1), float64(11), int32(2), int64(2), object(2)
# memory usage: 3.0+ MB

# %%
# comenzamos incorporando la columna pk_partition que nos permitirá dividir el dataframe en train, test y validation según los meses
df_cat_procesado = df_cat_procesado.reset_index()

incorporar_fechas = df_fechas[['cid','pk_partition']]
df_final1 = pd.merge(df_cat_procesado,incorporar_fechas,on='cid',how='left')
df_final1[categoricas] = df_final1[categoricas].astype('category')

df_final1.set_index('cid', inplace=True)

df_final1.head()
# Out:
#         gender       age    salary entry_channel  active_customer  \
# cid
# 1517558      V  0.632618 -0.307488           KHN                1
# 1161959      H -0.558602 -0.109460           KAT                0
# 1100492      H -0.796846 -0.130175           KHE                0
# 1391462      V  1.188520  0.044452           KHN                0
# 1391434      V  1.823838 -0.307488           KHK                1
#
#                segment  entry_date_month  Compra_debit_card  \
# cid
# 1517558   Particulares          1.307894                  1
# 1161959  Universitario          0.184376                  0
# 1100492  Universitario          1.027014                  0
# 1391462            Top         -0.939141                  1
# 1391434   Particulares         -0.939141                  1
#
#          em_acount_consecutive_months  payroll_consecutive_months  \
# cid
# 1517558                     -0.710352                    -0.20414
# 1161959                      1.030839                    -0.20414
# 1100492                      1.030839                    -0.20414
# 1391462                     -1.026933                    -0.20414
# 1391434                     -1.026933                    -0.20414
#
#          payroll_account_consecutive_months  emc_account_consecutive_months  \
# cid
# 1517558                           -0.262731                       -0.209883
# 1161959                           -0.262731                       -0.209883
# 1100492                           -0.262731                       -0.209883
# 1391462                           -0.262731                       -0.209883
# 1391434                            0.165599                       -0.209883
#
#          has_account  has_pension_plan  num_accounts  meses_antigüedad  \
# cid
# 1517558            1                 0      0.039488         -1.054340
# 1161959            1                 0      0.039488          0.878981
# 1100492            1                 0      0.039488          1.500405
# 1391462            0                 0     -1.731852         -0.501963
# 1391434            1                 0      0.039488         -0.501963
#
#          days_since_last_purchase  region_encoded pk_partition
# cid
# 1517558                 -1.007431        1.939935   2019-01-01
# 1161959                  1.484603       -0.181164   2019-01-01
# 1100492                  1.484603        0.942360   2019-01-01
# 1391462                  0.153693        0.901857   2019-01-01
# 1391434                 -0.344714       -0.920194   2019-01-01

# %%
X_train1,y_train1= particion_dataset(df_final1,'train','2019-01-01','2019-04-01')
# Out:
# Porcentaje de train sobre el dataset completo: 60.87%
#
# train va desde 2019-01-01 00:00:00 hasta 2019-03-01 00:00:00
#
# Tamaño de X_{nombre}:  (13789, 17)
# Tamaño de y_{nombre}:  (13789, 1)

# %%
X_validation1,y_validation1 = particion_dataset(df_final1,'validation','2019-04-01','2019-05-01')
# Out:
# Porcentaje de validation sobre el dataset completo: 19.52%
#
# validation va desde 2019-04-01 00:00:00 hasta 2019-04-01 00:00:00
#
# Tamaño de X_{nombre}:  (4421, 17)
# Tamaño de y_{nombre}:  (4421, 1)

# %%
X_test1,y_test1 = particion_dataset(df_final1,'test','2019-05-01','2019-06-01')
# Out:
# Porcentaje de test sobre el dataset completo: 19.61%
#
# test va desde 2019-05-01 00:00:00 hasta 2019-05-01 00:00:00
#
# Tamaño de X_{nombre}:  (4443, 17)
# Tamaño de y_{nombre}:  (4443, 1)

# %%
model_cat = cat.CatBoostClassifier(
    iterations=500,
    random_seed=44,
    loss_function='Logloss',
    cat_features=['gender', 'segment', 'entry_channel', 'tipo_cliente']
)

# %%
# Ajustar los parámetros para el Grid Search
#params_cat = {
#    "learning_rate": [0.005,0.01, 0.1],
#    "depth": [5, 6, 7],
#    "early_stopping_rounds": [20, 50, 70]
#}

# Configurar Grid Search con Validación Cruzada
#grid_search_cat = model_selection.GridSearchCV(estimator=model_cat, 
#                                           param_grid=params_cat, 
#                                           cv=5, scoring='accuracy', 
#                                           n_jobs=-1, verbose=1)

# Entrenar usando Grid Search
#grid_search_cat.fit(X_train1, y_train1)

# Mejor combinación de parámetros
#print("Best parameters found: ", grid_search_cat.best_params_)
#print("Best score found: ", grid_search_cat.best_score_)

# %%
#model_cat = grid_search_cat.best_estimator_

# %%
model_cat = cat.CatBoostClassifier(
    iterations=500,
    random_seed=44,
    loss_function='Logloss',
    cat_features=['gender', 'segment', 'entry_channel'],
    depth = 6,
    early_stopping_rounds = 20,
    learning_rate = 0.005 #0.01
)

# %%
model_cat.fit(
          X_train1,
          y_train1, 
          eval_set=[(X_train1, y_train1), (X_validation1, y_validation1)], 
          use_best_model=True,
          plot=True
)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.6843928	test: 0.6843928	test1: 0.6845934	best: 0.6845934 (0)	total: 424ms	remaining: 3m 31s
# 1:	learn: 0.6769520	test: 0.6769520	test1: 0.6773637	best: 0.6773637 (1)	total: 498ms	remaining: 2m 4s
# 2:	learn: 0.6687690	test: 0.6687690	test1: 0.6694623	best: 0.6694623 (2)	total: 543ms	remaining: 1m 29s
# 3:	learn: 0.6620741	test: 0.6620741	test1: 0.6630316	best: 0.6630316 (3)	total: 586ms	remaining: 1m 12s
# 4:	learn: 0.6537294	test: 0.6537294	test1: 0.6550264	best: 0.6550264 (4)	total: 632ms	remaining: 1m 2s
# 5:	learn: 0.6459263	test: 0.6459263	test1: 0.6476372	best: 0.6476372 (5)	total: 697ms	remaining: 57.4s
# 6:	learn: 0.6389957	test: 0.6389957	test1: 0.6409430	best: 0.6409430 (6)	total: 741ms	remaining: 52.2s
# 7:	learn: 0.6322120	test: 0.6322120	test1: 0.6343291	best: 0.6343291 (7)	total: 788ms	remaining: 48.4s
# 8:	learn: 0.6245189	test: 0.6245228	test1: 0.6268510	best: 0.6268510 (8)	total: 844ms	remaining: 46s
# 9:	learn: 0.6170957	test: 0.6170986	test1: 0.6199689	best: 0.6199689 (9)	total: 893ms	remaining: 43.8s
# 10:	learn: 0.6100461	test: 0.6100489	test1: 0.6130587	best: 0.6130587 (10)	total: 940ms	remaining: 41.8s
# 11:	learn: 0.6026901	test: 0.6024411	test1: 0.6057097	best: 0.6057097 (11)	total: 987ms	remaining: 40.1s
# 12:	learn: 0.5955355	test: 0.5952682	test1: 0.5987477	best: 0.5987477 (12)	total: 1.04s	remaining: 38.9s
# 13:	learn: 0.5879842	test: 0.5877171	test1: 0.5914613	best: 0.5914613 (13)	total: 1.08s	remaining: 37.7s
# 14:	learn: 0.5826932	test: 0.5824281	test1: 0.5864210	best: 0.5864210 (14)	total: 1.11s	remaining: 36s
# 15:	learn: 0.5763777	test: 0.5761163	test1: 0.5803429	best: 0.5803429 (15)	total: 1.16s	remaining: 35s
# 16:	learn: 0.5704530	test: 0.5701938	test1: 0.5745468	best: 0.5745468 (16)	total: 1.23s	remaining: 35.1s
# 17:	learn: 0.5644306	test: 0.5641632	test1: 0.5687595	best: 0.5687595 (17)	total: 1.27s	remaining: 34.2s
# 18:	learn: 0.5572699	test: 0.5570065	test1: 0.5617718	best: 0.5617718 (18)	total: 1.4s	remaining: 35.3s
# 19:	learn: 0.5512522	test: 0.5509912	test1: 0.5561467	best: 0.5561467 (19)	total: 1.44s	remaining: 34.6s
# 20:	learn: 0.5452392	test: 0.5449806	test1: 0.5502275	best: 0.5502275 (20)	total: 1.48s	remaining: 33.8s
# 21:	learn: 0.5391751	test: 0.5389189	test1: 0.5443279	best: 0.5443279 (21)	total: 1.52s	remaining: 33.1s
# 22:	learn: 0.5339639	test: 0.5337098	test1: 0.5392891	best: 0.5392891 (22)	total: 1.56s	remaining: 32.4s
# 23:	learn: 0.5275175	test: 0.5272685	test1: 0.5330742	best: 0.5330742 (23)	total: 1.6s	remaining: 31.7s
# 24:	learn: 0.5223097	test: 0.5220628	test1: 0.5288957	best: 0.5288957 (24)	total: 1.64s	remaining: 31.2s
# 25:	learn: 0.5171638	test: 0.5169190	test1: 0.5240194	best: 0.5240194 (25)	total: 1.67s	remaining: 30.5s
# 26:	learn: 0.5113816	test: 0.5111393	test1: 0.5185966	best: 0.5185966 (26)	total: 1.71s	remaining: 30s
# 27:	learn: 0.5063525	test: 0.5061123	test1: 0.5136989	best: 0.5136989 (27)	total: 1.75s	remaining: 29.5s
# 28:	learn: 0.5003427	test: 0.5001014	test1: 0.5078325	best: 0.5078325 (28)	total: 1.79s	remaining: 29.1s
# 29:	learn: 0.4953906	test: 0.4951515	test1: 0.5030253	best: 0.5030253 (29)	total: 1.83s	remaining: 28.7s
# 30:	learn: 0.4906558	test: 0.4904187	test1: 0.4984701	best: 0.4984701 (30)	total: 1.87s	remaining: 28.4s
# 31:	learn: 0.4855791	test: 0.4853441	test1: 0.4935176	best: 0.4935176 (31)	total: 1.92s	remaining: 28s
# 32:	learn: 0.4811744	test: 0.4809413	test1: 0.4892149	best: 0.4892149 (32)	total: 1.96s	remaining: 27.7s
# 33:	learn: 0.4757447	test: 0.4754933	test1: 0.4838674	best: 0.4838674 (33)	total: 2s	remaining: 27.4s
# 34:	learn: 0.4706983	test: 0.4704443	test1: 0.4790086	best: 0.4790086 (34)	total: 2.1s	remaining: 27.9s
# 35:	learn: 0.4663114	test: 0.4660603	test1: 0.4748061	best: 0.4748061 (35)	total: 2.18s	remaining: 28s
# 36:	learn: 0.4621157	test: 0.4618667	test1: 0.4707741	best: 0.4707741 (36)	total: 2.23s	remaining: 27.9s
# 37:	learn: 0.4571187	test: 0.4568562	test1: 0.4658995	best: 0.4658995 (37)	total: 2.27s	remaining: 27.6s
# 38:	learn: 0.4528534	test: 0.4525933	test1: 0.4617384	best: 0.4617384 (38)	total: 2.31s	remaining: 27.4s
# 39:	learn: 0.4475999	test: 0.4473412	test1: 0.4566008	best: 0.4566008 (39)	total: 2.36s	remaining: 27.1s
# 40:	learn: 0.4435188	test: 0.4432622	test1: 0.4526763	best: 0.4526763 (40)	total: 2.4s	remaining: 26.9s
# 41:	learn: 0.4393913	test: 0.4391370	test1: 0.4488437	best: 0.4488437 (41)	total: 2.44s	remaining: 26.6s
# 42:	learn: 0.4360565	test: 0.4358020	test1: 0.4457384	best: 0.4457384 (42)	total: 2.47s	remaining: 26.3s
# 43:	learn: 0.4319706	test: 0.4317184	test1: 0.4417211	best: 0.4417211 (43)	total: 2.51s	remaining: 26s
# 44:	learn: 0.4279455	test: 0.4276954	test1: 0.4378101	best: 0.4378101 (44)	total: 2.56s	remaining: 25.9s
# 45:	learn: 0.4242065	test: 0.4239586	test1: 0.4341491	best: 0.4341491 (45)	total: 2.59s	remaining: 25.6s
# 46:	learn: 0.4196616	test: 0.4194163	test1: 0.4298079	best: 0.4298079 (46)	total: 2.64s	remaining: 25.4s
# 47:	learn: 0.4157854	test: 0.4155422	test1: 0.4261707	best: 0.4261707 (47)	total: 2.69s	remaining: 25.4s
# 48:	learn: 0.4112018	test: 0.4109574	test1: 0.4216795	best: 0.4216795 (48)	total: 2.75s	remaining: 25.3s
# 49:	learn: 0.4070905	test: 0.4068471	test1: 0.4177391	best: 0.4177391 (49)	total: 2.79s	remaining: 25.2s
# 50:	learn: 0.4035634	test: 0.4033220	test1: 0.4143651	best: 0.4143651 (50)	total: 2.84s	remaining: 25s
# 51:	learn: 0.4002190	test: 0.3999797	test1: 0.4113817	best: 0.4113817 (51)	total: 2.88s	remaining: 24.8s
# 52:	learn: 0.3964487	test: 0.3962117	test1: 0.4078172	best: 0.4078172 (52)	total: 2.92s	remaining: 24.7s
# 53:	learn: 0.3927607	test: 0.3925259	test1: 0.4041762	best: 0.4041762 (53)	total: 2.97s	remaining: 24.5s
# 54:	learn: 0.3890822	test: 0.3888463	test1: 0.4004709	best: 0.4004709 (54)	total: 3.01s	remaining: 24.4s
# 55:	learn: 0.3853593	test: 0.3851240	test1: 0.3970147	best: 0.3970147 (55)	total: 3.05s	remaining: 24.2s
# 56:	learn: 0.3820840	test: 0.3818507	test1: 0.3939880	best: 0.3939880 (56)	total: 3.1s	remaining: 24.1s
# 57:	learn: 0.3784539	test: 0.3782206	test1: 0.3904834	best: 0.3904834 (57)	total: 3.14s	remaining: 23.9s
# 58:	learn: 0.3753316	test: 0.3751003	test1: 0.3876035	best: 0.3876035 (58)	total: 3.18s	remaining: 23.7s
# 59:	learn: 0.3722643	test: 0.3720350	test1: 0.3848208	best: 0.3848208 (59)	total: 3.21s	remaining: 23.6s
# 60:	learn: 0.3688769	test: 0.3685147	test1: 0.3814807	best: 0.3814807 (60)	total: 3.25s	remaining: 23.4s
# 61:	learn: 0.3660205	test: 0.3656612	test1: 0.3787492	best: 0.3787492 (61)	total: 3.29s	remaining: 23.3s
# 62:	learn: 0.3630234	test: 0.3626679	test1: 0.3758365	best: 0.3758365 (62)	total: 3.33s	remaining: 23.1s
# 63:	learn: 0.3599617	test: 0.3596100	test1: 0.3728991	best: 0.3728991 (63)	total: 3.37s	remaining: 23s
# 64:	learn: 0.3567082	test: 0.3563602	test1: 0.3697414	best: 0.3697414 (64)	total: 3.42s	remaining: 22.9s
# 65:	learn: 0.3537157	test: 0.3533715	test1: 0.3669051	best: 0.3669051 (65)	total: 3.45s	remaining: 22.7s
# 66:	learn: 0.3509850	test: 0.3506448	test1: 0.3643382	best: 0.3643382 (66)	total: 3.5s	remaining: 22.6s
# 67:	learn: 0.3482073	test: 0.3478706	test1: 0.3616299	best: 0.3616299 (67)	total: 3.53s	remaining: 22.5s
# 68:	learn: 0.3452862	test: 0.3449531	test1: 0.3588816	best: 0.3588816 (68)	total: 3.57s	remaining: 22.3s
# 69:	learn: 0.3423688	test: 0.3420392	test1: 0.3560416	best: 0.3560416 (69)	total: 3.61s	remaining: 22.2s
# 70:	learn: 0.3396444	test: 0.3393183	test1: 0.3533845	best: 0.3533845 (70)	total: 3.65s	remaining: 22.1s
# 71:	learn: 0.3364961	test: 0.3361739	test1: 0.3502594	best: 0.3502594 (71)	total: 3.69s	remaining: 21.9s
# 72:	learn: 0.3348156	test: 0.3344952	test1: 0.3487029	best: 0.3487029 (72)	total: 3.71s	remaining: 21.7s
# 73:	learn: 0.3321834	test: 0.3318595	test1: 0.3462122	best: 0.3462122 (73)	total: 3.75s	remaining: 21.6s
# 74:	learn: 0.3291872	test: 0.3288629	test1: 0.3434111	best: 0.3434111 (74)	total: 3.79s	remaining: 21.5s
# 75:	learn: 0.3259987	test: 0.3256743	test1: 0.3403065	best: 0.3403065 (75)	total: 3.83s	remaining: 21.4s
# 76:	learn: 0.3236475	test: 0.3233264	test1: 0.3380702	best: 0.3380702 (76)	total: 3.87s	remaining: 21.3s
# 77:	learn: 0.3219906	test: 0.3216715	test1: 0.3365482	best: 0.3365482 (77)	total: 3.89s	remaining: 21s
# 78:	learn: 0.3191099	test: 0.3187946	test1: 0.3336568	best: 0.3336568 (78)	total: 3.93s	remaining: 20.9s
# 79:	learn: 0.3172894	test: 0.3169764	test1: 0.3319424	best: 0.3319424 (79)	total: 3.95s	remaining: 20.8s
# 80:	learn: 0.3149301	test: 0.3146204	test1: 0.3296891	best: 0.3296891 (80)	total: 3.99s	remaining: 20.7s
# 81:	learn: 0.3125929	test: 0.3122866	test1: 0.3275791	best: 0.3275791 (81)	total: 4.03s	remaining: 20.5s
# 82:	learn: 0.3098619	test: 0.3095591	test1: 0.3248844	best: 0.3248844 (82)	total: 4.08s	remaining: 20.5s
# 83:	learn: 0.3074008	test: 0.3069930	test1: 0.3224394	best: 0.3224394 (83)	total: 4.12s	remaining: 20.4s
# 84:	learn: 0.3046258	test: 0.3042244	test1: 0.3197700	best: 0.3197700 (84)	total: 4.16s	remaining: 20.3s
# 85:	learn: 0.3024163	test: 0.3020193	test1: 0.3177049	best: 0.3177049 (85)	total: 4.21s	remaining: 20.2s
# 86:	learn: 0.3002301	test: 0.2998368	test1: 0.3156092	best: 0.3156092 (86)	total: 4.25s	remaining: 20.2s
# 87:	learn: 0.2979842	test: 0.2975089	test1: 0.3134462	best: 0.3134462 (87)	total: 4.29s	remaining: 20.1s
# 88:	learn: 0.2957264	test: 0.2952129	test1: 0.3112588	best: 0.3112588 (88)	total: 4.34s	remaining: 20s
# 89:	learn: 0.2936519	test: 0.2931440	test1: 0.3093038	best: 0.3093038 (89)	total: 4.4s	remaining: 20s
# 90:	learn: 0.2920600	test: 0.2915559	test1: 0.3078094	best: 0.3078094 (90)	total: 4.43s	remaining: 19.9s
# 91:	learn: 0.2900078	test: 0.2895093	test1: 0.3059025	best: 0.3059025 (91)	total: 4.47s	remaining: 19.8s
# 92:	learn: 0.2880245	test: 0.2875314	test1: 0.3039746	best: 0.3039746 (92)	total: 4.52s	remaining: 19.8s
# 93:	learn: 0.2858893	test: 0.2853969	test1: 0.3019798	best: 0.3019798 (93)	total: 4.56s	remaining: 19.7s
# 94:	learn: 0.2839041	test: 0.2834164	test1: 0.3000794	best: 0.3000794 (94)	total: 4.61s	remaining: 19.6s
# 95:	learn: 0.2818022	test: 0.2813173	test1: 0.2981102	best: 0.2981102 (95)	total: 4.65s	remaining: 19.6s
# 96:	learn: 0.2804026	test: 0.2799220	test1: 0.2968311	best: 0.2968311 (96)	total: 4.67s	remaining: 19.4s
# 97:	learn: 0.2783453	test: 0.2778702	test1: 0.2948601	best: 0.2948601 (97)	total: 4.71s	remaining: 19.3s
# 98:	learn: 0.2763027	test: 0.2758331	test1: 0.2929030	best: 0.2929030 (98)	total: 4.75s	remaining: 19.3s
# 99:	learn: 0.2744928	test: 0.2739719	test1: 0.2911408	best: 0.2911408 (99)	total: 4.79s	remaining: 19.2s
# 100:	learn: 0.2724989	test: 0.2719840	test1: 0.2892385	best: 0.2892385 (100)	total: 4.84s	remaining: 19.1s
# 101:	learn: 0.2704909	test: 0.2699818	test1: 0.2873115	best: 0.2873115 (101)	total: 4.88s	remaining: 19s
# 102:	learn: 0.2687574	test: 0.2682538	test1: 0.2857040	best: 0.2857040 (102)	total: 4.92s	remaining: 19s
# 103:	learn: 0.2675080	test: 0.2670087	test1: 0.2845717	best: 0.2845717 (103)	total: 4.94s	remaining: 18.8s
# 104:	learn: 0.2658383	test: 0.2653425	test1: 0.2830704	best: 0.2830704 (104)	total: 4.98s	remaining: 18.7s
# 105:	learn: 0.2642788	test: 0.2638174	test1: 0.2816674	best: 0.2816674 (105)	total: 5.03s	remaining: 18.7s
# 106:	learn: 0.2625235	test: 0.2620671	test1: 0.2800072	best: 0.2800072 (106)	total: 5.07s	remaining: 18.6s
# 107:	learn: 0.2607377	test: 0.2602866	test1: 0.2783176	best: 0.2783176 (107)	total: 5.11s	remaining: 18.5s
# 108:	learn: 0.2591487	test: 0.2586972	test1: 0.2767199	best: 0.2767199 (108)	total: 5.14s	remaining: 18.5s
# 109:	learn: 0.2572935	test: 0.2568475	test1: 0.2749758	best: 0.2749758 (109)	total: 5.18s	remaining: 18.4s
# 110:	learn: 0.2556378	test: 0.2551966	test1: 0.2733306	best: 0.2733306 (110)	total: 5.21s	remaining: 18.3s
# 111:	learn: 0.2539172	test: 0.2534811	test1: 0.2716932	best: 0.2716932 (111)	total: 5.25s	remaining: 18.2s
# 112:	learn: 0.2521559	test: 0.2517222	test1: 0.2700245	best: 0.2700245 (112)	total: 5.29s	remaining: 18.1s
# 113:	learn: 0.2505862	test: 0.2501571	test1: 0.2685234	best: 0.2685234 (113)	total: 5.33s	remaining: 18.1s
# 114:	learn: 0.2495080	test: 0.2490827	test1: 0.2675290	best: 0.2675290 (114)	total: 5.36s	remaining: 18s
# 115:	learn: 0.2482272	test: 0.2478060	test1: 0.2663927	best: 0.2663927 (115)	total: 5.4s	remaining: 17.9s
# 116:	learn: 0.2468722	test: 0.2464553	test1: 0.2651490	best: 0.2651490 (116)	total: 5.72s	remaining: 18.7s
# 117:	learn: 0.2454804	test: 0.2450678	test1: 0.2638300	best: 0.2638300 (117)	total: 5.77s	remaining: 18.7s
# 118:	learn: 0.2439188	test: 0.2435108	test1: 0.2623506	best: 0.2623506 (118)	total: 5.82s	remaining: 18.6s
# 119:	learn: 0.2427066	test: 0.2423021	test1: 0.2612228	best: 0.2612228 (119)	total: 5.87s	remaining: 18.6s
# 120:	learn: 0.2412529	test: 0.2408530	test1: 0.2598504	best: 0.2598504 (120)	total: 5.91s	remaining: 18.5s
# 121:	learn: 0.2399858	test: 0.2395900	test1: 0.2586862	best: 0.2586862 (121)	total: 5.95s	remaining: 18.4s
# 122:	learn: 0.2387252	test: 0.2383332	test1: 0.2574945	best: 0.2574945 (122)	total: 6s	remaining: 18.4s
# 123:	learn: 0.2379529	test: 0.2375633	test1: 0.2568287	best: 0.2568287 (123)	total: 6.02s	remaining: 18.3s
# 124:	learn: 0.2367364	test: 0.2363508	test1: 0.2556925	best: 0.2556925 (124)	total: 6.07s	remaining: 18.2s
# 125:	learn: 0.2353379	test: 0.2349566	test1: 0.2543723	best: 0.2543723 (125)	total: 6.13s	remaining: 18.2s
# 126:	learn: 0.2339859	test: 0.2336089	test1: 0.2530926	best: 0.2530926 (126)	total: 6.18s	remaining: 18.2s
# 127:	learn: 0.2327990	test: 0.2324259	test1: 0.2520175	best: 0.2520175 (127)	total: 6.23s	remaining: 18.1s
# 128:	learn: 0.2314534	test: 0.2310846	test1: 0.2507648	best: 0.2507648 (128)	total: 6.28s	remaining: 18.1s
# 129:	learn: 0.2300311	test: 0.2296635	test1: 0.2493867	best: 0.2493867 (129)	total: 6.32s	remaining: 18s
# 130:	learn: 0.2289381	test: 0.2285741	test1: 0.2484646	best: 0.2484646 (130)	total: 6.36s	remaining: 17.9s
# 131:	learn: 0.2276146	test: 0.2272547	test1: 0.2471801	best: 0.2471801 (131)	total: 6.41s	remaining: 17.9s
# 132:	learn: 0.2264541	test: 0.2260437	test1: 0.2460768	best: 0.2460768 (132)	total: 6.45s	remaining: 17.8s
# 133:	learn: 0.2254019	test: 0.2249957	test1: 0.2451110	best: 0.2451110 (133)	total: 6.49s	remaining: 17.7s
# 134:	learn: 0.2243208	test: 0.2239187	test1: 0.2441474	best: 0.2441474 (134)	total: 6.53s	remaining: 17.7s
# 135:	learn: 0.2232343	test: 0.2228312	test1: 0.2431800	best: 0.2431800 (135)	total: 6.58s	remaining: 17.6s
# 136:	learn: 0.2220099	test: 0.2216094	test1: 0.2420501	best: 0.2420501 (136)	total: 6.64s	remaining: 17.6s
# 137:	learn: 0.2211078	test: 0.2207122	test1: 0.2412652	best: 0.2412652 (137)	total: 6.71s	remaining: 17.6s
# 138:	learn: 0.2199663	test: 0.2195750	test1: 0.2402110	best: 0.2402110 (138)	total: 6.77s	remaining: 17.6s
# 139:	learn: 0.2188499	test: 0.2184630	test1: 0.2391748	best: 0.2391748 (139)	total: 6.81s	remaining: 17.5s
# 140:	learn: 0.2181731	test: 0.2177886	test1: 0.2385999	best: 0.2385999 (140)	total: 6.84s	remaining: 17.4s
# 141:	learn: 0.2172084	test: 0.2168279	test1: 0.2377210	best: 0.2377210 (141)	total: 6.88s	remaining: 17.4s
# 142:	learn: 0.2161703	test: 0.2157939	test1: 0.2367598	best: 0.2367598 (142)	total: 6.93s	remaining: 17.3s
# 143:	learn: 0.2152410	test: 0.2148685	test1: 0.2359234	best: 0.2359234 (143)	total: 6.99s	remaining: 17.3s
# 144:	learn: 0.2142178	test: 0.2138493	test1: 0.2349819	best: 0.2349819 (144)	total: 7.04s	remaining: 17.2s
# 145:	learn: 0.2133248	test: 0.2129599	test1: 0.2341691	best: 0.2341691 (145)	total: 7.09s	remaining: 17.2s
# 146:	learn: 0.2123695	test: 0.2120053	test1: 0.2333316	best: 0.2333316 (146)	total: 7.14s	remaining: 17.2s
# 147:	learn: 0.2116472	test: 0.2112864	test1: 0.2326916	best: 0.2326916 (147)	total: 7.17s	remaining: 17.1s
# 148:	learn: 0.2105827	test: 0.2102258	test1: 0.2316752	best: 0.2316752 (148)	total: 7.22s	remaining: 17s
# 149:	learn: 0.2097272	test: 0.2093711	test1: 0.2309878	best: 0.2309878 (149)	total: 7.28s	remaining: 17s
# 150:	learn: 0.2087362	test: 0.2083840	test1: 0.2300734	best: 0.2300734 (150)	total: 7.34s	remaining: 17s
# 151:	learn: 0.2077815	test: 0.2074331	test1: 0.2291899	best: 0.2291899 (151)	total: 7.39s	remaining: 16.9s
# 152:	learn: 0.2067827	test: 0.2064382	test1: 0.2282501	best: 0.2282501 (152)	total: 7.45s	remaining: 16.9s
# 153:	learn: 0.2060184	test: 0.2056772	test1: 0.2275636	best: 0.2275636 (153)	total: 7.49s	remaining: 16.8s
# 154:	learn: 0.2053202	test: 0.2049819	test1: 0.2269710	best: 0.2269710 (154)	total: 7.54s	remaining: 16.8s
# 155:	learn: 0.2044143	test: 0.2040797	test1: 0.2261453	best: 0.2261453 (155)	total: 7.59s	remaining: 16.7s
# 156:	learn: 0.2035414	test: 0.2032076	test1: 0.2253546	best: 0.2253546 (156)	total: 7.63s	remaining: 16.7s
# 157:	learn: 0.2026782	test: 0.2023479	test1: 0.2245652	best: 0.2245652 (157)	total: 7.68s	remaining: 16.6s
# 158:	learn: 0.2018117	test: 0.2014841	test1: 0.2237737	best: 0.2237737 (158)	total: 7.73s	remaining: 16.6s
# 159:	learn: 0.2009827	test: 0.2006593	test1: 0.2230264	best: 0.2230264 (159)	total: 7.77s	remaining: 16.5s
# 160:	learn: 0.2002463	test: 0.1999260	test1: 0.2223782	best: 0.2223782 (160)	total: 7.82s	remaining: 16.5s
# 161:	learn: 0.1995331	test: 0.1992158	test1: 0.2217268	best: 0.2217268 (161)	total: 7.87s	remaining: 16.4s
# 162:	learn: 0.1986532	test: 0.1983394	test1: 0.2208881	best: 0.2208881 (162)	total: 7.91s	remaining: 16.4s
# 163:	learn: 0.1978367	test: 0.1975268	test1: 0.2201486	best: 0.2201486 (163)	total: 7.96s	remaining: 16.3s
# 164:	learn: 0.1972099	test: 0.1969027	test1: 0.2196291	best: 0.2196291 (164)	total: 8s	remaining: 16.2s
# 165:	learn: 0.1964148	test: 0.1961109	test1: 0.2189616	best: 0.2189616 (165)	total: 8.05s	remaining: 16.2s
# 166:	learn: 0.1957617	test: 0.1954617	test1: 0.2183970	best: 0.2183970 (166)	total: 8.1s	remaining: 16.2s
# 167:	learn: 0.1950311	test: 0.1947341	test1: 0.2176875	best: 0.2176875 (167)	total: 8.14s	remaining: 16.1s
# 168:	learn: 0.1942307	test: 0.1939340	test1: 0.2169319	best: 0.2169319 (168)	total: 8.2s	remaining: 16.1s
# 169:	learn: 0.1937269	test: 0.1934326	test1: 0.2165194	best: 0.2165194 (169)	total: 8.24s	remaining: 16s
# 170:	learn: 0.1931799	test: 0.1928877	test1: 0.2160614	best: 0.2160614 (170)	total: 8.29s	remaining: 15.9s
# 171:	learn: 0.1924319	test: 0.1921432	test1: 0.2153877	best: 0.2153877 (171)	total: 8.34s	remaining: 15.9s
# 172:	learn: 0.1917262	test: 0.1914405	test1: 0.2147610	best: 0.2147610 (172)	total: 8.39s	remaining: 15.9s
# 173:	learn: 0.1910465	test: 0.1907636	test1: 0.2141413	best: 0.2141413 (173)	total: 8.43s	remaining: 15.8s
# 174:	learn: 0.1904340	test: 0.1901505	test1: 0.2136219	best: 0.2136219 (174)	total: 8.48s	remaining: 15.7s
# 175:	learn: 0.1898395	test: 0.1895587	test1: 0.2131181	best: 0.2131181 (175)	total: 8.53s	remaining: 15.7s
# 176:	learn: 0.1891143	test: 0.1888366	test1: 0.2124587	best: 0.2124587 (176)	total: 8.59s	remaining: 15.7s
# 177:	learn: 0.1884773	test: 0.1882024	test1: 0.2118863	best: 0.2118863 (177)	total: 8.63s	remaining: 15.6s
# 178:	learn: 0.1879024	test: 0.1876296	test1: 0.2113750	best: 0.2113750 (178)	total: 8.68s	remaining: 15.6s
# 179:	learn: 0.1872724	test: 0.1870023	test1: 0.2108447	best: 0.2108447 (179)	total: 8.72s	remaining: 15.5s
# 180:	learn: 0.1868004	test: 0.1865333	test1: 0.2104477	best: 0.2104477 (180)	total: 8.76s	remaining: 15.4s
# 181:	learn: 0.1861584	test: 0.1858708	test1: 0.2098620	best: 0.2098620 (181)	total: 8.8s	remaining: 15.4s
# 182:	learn: 0.1855764	test: 0.1852917	test1: 0.2093455	best: 0.2093455 (182)	total: 8.84s	remaining: 15.3s
# 183:	learn: 0.1850326	test: 0.1847507	test1: 0.2088915	best: 0.2088915 (183)	total: 8.89s	remaining: 15.3s
# 184:	learn: 0.1844271	test: 0.1841479	test1: 0.2083462	best: 0.2083462 (184)	total: 8.94s	remaining: 15.2s
# 185:	learn: 0.1838492	test: 0.1835713	test1: 0.2078543	best: 0.2078543 (185)	total: 8.99s	remaining: 15.2s
# 186:	learn: 0.1832822	test: 0.1830067	test1: 0.2073909	best: 0.2073909 (186)	total: 9.03s	remaining: 15.1s
# 187:	learn: 0.1827927	test: 0.1825195	test1: 0.2069790	best: 0.2069790 (187)	total: 9.07s	remaining: 15.1s
# 188:	learn: 0.1823236	test: 0.1820523	test1: 0.2065996	best: 0.2065996 (188)	total: 9.12s	remaining: 15s
# 189:	learn: 0.1818113	test: 0.1815427	test1: 0.2061605	best: 0.2061605 (189)	total: 9.16s	remaining: 14.9s
# 190:	learn: 0.1812776	test: 0.1810115	test1: 0.2056724	best: 0.2056724 (190)	total: 9.21s	remaining: 14.9s
# 191:	learn: 0.1808454	test: 0.1805893	test1: 0.2053371	best: 0.2053371 (191)	total: 9.25s	remaining: 14.8s
# 192:	learn: 0.1804001	test: 0.1801463	test1: 0.2049871	best: 0.2049871 (192)	total: 9.29s	remaining: 14.8s
# 193:	learn: 0.1799974	test: 0.1797459	test1: 0.2046521	best: 0.2046521 (193)	total: 9.33s	remaining: 14.7s
# 194:	learn: 0.1795823	test: 0.1793329	test1: 0.2043183	best: 0.2043183 (194)	total: 9.37s	remaining: 14.7s
# 195:	learn: 0.1791347	test: 0.1788875	test1: 0.2039115	best: 0.2039115 (195)	total: 9.41s	remaining: 14.6s
# 196:	learn: 0.1785859	test: 0.1783573	test1: 0.2034672	best: 0.2034672 (196)	total: 9.46s	remaining: 14.5s
# 197:	learn: 0.1781413	test: 0.1779149	test1: 0.2030943	best: 0.2030943 (197)	total: 9.5s	remaining: 14.5s
# 198:	learn: 0.1778031	test: 0.1775779	test1: 0.2028499	best: 0.2028499 (198)	total: 9.53s	remaining: 14.4s
# 199:	learn: 0.1773396	test: 0.1771165	test1: 0.2024559	best: 0.2024559 (199)	total: 9.57s	remaining: 14.4s
# 200:	learn: 0.1768946	test: 0.1766734	test1: 0.2021332	best: 0.2021332 (200)	total: 9.61s	remaining: 14.3s
# 201:	learn: 0.1764395	test: 0.1762204	test1: 0.2017536	best: 0.2017536 (201)	total: 9.65s	remaining: 14.2s
# 202:	learn: 0.1760066	test: 0.1757904	test1: 0.2014223	best: 0.2014223 (202)	total: 9.7s	remaining: 14.2s
# 203:	learn: 0.1754920	test: 0.1752780	test1: 0.2009667	best: 0.2009667 (203)	total: 9.75s	remaining: 14.2s
# 204:	learn: 0.1749851	test: 0.1747735	test1: 0.2004993	best: 0.2004993 (204)	total: 9.79s	remaining: 14.1s
# 205:	learn: 0.1745959	test: 0.1743858	test1: 0.2002256	best: 0.2002256 (205)	total: 9.84s	remaining: 14s
# 206:	learn: 0.1741832	test: 0.1739750	test1: 0.1999121	best: 0.1999121 (206)	total: 9.88s	remaining: 14s
# 207:	learn: 0.1738231	test: 0.1736154	test1: 0.1996406	best: 0.1996406 (207)	total: 9.92s	remaining: 13.9s
# 208:	learn: 0.1733299	test: 0.1731236	test1: 0.1992227	best: 0.1992227 (208)	total: 9.97s	remaining: 13.9s
# 209:	learn: 0.1729419	test: 0.1727372	test1: 0.1989149	best: 0.1989149 (209)	total: 10s	remaining: 13.9s
# 210:	learn: 0.1725540	test: 0.1723512	test1: 0.1985776	best: 0.1985776 (210)	total: 10.1s	remaining: 13.8s
# 211:	learn: 0.1722191	test: 0.1720158	test1: 0.1983352	best: 0.1983352 (211)	total: 10.1s	remaining: 13.8s
# 212:	learn: 0.1718660	test: 0.1716639	test1: 0.1980638	best: 0.1980638 (212)	total: 10.2s	remaining: 13.7s
# 213:	learn: 0.1714626	test: 0.1712626	test1: 0.1977303	best: 0.1977303 (213)	total: 10.2s	remaining: 13.7s
# 214:	learn: 0.1712857	test: 0.1710865	test1: 0.1976106	best: 0.1976106 (214)	total: 10.3s	remaining: 13.6s
# 215:	learn: 0.1709481	test: 0.1707511	test1: 0.1973136	best: 0.1973136 (215)	total: 10.3s	remaining: 13.5s
# 216:	learn: 0.1705939	test: 0.1703988	test1: 0.1969931	best: 0.1969931 (216)	total: 10.3s	remaining: 13.5s
# 217:	learn: 0.1701503	test: 0.1699574	test1: 0.1966218	best: 0.1966218 (217)	total: 10.4s	remaining: 13.4s
# 218:	learn: 0.1697279	test: 0.1695368	test1: 0.1962582	best: 0.1962582 (218)	total: 10.4s	remaining: 13.4s
# 219:	learn: 0.1693764	test: 0.1691866	test1: 0.1959602	best: 0.1959602 (219)	total: 10.5s	remaining: 13.3s
# 220:	learn: 0.1689382	test: 0.1687506	test1: 0.1958025	best: 0.1958025 (220)	total: 10.5s	remaining: 13.3s
# 221:	learn: 0.1685563	test: 0.1683688	test1: 0.1954606	best: 0.1954606 (221)	total: 10.6s	remaining: 13.3s
# 222:	learn: 0.1682562	test: 0.1680704	test1: 0.1952404	best: 0.1952404 (222)	total: 10.7s	remaining: 13.2s
# 223:	learn: 0.1679086	test: 0.1677245	test1: 0.1949682	best: 0.1949682 (223)	total: 10.7s	remaining: 13.2s
# 224:	learn: 0.1675396	test: 0.1673578	test1: 0.1946697	best: 0.1946697 (224)	total: 10.8s	remaining: 13.2s
# 225:	learn: 0.1672008	test: 0.1670207	test1: 0.1943900	best: 0.1943900 (225)	total: 10.8s	remaining: 13.1s
# 226:	learn: 0.1668519	test: 0.1666731	test1: 0.1941178	best: 0.1941178 (226)	total: 10.9s	remaining: 13.1s
# 227:	learn: 0.1665761	test: 0.1663982	test1: 0.1939137	best: 0.1939137 (227)	total: 10.9s	remaining: 13s
# 228:	learn: 0.1662646	test: 0.1660871	test1: 0.1936964	best: 0.1936964 (228)	total: 11s	remaining: 13s
# 229:	learn: 0.1659229	test: 0.1657468	test1: 0.1934200	best: 0.1934200 (229)	total: 11s	remaining: 12.9s
# 230:	learn: 0.1656558	test: 0.1654811	test1: 0.1932225	best: 0.1932225 (230)	total: 11.1s	remaining: 12.9s
# 231:	learn: 0.1654070	test: 0.1652351	test1: 0.1930000	best: 0.1930000 (231)	total: 11.1s	remaining: 12.9s
# 232:	learn: 0.1651122	test: 0.1649403	test1: 0.1927555	best: 0.1927555 (232)	total: 11.2s	remaining: 12.8s
# 233:	learn: 0.1648564	test: 0.1646859	test1: 0.1925790	best: 0.1925790 (233)	total: 11.2s	remaining: 12.8s
# 234:	learn: 0.1645495	test: 0.1643813	test1: 0.1923325	best: 0.1923325 (234)	total: 11.3s	remaining: 12.7s
# 235:	learn: 0.1642718	test: 0.1641047	test1: 0.1921256	best: 0.1921256 (235)	total: 11.3s	remaining: 12.6s
# 236:	learn: 0.1639716	test: 0.1638055	test1: 0.1919150	best: 0.1919150 (236)	total: 11.3s	remaining: 12.6s
# 237:	learn: 0.1636137	test: 0.1634477	test1: 0.1916170	best: 0.1916170 (237)	total: 11.4s	remaining: 12.5s
# 238:	learn: 0.1633136	test: 0.1631488	test1: 0.1913820	best: 0.1913820 (238)	total: 11.4s	remaining: 12.5s
# 239:	learn: 0.1629951	test: 0.1628324	test1: 0.1911279	best: 0.1911279 (239)	total: 11.5s	remaining: 12.4s
# 240:	learn: 0.1627246	test: 0.1625658	test1: 0.1909323	best: 0.1909323 (240)	total: 11.5s	remaining: 12.4s
# 241:	learn: 0.1625290	test: 0.1623714	test1: 0.1908040	best: 0.1908040 (241)	total: 11.6s	remaining: 12.4s
# 242:	learn: 0.1622774	test: 0.1621192	test1: 0.1906424	best: 0.1906424 (242)	total: 11.6s	remaining: 12.3s
# 243:	learn: 0.1619790	test: 0.1618208	test1: 0.1903936	best: 0.1903936 (243)	total: 11.7s	remaining: 12.2s
# 244:	learn: 0.1616726	test: 0.1615175	test1: 0.1901935	best: 0.1901935 (244)	total: 11.7s	remaining: 12.2s
# 245:	learn: 0.1613437	test: 0.1611880	test1: 0.1899128	best: 0.1899128 (245)	total: 11.8s	remaining: 12.1s
# 246:	learn: 0.1610486	test: 0.1608928	test1: 0.1896580	best: 0.1896580 (246)	total: 11.8s	remaining: 12.1s
# 247:	learn: 0.1607998	test: 0.1606455	test1: 0.1894636	best: 0.1894636 (247)	total: 11.8s	remaining: 12s
# 248:	learn: 0.1604992	test: 0.1603454	test1: 0.1892288	best: 0.1892288 (248)	total: 11.9s	remaining: 12s
# 249:	learn: 0.1602316	test: 0.1600831	test1: 0.1890591	best: 0.1890591 (249)	total: 11.9s	remaining: 11.9s
# 250:	learn: 0.1599194	test: 0.1597724	test1: 0.1887938	best: 0.1887938 (250)	total: 12s	remaining: 11.9s
# 251:	learn: 0.1596330	test: 0.1594890	test1: 0.1885736	best: 0.1885736 (251)	total: 12s	remaining: 11.8s
# 252:	learn: 0.1593130	test: 0.1591706	test1: 0.1882942	best: 0.1882942 (252)	total: 12s	remaining: 11.8s
# 253:	learn: 0.1590748	test: 0.1589335	test1: 0.1880945	best: 0.1880945 (253)	total: 12.1s	remaining: 11.7s
# 254:	learn: 0.1588572	test: 0.1587170	test1: 0.1879557	best: 0.1879557 (254)	total: 12.1s	remaining: 11.6s
# 255:	learn: 0.1585531	test: 0.1584145	test1: 0.1877188	best: 0.1877188 (255)	total: 12.2s	remaining: 11.6s
# 256:	learn: 0.1583913	test: 0.1582533	test1: 0.1876095	best: 0.1876095 (256)	total: 12.2s	remaining: 11.6s
# 257:	learn: 0.1581049	test: 0.1579677	test1: 0.1873988	best: 0.1873988 (257)	total: 12.3s	remaining: 11.5s
# 258:	learn: 0.1578821	test: 0.1577462	test1: 0.1872299	best: 0.1872299 (258)	total: 12.3s	remaining: 11.4s
# 259:	learn: 0.1576271	test: 0.1574920	test1: 0.1870196	best: 0.1870196 (259)	total: 12.3s	remaining: 11.4s
# 260:	learn: 0.1573859	test: 0.1572520	test1: 0.1868411	best: 0.1868411 (260)	total: 12.4s	remaining: 11.3s
# 261:	learn: 0.1571346	test: 0.1570017	test1: 0.1866853	best: 0.1866853 (261)	total: 12.4s	remaining: 11.3s
# 262:	learn: 0.1568795	test: 0.1567494	test1: 0.1865150	best: 0.1865150 (262)	total: 12.5s	remaining: 11.2s
# 263:	learn: 0.1567362	test: 0.1566066	test1: 0.1864353	best: 0.1864353 (263)	total: 12.5s	remaining: 11.2s
# 264:	learn: 0.1565581	test: 0.1564294	test1: 0.1863146	best: 0.1863146 (264)	total: 12.6s	remaining: 11.1s
# 265:	learn: 0.1563924	test: 0.1562653	test1: 0.1862281	best: 0.1862281 (265)	total: 12.6s	remaining: 11.1s
# 266:	learn: 0.1561470	test: 0.1560208	test1: 0.1860206	best: 0.1860206 (266)	total: 12.6s	remaining: 11s
# 267:	learn: 0.1559853	test: 0.1558598	test1: 0.1859088	best: 0.1859088 (267)	total: 12.7s	remaining: 11s
# 268:	learn: 0.1557759	test: 0.1556514	test1: 0.1857387	best: 0.1857387 (268)	total: 12.7s	remaining: 10.9s
# 269:	learn: 0.1555628	test: 0.1554394	test1: 0.1856214	best: 0.1856214 (269)	total: 12.8s	remaining: 10.9s
# 270:	learn: 0.1553436	test: 0.1552212	test1: 0.1854493	best: 0.1854493 (270)	total: 12.8s	remaining: 10.8s
# 271:	learn: 0.1550850	test: 0.1549640	test1: 0.1852337	best: 0.1852337 (271)	total: 12.8s	remaining: 10.8s
# 272:	learn: 0.1549167	test: 0.1547949	test1: 0.1851145	best: 0.1851145 (272)	total: 12.9s	remaining: 10.7s
# 273:	learn: 0.1547243	test: 0.1546063	test1: 0.1849771	best: 0.1849771 (273)	total: 12.9s	remaining: 10.7s
# 274:	learn: 0.1544841	test: 0.1543663	test1: 0.1847745	best: 0.1847745 (274)	total: 13s	remaining: 10.6s
# 275:	learn: 0.1542803	test: 0.1541637	test1: 0.1846436	best: 0.1846436 (275)	total: 13s	remaining: 10.6s
# 276:	learn: 0.1540868	test: 0.1539707	test1: 0.1845061	best: 0.1845061 (276)	total: 13.1s	remaining: 10.5s
# 277:	learn: 0.1538820	test: 0.1537686	test1: 0.1843460	best: 0.1843460 (277)	total: 13.1s	remaining: 10.5s
# 278:	learn: 0.1537054	test: 0.1535930	test1: 0.1842130	best: 0.1842130 (278)	total: 13.2s	remaining: 10.4s
# 279:	learn: 0.1535362	test: 0.1534244	test1: 0.1840935	best: 0.1840935 (279)	total: 13.2s	remaining: 10.4s
# 280:	learn: 0.1533714	test: 0.1532602	test1: 0.1840109	best: 0.1840109 (280)	total: 13.3s	remaining: 10.3s
# 281:	learn: 0.1531607	test: 0.1530503	test1: 0.1838627	best: 0.1838627 (281)	total: 13.3s	remaining: 10.3s
# 282:	learn: 0.1530201	test: 0.1529105	test1: 0.1838029	best: 0.1838029 (282)	total: 13.4s	remaining: 10.3s
# 283:	learn: 0.1527748	test: 0.1526664	test1: 0.1836064	best: 0.1836064 (283)	total: 13.4s	remaining: 10.2s
# 284:	learn: 0.1525787	test: 0.1524715	test1: 0.1834547	best: 0.1834547 (284)	total: 13.5s	remaining: 10.2s
# 285:	learn: 0.1524105	test: 0.1523037	test1: 0.1833300	best: 0.1833300 (285)	total: 13.5s	remaining: 10.1s
# 286:	learn: 0.1522460	test: 0.1521394	test1: 0.1832251	best: 0.1832251 (286)	total: 13.6s	remaining: 10.1s
# 287:	learn: 0.1520306	test: 0.1519255	test1: 0.1830383	best: 0.1830383 (287)	total: 13.6s	remaining: 10s
# 288:	learn: 0.1518686	test: 0.1517632	test1: 0.1829444	best: 0.1829444 (288)	total: 13.7s	remaining: 9.97s
# 289:	learn: 0.1517252	test: 0.1516215	test1: 0.1828876	best: 0.1828876 (289)	total: 13.7s	remaining: 9.93s
# 290:	learn: 0.1515815	test: 0.1514785	test1: 0.1827915	best: 0.1827915 (290)	total: 13.8s	remaining: 9.88s
# 291:	learn: 0.1513638	test: 0.1512614	test1: 0.1826285	best: 0.1826285 (291)	total: 13.8s	remaining: 9.83s
# 292:	learn: 0.1512363	test: 0.1511344	test1: 0.1825425	best: 0.1825425 (292)	total: 13.9s	remaining: 9.79s
# 293:	learn: 0.1510843	test: 0.1509827	test1: 0.1824457	best: 0.1824457 (293)	total: 13.9s	remaining: 9.73s
# 294:	learn: 0.1509456	test: 0.1508446	test1: 0.1823676	best: 0.1823676 (294)	total: 13.9s	remaining: 9.68s
# 295:	learn: 0.1507847	test: 0.1506840	test1: 0.1822482	best: 0.1822482 (295)	total: 14s	remaining: 9.63s
# 296:	learn: 0.1506285	test: 0.1505286	test1: 0.1821380	best: 0.1821380 (296)	total: 14s	remaining: 9.58s
# 297:	learn: 0.1504505	test: 0.1503512	test1: 0.1820303	best: 0.1820303 (297)	total: 14.1s	remaining: 9.53s
# 298:	learn: 0.1502769	test: 0.1501775	test1: 0.1819063	best: 0.1819063 (298)	total: 14.1s	remaining: 9.48s
# 299:	learn: 0.1500696	test: 0.1499721	test1: 0.1817320	best: 0.1817320 (299)	total: 14.1s	remaining: 9.43s
# 300:	learn: 0.1499295	test: 0.1498304	test1: 0.1816288	best: 0.1816288 (300)	total: 14.2s	remaining: 9.37s
# 301:	learn: 0.1497773	test: 0.1496793	test1: 0.1815235	best: 0.1815235 (301)	total: 14.2s	remaining: 9.32s
# 302:	learn: 0.1495975	test: 0.1495016	test1: 0.1813858	best: 0.1813858 (302)	total: 14.3s	remaining: 9.27s
# 303:	learn: 0.1493924	test: 0.1492972	test1: 0.1812193	best: 0.1812193 (303)	total: 14.3s	remaining: 9.22s
# 304:	learn: 0.1492554	test: 0.1491611	test1: 0.1811410	best: 0.1811410 (304)	total: 14.3s	remaining: 9.17s
# 305:	learn: 0.1490832	test: 0.1489899	test1: 0.1810377	best: 0.1810377 (305)	total: 14.4s	remaining: 9.12s
# 306:	learn: 0.1489169	test: 0.1488248	test1: 0.1809077	best: 0.1809077 (306)	total: 14.4s	remaining: 9.06s
# 307:	learn: 0.1487422	test: 0.1486513	test1: 0.1807807	best: 0.1807807 (307)	total: 14.5s	remaining: 9.01s
# 308:	learn: 0.1485529	test: 0.1484631	test1: 0.1806420	best: 0.1806420 (308)	total: 14.5s	remaining: 8.96s
# 309:	learn: 0.1484062	test: 0.1483174	test1: 0.1805613	best: 0.1805613 (309)	total: 14.5s	remaining: 8.91s
# 310:	learn: 0.1482668	test: 0.1481789	test1: 0.1804528	best: 0.1804528 (310)	total: 14.6s	remaining: 8.85s
# 311:	learn: 0.1480778	test: 0.1479900	test1: 0.1803377	best: 0.1803377 (311)	total: 14.6s	remaining: 8.8s
# 312:	learn: 0.1479047	test: 0.1478184	test1: 0.1801949	best: 0.1801949 (312)	total: 14.7s	remaining: 8.75s
# 313:	learn: 0.1478159	test: 0.1477300	test1: 0.1801628	best: 0.1801628 (313)	total: 14.7s	remaining: 8.7s
# 314:	learn: 0.1476798	test: 0.1475947	test1: 0.1800917	best: 0.1800917 (314)	total: 14.7s	remaining: 8.65s
# 315:	learn: 0.1475218	test: 0.1474322	test1: 0.1799998	best: 0.1799998 (315)	total: 14.8s	remaining: 8.61s
# 316:	learn: 0.1473576	test: 0.1472667	test1: 0.1798774	best: 0.1798774 (316)	total: 14.8s	remaining: 8.56s
# 317:	learn: 0.1472060	test: 0.1471168	test1: 0.1797772	best: 0.1797772 (317)	total: 14.9s	remaining: 8.51s
# 318:	learn: 0.1470577	test: 0.1469698	test1: 0.1796759	best: 0.1796759 (318)	total: 14.9s	remaining: 8.46s
# 319:	learn: 0.1468926	test: 0.1468057	test1: 0.1795509	best: 0.1795509 (319)	total: 15s	remaining: 8.41s
# 320:	learn: 0.1467624	test: 0.1466753	test1: 0.1794957	best: 0.1794957 (320)	total: 15s	remaining: 8.37s
# 321:	learn: 0.1466369	test: 0.1465519	test1: 0.1794176	best: 0.1794176 (321)	total: 15s	remaining: 8.32s
# 322:	learn: 0.1464496	test: 0.1463654	test1: 0.1793031	best: 0.1793031 (322)	total: 15.1s	remaining: 8.27s
# 323:	learn: 0.1462873	test: 0.1462031	test1: 0.1791706	best: 0.1791706 (323)	total: 15.1s	remaining: 8.22s
# 324:	learn: 0.1461890	test: 0.1461046	test1: 0.1791251	best: 0.1791251 (324)	total: 15.2s	remaining: 8.17s
# 325:	learn: 0.1460680	test: 0.1459840	test1: 0.1790556	best: 0.1790556 (325)	total: 15.2s	remaining: 8.12s
# 326:	learn: 0.1459608	test: 0.1458778	test1: 0.1789923	best: 0.1789923 (326)	total: 15.3s	remaining: 8.07s
# 327:	learn: 0.1458477	test: 0.1457644	test1: 0.1789212	best: 0.1789212 (327)	total: 15.3s	remaining: 8.02s
# 328:	learn: 0.1457132	test: 0.1456314	test1: 0.1788242	best: 0.1788242 (328)	total: 15.3s	remaining: 7.97s
# 329:	learn: 0.1455509	test: 0.1454700	test1: 0.1787580	best: 0.1787580 (329)	total: 15.4s	remaining: 7.92s
# 330:	learn: 0.1453879	test: 0.1453068	test1: 0.1786433	best: 0.1786433 (330)	total: 15.4s	remaining: 7.87s
# 331:	learn: 0.1452142	test: 0.1451341	test1: 0.1784980	best: 0.1784980 (331)	total: 15.5s	remaining: 7.83s
# 332:	learn: 0.1450821	test: 0.1450019	test1: 0.1783952	best: 0.1783952 (332)	total: 15.5s	remaining: 7.79s
# 333:	learn: 0.1449273	test: 0.1448481	test1: 0.1782696	best: 0.1782696 (333)	total: 15.6s	remaining: 7.74s
# 334:	learn: 0.1448293	test: 0.1447505	test1: 0.1781946	best: 0.1781946 (334)	total: 15.6s	remaining: 7.69s
# 335:	learn: 0.1447162	test: 0.1446377	test1: 0.1781530	best: 0.1781530 (335)	total: 15.6s	remaining: 7.64s
# 336:	learn: 0.1445986	test: 0.1445212	test1: 0.1781045	best: 0.1781045 (336)	total: 15.7s	remaining: 7.59s
# 337:	learn: 0.1444602	test: 0.1443845	test1: 0.1780073	best: 0.1780073 (337)	total: 15.7s	remaining: 7.54s
# 338:	learn: 0.1443338	test: 0.1442594	test1: 0.1779253	best: 0.1779253 (338)	total: 15.8s	remaining: 7.49s
# 339:	learn: 0.1441968	test: 0.1441235	test1: 0.1778249	best: 0.1778249 (339)	total: 15.8s	remaining: 7.44s
# 340:	learn: 0.1440513	test: 0.1439782	test1: 0.1777354	best: 0.1777354 (340)	total: 15.9s	remaining: 7.4s
# 341:	learn: 0.1439864	test: 0.1439139	test1: 0.1777041	best: 0.1777041 (341)	total: 15.9s	remaining: 7.36s
# 342:	learn: 0.1438754	test: 0.1438036	test1: 0.1776162	best: 0.1776162 (342)	total: 16s	remaining: 7.31s
# 343:	learn: 0.1437456	test: 0.1436744	test1: 0.1775293	best: 0.1775293 (343)	total: 16s	remaining: 7.26s
# 344:	learn: 0.1436400	test: 0.1435694	test1: 0.1774640	best: 0.1774640 (344)	total: 16.1s	remaining: 7.21s
# 345:	learn: 0.1435462	test: 0.1434758	test1: 0.1774145	best: 0.1774145 (345)	total: 16.1s	remaining: 7.17s
# 346:	learn: 0.1434655	test: 0.1433954	test1: 0.1773976	best: 0.1773976 (346)	total: 16.1s	remaining: 7.12s
# 347:	learn: 0.1433245	test: 0.1432552	test1: 0.1773059	best: 0.1773059 (347)	total: 16.2s	remaining: 7.07s
# 348:	learn: 0.1432285	test: 0.1431596	test1: 0.1772706	best: 0.1772706 (348)	total: 16.2s	remaining: 7.02s
# 349:	learn: 0.1431386	test: 0.1430701	test1: 0.1772383	best: 0.1772383 (349)	total: 16.3s	remaining: 6.97s
# 350:	learn: 0.1430190	test: 0.1429512	test1: 0.1771918	best: 0.1771918 (350)	total: 16.3s	remaining: 6.92s
# 351:	learn: 0.1429015	test: 0.1428353	test1: 0.1771101	best: 0.1771101 (351)	total: 16.4s	remaining: 6.88s
# 352:	learn: 0.1427966	test: 0.1427310	test1: 0.1770284	best: 0.1770284 (352)	total: 16.4s	remaining: 6.83s
# 353:	learn: 0.1426672	test: 0.1426020	test1: 0.1769670	best: 0.1769670 (353)	total: 16.4s	remaining: 6.78s
# 354:	learn: 0.1424867	test: 0.1424232	test1: 0.1768288	best: 0.1768288 (354)	total: 16.5s	remaining: 6.73s
# 355:	learn: 0.1423627	test: 0.1423010	test1: 0.1767174	best: 0.1767174 (355)	total: 16.5s	remaining: 6.68s
# 356:	learn: 0.1422296	test: 0.1421686	test1: 0.1766171	best: 0.1766171 (356)	total: 16.6s	remaining: 6.63s
# 357:	learn: 0.1421215	test: 0.1420612	test1: 0.1765487	best: 0.1765487 (357)	total: 16.6s	remaining: 6.58s
# 358:	learn: 0.1419852	test: 0.1419236	test1: 0.1764530	best: 0.1764530 (358)	total: 16.6s	remaining: 6.53s
# 359:	learn: 0.1418737	test: 0.1418141	test1: 0.1763819	best: 0.1763819 (359)	total: 16.7s	remaining: 6.49s
# 360:	learn: 0.1417390	test: 0.1416783	test1: 0.1763078	best: 0.1763078 (360)	total: 16.7s	remaining: 6.44s
# 361:	learn: 0.1416153	test: 0.1415552	test1: 0.1762213	best: 0.1762213 (361)	total: 16.8s	remaining: 6.39s
# 362:	learn: 0.1415112	test: 0.1414516	test1: 0.1761612	best: 0.1761612 (362)	total: 16.8s	remaining: 6.34s
# 363:	learn: 0.1414381	test: 0.1413791	test1: 0.1761308	best: 0.1761308 (363)	total: 16.8s	remaining: 6.29s
# 364:	learn: 0.1413596	test: 0.1413012	test1: 0.1761064	best: 0.1761064 (364)	total: 16.9s	remaining: 6.24s
# 365:	learn: 0.1412515	test: 0.1411947	test1: 0.1760241	best: 0.1760241 (365)	total: 16.9s	remaining: 6.19s
# 366:	learn: 0.1411430	test: 0.1410898	test1: 0.1759640	best: 0.1759640 (366)	total: 17s	remaining: 6.15s
# 367:	learn: 0.1410544	test: 0.1410018	test1: 0.1759271	best: 0.1759271 (367)	total: 17s	remaining: 6.1s
# 368:	learn: 0.1409331	test: 0.1408809	test1: 0.1758574	best: 0.1758574 (368)	total: 17s	remaining: 6.05s
# 369:	learn: 0.1407984	test: 0.1407468	test1: 0.1757947	best: 0.1757947 (369)	total: 17.1s	remaining: 6s
# 370:	learn: 0.1406894	test: 0.1406410	test1: 0.1757207	best: 0.1757207 (370)	total: 17.1s	remaining: 5.95s
# 371:	learn: 0.1405889	test: 0.1405348	test1: 0.1756666	best: 0.1756666 (371)	total: 17.2s	remaining: 5.9s
# 372:	learn: 0.1405093	test: 0.1404556	test1: 0.1756252	best: 0.1756252 (372)	total: 17.2s	remaining: 5.85s
# 373:	learn: 0.1403976	test: 0.1403456	test1: 0.1755669	best: 0.1755669 (373)	total: 17.2s	remaining: 5.8s
# 374:	learn: 0.1403323	test: 0.1402809	test1: 0.1755425	best: 0.1755425 (374)	total: 17.3s	remaining: 5.76s
# 375:	learn: 0.1402224	test: 0.1401711	test1: 0.1754664	best: 0.1754664 (375)	total: 17.3s	remaining: 5.71s
# 376:	learn: 0.1401264	test: 0.1400749	test1: 0.1753987	best: 0.1753987 (376)	total: 17.3s	remaining: 5.66s
# 377:	learn: 0.1400516	test: 0.1400007	test1: 0.1753784	best: 0.1753784 (377)	total: 17.4s	remaining: 5.61s
# 378:	learn: 0.1399536	test: 0.1399081	test1: 0.1753168	best: 0.1753168 (378)	total: 17.4s	remaining: 5.57s
# 379:	learn: 0.1398541	test: 0.1398091	test1: 0.1752378	best: 0.1752378 (379)	total: 17.5s	remaining: 5.52s
# 380:	learn: 0.1397998	test: 0.1397551	test1: 0.1752244	best: 0.1752244 (380)	total: 17.5s	remaining: 5.47s
# 381:	learn: 0.1396940	test: 0.1396496	test1: 0.1751631	best: 0.1751631 (381)	total: 17.6s	remaining: 5.44s
# 382:	learn: 0.1395943	test: 0.1395515	test1: 0.1750911	best: 0.1750911 (382)	total: 17.6s	remaining: 5.39s
# 383:	learn: 0.1395090	test: 0.1394665	test1: 0.1750325	best: 0.1750325 (383)	total: 17.7s	remaining: 5.34s
# 384:	learn: 0.1394235	test: 0.1393815	test1: 0.1749729	best: 0.1749729 (384)	total: 17.8s	remaining: 5.3s
# 385:	learn: 0.1393423	test: 0.1393011	test1: 0.1749167	best: 0.1749167 (385)	total: 17.8s	remaining: 5.26s
# 386:	learn: 0.1392738	test: 0.1392339	test1: 0.1749059	best: 0.1749059 (386)	total: 17.8s	remaining: 5.21s
# 387:	learn: 0.1391877	test: 0.1391484	test1: 0.1748573	best: 0.1748573 (387)	total: 17.9s	remaining: 5.16s
# 388:	learn: 0.1390839	test: 0.1390465	test1: 0.1748304	best: 0.1748304 (388)	total: 17.9s	remaining: 5.12s
# 389:	learn: 0.1390009	test: 0.1389640	test1: 0.1747859	best: 0.1747859 (389)	total: 18s	remaining: 5.07s
# 390:	learn: 0.1389011	test: 0.1388645	test1: 0.1747269	best: 0.1747269 (390)	total: 18s	remaining: 5.02s
# 391:	learn: 0.1388182	test: 0.1387778	test1: 0.1746618	best: 0.1746618 (391)	total: 18.1s	remaining: 4.98s
# 392:	learn: 0.1387150	test: 0.1386756	test1: 0.1746192	best: 0.1746192 (392)	total: 18.1s	remaining: 4.93s
# 393:	learn: 0.1386305	test: 0.1385905	test1: 0.1745600	best: 0.1745600 (393)	total: 18.1s	remaining: 4.88s
# 394:	learn: 0.1385846	test: 0.1385452	test1: 0.1745468	best: 0.1745468 (394)	total: 18.2s	remaining: 4.84s
# 395:	learn: 0.1384829	test: 0.1384442	test1: 0.1744786	best: 0.1744786 (395)	total: 18.2s	remaining: 4.79s
# 396:	learn: 0.1383950	test: 0.1383580	test1: 0.1744514	best: 0.1744514 (396)	total: 18.3s	remaining: 4.74s
# 397:	learn: 0.1383082	test: 0.1382718	test1: 0.1743913	best: 0.1743913 (397)	total: 18.3s	remaining: 4.7s
# 398:	learn: 0.1382180	test: 0.1381821	test1: 0.1743374	best: 0.1743374 (398)	total: 18.4s	remaining: 4.66s
# 399:	learn: 0.1381329	test: 0.1380996	test1: 0.1742979	best: 0.1742979 (399)	total: 18.4s	remaining: 4.61s
# 400:	learn: 0.1380905	test: 0.1380574	test1: 0.1742912	best: 0.1742912 (400)	total: 18.5s	remaining: 4.56s
# 401:	learn: 0.1380207	test: 0.1379898	test1: 0.1742701	best: 0.1742701 (401)	total: 18.5s	remaining: 4.51s
# 402:	learn: 0.1379149	test: 0.1378846	test1: 0.1741930	best: 0.1741930 (402)	total: 18.6s	remaining: 4.48s
# 403:	learn: 0.1377865	test: 0.1377565	test1: 0.1742144	best: 0.1741930 (402)	total: 18.6s	remaining: 4.43s
# 404:	learn: 0.1376925	test: 0.1376630	test1: 0.1741509	best: 0.1741509 (404)	total: 18.7s	remaining: 4.38s
# 405:	learn: 0.1376135	test: 0.1375843	test1: 0.1741023	best: 0.1741023 (405)	total: 18.7s	remaining: 4.33s
# 406:	learn: 0.1375314	test: 0.1375025	test1: 0.1740582	best: 0.1740582 (406)	total: 18.8s	remaining: 4.29s
# 407:	learn: 0.1374226	test: 0.1373930	test1: 0.1739938	best: 0.1739938 (407)	total: 18.8s	remaining: 4.24s
# 408:	learn: 0.1373180	test: 0.1372880	test1: 0.1739184	best: 0.1739184 (408)	total: 18.8s	remaining: 4.19s
# 409:	learn: 0.1372254	test: 0.1371959	test1: 0.1738685	best: 0.1738685 (409)	total: 18.9s	remaining: 4.14s
# 410:	learn: 0.1370945	test: 0.1370643	test1: 0.1739197	best: 0.1738685 (409)	total: 18.9s	remaining: 4.09s
# 411:	learn: 0.1370073	test: 0.1369774	test1: 0.1738574	best: 0.1738574 (411)	total: 19s	remaining: 4.05s
# 412:	learn: 0.1369513	test: 0.1369227	test1: 0.1738336	best: 0.1738336 (412)	total: 19s	remaining: 4s
# 413:	learn: 0.1368828	test: 0.1368555	test1: 0.1737916	best: 0.1737916 (413)	total: 19s	remaining: 3.95s
# 414:	learn: 0.1368044	test: 0.1367774	test1: 0.1737455	best: 0.1737455 (414)	total: 19.1s	remaining: 3.9s
# 415:	learn: 0.1367530	test: 0.1367261	test1: 0.1737494	best: 0.1737455 (414)	total: 19.1s	remaining: 3.86s
# 416:	learn: 0.1366872	test: 0.1366615	test1: 0.1737212	best: 0.1737212 (416)	total: 19.1s	remaining: 3.81s
# 417:	learn: 0.1366019	test: 0.1365771	test1: 0.1736638	best: 0.1736638 (417)	total: 19.2s	remaining: 3.76s
# 418:	learn: 0.1365196	test: 0.1364994	test1: 0.1736161	best: 0.1736161 (418)	total: 19.2s	remaining: 3.71s
# 419:	learn: 0.1364829	test: 0.1364640	test1: 0.1736221	best: 0.1736161 (418)	total: 19.3s	remaining: 3.67s
# 420:	learn: 0.1363991	test: 0.1363808	test1: 0.1735787	best: 0.1735787 (420)	total: 19.3s	remaining: 3.62s
# 421:	learn: 0.1363074	test: 0.1362906	test1: 0.1735423	best: 0.1735423 (421)	total: 19.3s	remaining: 3.58s
# 422:	learn: 0.1362226	test: 0.1362068	test1: 0.1734943	best: 0.1734943 (422)	total: 19.4s	remaining: 3.53s
# 423:	learn: 0.1361263	test: 0.1361115	test1: 0.1734207	best: 0.1734207 (423)	total: 19.4s	remaining: 3.48s
# 424:	learn: 0.1360609	test: 0.1360464	test1: 0.1734088	best: 0.1734088 (424)	total: 19.5s	remaining: 3.44s
# 425:	learn: 0.1359975	test: 0.1359845	test1: 0.1733682	best: 0.1733682 (425)	total: 19.5s	remaining: 3.39s
# 426:	learn: 0.1359085	test: 0.1358959	test1: 0.1732902	best: 0.1732902 (426)	total: 19.6s	remaining: 3.35s
# 427:	learn: 0.1358259	test: 0.1358141	test1: 0.1732883	best: 0.1732883 (427)	total: 19.6s	remaining: 3.3s
# 428:	learn: 0.1357596	test: 0.1357489	test1: 0.1732389	best: 0.1732389 (428)	total: 19.7s	remaining: 3.26s
# 429:	learn: 0.1356781	test: 0.1356686	test1: 0.1731696	best: 0.1731696 (429)	total: 19.7s	remaining: 3.21s
# 430:	learn: 0.1355842	test: 0.1355753	test1: 0.1731022	best: 0.1731022 (430)	total: 19.8s	remaining: 3.17s
# 431:	learn: 0.1355480	test: 0.1355396	test1: 0.1730774	best: 0.1730774 (431)	total: 19.8s	remaining: 3.12s
# 432:	learn: 0.1354589	test: 0.1354496	test1: 0.1730230	best: 0.1730230 (432)	total: 19.9s	remaining: 3.08s
# 433:	learn: 0.1353855	test: 0.1353767	test1: 0.1729857	best: 0.1729857 (433)	total: 19.9s	remaining: 3.03s
# 434:	learn: 0.1352934	test: 0.1352852	test1: 0.1729553	best: 0.1729553 (434)	total: 20s	remaining: 2.99s
# 435:	learn: 0.1352036	test: 0.1351951	test1: 0.1729096	best: 0.1729096 (435)	total: 20s	remaining: 2.94s
# 436:	learn: 0.1351328	test: 0.1351253	test1: 0.1728547	best: 0.1728547 (436)	total: 20.1s	remaining: 2.9s
# 437:	learn: 0.1350467	test: 0.1350412	test1: 0.1727945	best: 0.1727945 (437)	total: 20.1s	remaining: 2.85s
# 438:	learn: 0.1349836	test: 0.1349784	test1: 0.1727521	best: 0.1727521 (438)	total: 20.2s	remaining: 2.81s
# 439:	learn: 0.1349111	test: 0.1349070	test1: 0.1727026	best: 0.1727026 (439)	total: 20.2s	remaining: 2.76s
# 440:	learn: 0.1348285	test: 0.1348228	test1: 0.1726650	best: 0.1726650 (440)	total: 20.3s	remaining: 2.71s
# 441:	learn: 0.1347764	test: 0.1347698	test1: 0.1726291	best: 0.1726291 (441)	total: 20.3s	remaining: 2.66s
# 442:	learn: 0.1346759	test: 0.1346699	test1: 0.1725633	best: 0.1725633 (442)	total: 20.3s	remaining: 2.62s
# 443:	learn: 0.1346050	test: 0.1346009	test1: 0.1725435	best: 0.1725435 (443)	total: 20.4s	remaining: 2.57s
# 444:	learn: 0.1345367	test: 0.1345319	test1: 0.1724997	best: 0.1724997 (444)	total: 20.4s	remaining: 2.52s
# 445:	learn: 0.1344836	test: 0.1344790	test1: 0.1724880	best: 0.1724880 (445)	total: 20.5s	remaining: 2.48s
# 446:	learn: 0.1344370	test: 0.1344326	test1: 0.1724666	best: 0.1724666 (446)	total: 20.5s	remaining: 2.43s
# 447:	learn: 0.1343177	test: 0.1343142	test1: 0.1723970	best: 0.1723970 (447)	total: 20.5s	remaining: 2.38s
# 448:	learn: 0.1342638	test: 0.1342603	test1: 0.1723765	best: 0.1723765 (448)	total: 20.6s	remaining: 2.34s
# 449:	learn: 0.1342036	test: 0.1342009	test1: 0.1723234	best: 0.1723234 (449)	total: 20.6s	remaining: 2.29s
# 450:	learn: 0.1341884	test: 0.1341858	test1: 0.1723190	best: 0.1723190 (450)	total: 20.6s	remaining: 2.24s
# 451:	learn: 0.1341204	test: 0.1341146	test1: 0.1723087	best: 0.1723087 (451)	total: 20.7s	remaining: 2.2s
# 452:	learn: 0.1340446	test: 0.1340391	test1: 0.1722410	best: 0.1722410 (452)	total: 20.7s	remaining: 2.15s
# 453:	learn: 0.1339802	test: 0.1339752	test1: 0.1721825	best: 0.1721825 (453)	total: 20.8s	remaining: 2.1s
# 454:	learn: 0.1339058	test: 0.1339011	test1: 0.1721250	best: 0.1721250 (454)	total: 20.8s	remaining: 2.06s
# 455:	learn: 0.1338555	test: 0.1338489	test1: 0.1721027	best: 0.1721027 (455)	total: 20.8s	remaining: 2.01s
# 456:	learn: 0.1338232	test: 0.1338169	test1: 0.1720883	best: 0.1720883 (456)	total: 20.9s	remaining: 1.96s
# 457:	learn: 0.1337460	test: 0.1337395	test1: 0.1720764	best: 0.1720764 (457)	total: 20.9s	remaining: 1.92s
# 458:	learn: 0.1336680	test: 0.1336629	test1: 0.1720225	best: 0.1720225 (458)	total: 20.9s	remaining: 1.87s
# 459:	learn: 0.1336214	test: 0.1336183	test1: 0.1719900	best: 0.1719900 (459)	total: 21s	remaining: 1.82s
# 460:	learn: 0.1335506	test: 0.1335477	test1: 0.1719440	best: 0.1719440 (460)	total: 21s	remaining: 1.78s
# 461:	learn: 0.1334961	test: 0.1334949	test1: 0.1719091	best: 0.1719091 (461)	total: 21.1s	remaining: 1.73s
# 462:	learn: 0.1334314	test: 0.1334328	test1: 0.1718673	best: 0.1718673 (462)	total: 21.1s	remaining: 1.69s
# 463:	learn: 0.1333668	test: 0.1333683	test1: 0.1718364	best: 0.1718364 (463)	total: 21.1s	remaining: 1.64s
# 464:	learn: 0.1332971	test: 0.1332987	test1: 0.1717975	best: 0.1717975 (464)	total: 21.2s	remaining: 1.59s
# 465:	learn: 0.1332677	test: 0.1332699	test1: 0.1717902	best: 0.1717902 (465)	total: 21.2s	remaining: 1.55s
# 466:	learn: 0.1332011	test: 0.1332035	test1: 0.1717831	best: 0.1717831 (466)	total: 21.2s	remaining: 1.5s
# 467:	learn: 0.1331340	test: 0.1331368	test1: 0.1717560	best: 0.1717560 (467)	total: 21.3s	remaining: 1.45s
# 468:	learn: 0.1330741	test: 0.1330772	test1: 0.1717431	best: 0.1717431 (468)	total: 21.4s	remaining: 1.41s
# 469:	learn: 0.1330254	test: 0.1330279	test1: 0.1717286	best: 0.1717286 (469)	total: 21.4s	remaining: 1.36s
# 470:	learn: 0.1329647	test: 0.1329683	test1: 0.1716880	best: 0.1716880 (470)	total: 21.4s	remaining: 1.32s
# 471:	learn: 0.1329325	test: 0.1329365	test1: 0.1716918	best: 0.1716880 (470)	total: 21.5s	remaining: 1.27s
# 472:	learn: 0.1328756	test: 0.1328831	test1: 0.1716608	best: 0.1716608 (472)	total: 21.5s	remaining: 1.23s
# 473:	learn: 0.1328105	test: 0.1328179	test1: 0.1716148	best: 0.1716148 (473)	total: 21.6s	remaining: 1.18s
# 474:	learn: 0.1327440	test: 0.1327530	test1: 0.1715701	best: 0.1715701 (474)	total: 21.6s	remaining: 1.14s
# 475:	learn: 0.1326791	test: 0.1326876	test1: 0.1715244	best: 0.1715244 (475)	total: 21.6s	remaining: 1.09s
# 476:	learn: 0.1326543	test: 0.1326630	test1: 0.1715164	best: 0.1715164 (476)	total: 21.7s	remaining: 1.04s
# 477:	learn: 0.1326191	test: 0.1326280	test1: 0.1715106	best: 0.1715106 (477)	total: 21.7s	remaining: 1000ms
# 478:	learn: 0.1325641	test: 0.1325745	test1: 0.1714984	best: 0.1714984 (478)	total: 21.8s	remaining: 954ms
# 479:	learn: 0.1324721	test: 0.1324829	test1: 0.1714361	best: 0.1714361 (479)	total: 21.8s	remaining: 909ms
# 480:	learn: 0.1324334	test: 0.1324453	test1: 0.1714344	best: 0.1714344 (480)	total: 21.9s	remaining: 863ms
# 481:	learn: 0.1323677	test: 0.1323768	test1: 0.1713821	best: 0.1713821 (481)	total: 21.9s	remaining: 818ms
# 482:	learn: 0.1322977	test: 0.1323074	test1: 0.1713422	best: 0.1713422 (482)	total: 21.9s	remaining: 772ms
# 483:	learn: 0.1322500	test: 0.1322598	test1: 0.1713338	best: 0.1713338 (483)	total: 22s	remaining: 727ms
# 484:	learn: 0.1321916	test: 0.1322029	test1: 0.1712921	best: 0.1712921 (484)	total: 22s	remaining: 681ms
# 485:	learn: 0.1321364	test: 0.1321487	test1: 0.1712582	best: 0.1712582 (485)	total: 22.1s	remaining: 636ms
# 486:	learn: 0.1320782	test: 0.1320910	test1: 0.1712177	best: 0.1712177 (486)	total: 22.1s	remaining: 590ms
# 487:	learn: 0.1320241	test: 0.1320381	test1: 0.1712076	best: 0.1712076 (487)	total: 22.2s	remaining: 545ms
# 488:	learn: 0.1319466	test: 0.1319615	test1: 0.1711566	best: 0.1711566 (488)	total: 22.2s	remaining: 500ms
# 489:	learn: 0.1318896	test: 0.1319045	test1: 0.1711329	best: 0.1711329 (489)	total: 22.3s	remaining: 454ms
# 490:	learn: 0.1318244	test: 0.1318406	test1: 0.1710911	best: 0.1710911 (490)	total: 22.3s	remaining: 409ms
# 491:	learn: 0.1318004	test: 0.1318169	test1: 0.1710861	best: 0.1710861 (491)	total: 22.3s	remaining: 363ms
# 492:	learn: 0.1317940	test: 0.1318107	test1: 0.1710965	best: 0.1710861 (491)	total: 22.4s	remaining: 317ms
# 493:	learn: 0.1317264	test: 0.1317440	test1: 0.1710603	best: 0.1710603 (493)	total: 22.4s	remaining: 272ms
# 494:	learn: 0.1316744	test: 0.1316930	test1: 0.1710209	best: 0.1710209 (494)	total: 22.5s	remaining: 227ms
# 495:	learn: 0.1316361	test: 0.1316547	test1: 0.1710144	best: 0.1710144 (495)	total: 22.5s	remaining: 182ms
# 496:	learn: 0.1315901	test: 0.1316091	test1: 0.1709858	best: 0.1709858 (496)	total: 22.6s	remaining: 136ms
# 497:	learn: 0.1315624	test: 0.1315826	test1: 0.1709769	best: 0.1709769 (497)	total: 22.6s	remaining: 90.8ms
# 498:	learn: 0.1315198	test: 0.1315402	test1: 0.1709643	best: 0.1709643 (498)	total: 22.6s	remaining: 45.4ms
# 499:	learn: 0.1314526	test: 0.1314737	test1: 0.1709314	best: 0.1709314 (499)	total: 22.7s	remaining: 0us
#
# bestTest = 0.1709314159
# bestIteration = 499

# %%
# Obtener la importancia de las características
feature_importances = model_cat.get_feature_importance()

# Mostrar la importancia de las características en un DataFrame
feature_names = X_train1.columns
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Ordenar por importancia
importance_df = importance_df.sort_values(by='Importance', ascending=False)
importance_df
# Out:
#                                Feature  Importance
# 15            days_since_last_purchase   69.421718
# 4                      active_customer    8.348563
# 5                              segment    4.296650
# 7         em_acount_consecutive_months    3.837836
# 13                        num_accounts    3.362937
# 9   payroll_account_consecutive_months    2.347366
# 11                         has_account    2.267149
# 3                        entry_channel    1.658443
# 6                     entry_date_month    1.594561
# 14                    meses_antigüedad    1.032488
# 1                                  age    0.650741
# 2                               salary    0.335656
# 8           payroll_consecutive_months    0.225452
# 10      emc_account_consecutive_months    0.199400
# 12                    has_pension_plan    0.196621
# 16                      region_encoded    0.192174
# 0                               gender    0.032245

# %%
# obtenemos las probabilidades y las predicciones de compra a partir del mejor modelo tras el grid search cross validation

y_test_pred_cat = pd.DataFrame(model_cat.predict(X_test1), index = y_test1.index, columns = ['Compra_predict'])
y_pred_proba_cat = model_cat.predict_proba(X_test1)[:, 1]

# %%
curva_roc_auc(y_test1,y_pred_proba_cat,'CatBoost')

# %%
resumen_cat = dataframe_resumen(y_test1,y_test_pred_cat,y_pred_proba_cat,producto)
resumen_cat
# Out:
#          Compra_debit_card  Compra_predict  Success  \
# cid
# 1451798                  1               1        1
# 1104047                  1               1        1
# 1443548                  1               1        1
# 1443226                  1               1        1
# 866793                   1               1        1
# ...                    ...             ...      ...
# 1540186                  1               1        1
# 1540192                  1               1        1
# 1540238                  1               1        1
# 1553394                  0               0        1
# 1546388                  1               1        1
#
#          Probabilidad_compra_debit_card
# cid
# 1451798                        0.974806
# 1104047                        0.974174
# 1443548                        0.976350
# 1443226                        0.971056
# 866793                         0.954388
# ...                                 ...
# 1540186                        0.962829
# 1540192                        0.960387
# 1540238                        0.963362
# 1553394                        0.103254
# 1546388                        0.962535
#
# [4443 rows x 4 columns]

# %%
resumen_metricas(model_cat,y_test1,y_test_pred_cat,X_train1,y_train1,X_validation1,y_validation1,X_test1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94      2394
#            1       0.91      0.96      0.93      2049
#
#     accuracy                           0.94      4443
#    macro avg       0.94      0.94      0.94      4443
# weighted avg       0.94      0.94      0.94      4443
#
# Accuracy: 0.9377
#
# El score en train es de: 0.958445137428385
# El score en validation es de: 0.9452612531101561
# El score en test es de: 0.9376547377897817

# %% [markdown]
# <a id='logistic'></a>
# ## Logistic Regresión
# [Volver al índice](#index)
#
# En este apartado utilizamos el modelo de Regresión Logística, que se caracteriza por ser un modelo lineal que estima la probabilidad de que un evento ocurra (en este caso, si un cliente comprará o no un producto). Este modelo es sencillo pero poderoso en problemas de clasificación binaria. La evaluación del modelo se lleva a cabo observando métricas como el accuracy, la curva ROC-AUC y la función de pérdidas, permitiendo analizar la capacidad del modelo para predecir correctamente y manejar desequilibrios en los datos.

# %%
log_reg = LogisticRegression(max_iter=1000,random_state=44)
log_reg.fit(X_train, y_train)

# Predicciones
y_pred_train = log_reg.predict(X_train)
y_pred_val = log_reg.predict(X_validation)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Curva ROC para entrenamiento
fpr_train, tpr_train, _ = metrics.roc_curve(y_train, log_reg.predict_proba(X_train)[:, 1])
roc_auc_train = metrics.auc(fpr_train, tpr_train)

# Curva ROC para validación
fpr_val, tpr_val, _ = metrics.roc_curve(y_validation, log_reg.predict_proba(X_validation)[:, 1])
roc_auc_val = metrics.auc(fpr_val, tpr_val)

plt.figure(figsize=(7, 4))
plt.plot(fpr_train, tpr_train, color='blue', label=f'ROC curve (Train) (area = {roc_auc_train:.2f})')
plt.plot(fpr_val, tpr_val, color='green', label=f'ROC curve (Validation) (area = {roc_auc_val:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %%
# Curva de precisión-recall para entrenamiento
precision_train, recall_train, _ = metrics.precision_recall_curve(y_train, log_reg.predict_proba(X_train)[:, 1])

# Curva de precisión-recall para validación
precision_val, recall_val, _ = metrics.precision_recall_curve(y_validation, log_reg.predict_proba(X_validation)[:, 1])

plt.figure(figsize=(10, 6))
plt.plot(recall_train, precision_train, color='blue', label='Precision-Recall (Train)')
plt.plot(recall_val, precision_val, color='green', label='Precision-Recall (Validation)')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="best")
plt.show()

# %%
# Obtener los coeficientes del modelo
coefficients = log_reg.coef_[0]

# Mostrar los coeficientes en un DataFrame
feature_names = X_train.columns
coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

# Ordenar por la magnitud de los coeficientes
coefficients_df = coefficients_df.reindex(coefficients_df.Coefficient.abs().sort_values(ascending=False).index)
coefficients_df
# Out:
#                                Feature  Coefficient
# 12            days_since_last_purchase    -2.945089
# 22               entry_channel_Unknown    -2.019412
# 2                      active_customer     1.789592
# 8                          has_account     1.725682
# 17                   entry_channel_KHQ    -1.317589
# 27                         segment_Top     1.225649
# 19                   entry_channel_KFC     0.650961
# 20                   entry_channel_KAT     0.550552
# 21                   entry_channel_KHK     0.478490
# 28               segment_Universitario    -0.447328
# 6   payroll_account_consecutive_months     0.397556
# 9                     has_pension_plan     0.350653
# 23                   entry_channel_RED     0.313540
# 10                        num_accounts    -0.292616
# 24                   entry_channel_KFA    -0.272544
# 16                   entry_channel_KHM    -0.212436
# 26                segment_Particulares    -0.177431
# 18                   entry_channel_KHN    -0.157181
# 0                                  age     0.137359
# 25                entry_channel_Others     0.124562
# 5           payroll_consecutive_months    -0.119311
# 14                            gender_H    -0.109833
# 15                   entry_channel_KHE     0.106659
# 3                     entry_date_month     0.050076
# 13                      region_encoded     0.046877
# 4         em_acount_consecutive_months    -0.046794
# 1                               salary    -0.040009
# 11                    meses_antigüedad    -0.036495
# 7       emc_account_consecutive_months     0.022989

# %%
# obtenemos las probabilidades y las predicciones de compra a partir del mejor modelo tras el grid search cross validation

y_test_pred_logistic = pd.DataFrame(log_reg.predict(X_test), index = y_test.index, columns = ['Compra_predict'])
y_pred_proba_logisic = log_reg.predict_proba(X_test)[:,1]

# %%
resumen_logistic = dataframe_resumen(y_test,y_test_pred_logistic,y_pred_proba_logisic,producto)
resumen_logistic
# Out:
#          Compra_debit_card  Compra_predict  Success  \
# cid
# 1451798                  1               1        1
# 1104047                  1               1        1
# 1443548                  1               1        1
# 1443226                  1               1        1
# 866793                   1               1        1
# ...                    ...             ...      ...
# 1540186                  1               1        1
# 1540192                  1               1        1
# 1540238                  1               1        1
# 1553394                  0               0        1
# 1546388                  1               1        1
#
#          Probabilidad_compra_debit_card
# cid
# 1451798                        0.993800
# 1104047                        0.994724
# 1443548                        0.981177
# 1443226                        0.988154
# 866793                         0.998835
# ...                                 ...
# 1540186                        0.988336
# 1540192                        0.980222
# 1540238                        0.988425
# 1553394                        0.416599
# 1546388                        0.980286
#
# [4443 rows x 4 columns]

# %%
resumen_metricas(log_reg,y_test,y_test_pred_logistic,X_train,y_train,X_validation,y_validation,X_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      2394
#            1       0.86      0.96      0.91      2049
#
#     accuracy                           0.91      4443
#    macro avg       0.91      0.91      0.91      4443
# weighted avg       0.92      0.91      0.91      4443
#
# Accuracy: 0.9088
#
# El score en train es de: 0.9366886648778011
# El score en validation es de: 0.923094322551459
# El score en test es de: 0.9088453747467927

# %% [markdown]
# # EVALUACIÓN FINAL y RANKING

# %% [markdown]
# ## Modelo final y ranking

# %%
clientes_junio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399734 entries, 657826 to 1550586
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 399734 non-null  float64
#  1   salary                              399734 non-null  float64
#  2   em_acount_consecutive_months        399734 non-null  float64
#  3   payroll_consecutive_months          399734 non-null  float64
#  4   payroll_account_consecutive_months  399734 non-null  float64
#  5   emc_account_consecutive_months      399734 non-null  float64
#  6   has_account                         399734 non-null  int64
#  7   has_pension_plan                    399734 non-null  int32
#  8   num_accounts                        399734 non-null  float64
#  9   active_customer                     399734 non-null  float64
#  10  meses_antigüedad                    399734 non-null  float64
#  11  days_since_last_purchase            399734 non-null  float64
#  12  entry_date_month                    399734 non-null  float64
#  13  region_encoded                      399734 non-null  float64
#  14  gender_H                            399734 non-null  int32
#  15  entry_channel_KAT                   399734 non-null  int32
#  16  entry_channel_KFA                   399734 non-null  int32
#  17  entry_channel_KFC                   399734 non-null  int32
#  18  entry_channel_KHE                   399734 non-null  int32
#  19  entry_channel_KHK                   399734 non-null  int32
#  20  entry_channel_KHM                   399734 non-null  int32
#  21  entry_channel_KHN                   399734 non-null  int32
#  22  entry_channel_KHQ                   399734 non-null  int32
#  23  entry_channel_Others                399734 non-null  int32
#  24  entry_channel_RED                   399734 non-null  int32
#  25  entry_channel_Unknown               399734 non-null  int32
#  26  segment_Particulares                399734 non-null  int32
#  27  segment_Top                         399734 non-null  int32
#  28  segment_Universitario               399734 non-null  int32
# dtypes: float64(12), int32(16), int64(1)
# memory usage: 67.1 MB

# %%
# respetamos el listado original de columnas
expected_columns = ['age', 'salary', 'active_customer', 'entry_date_month', 'em_acount_consecutive_months', 
                    'payroll_consecutive_months', 'payroll_account_consecutive_months', 'emc_account_consecutive_months', 
                    'has_account', 'has_pension_plan', 'num_accounts', 'meses_antigüedad', 'days_since_last_purchase', 
                    'region_encoded', 'gender_H', 'entry_channel_KHE', 'entry_channel_KHM', 'entry_channel_KHQ', 
                    'entry_channel_KHN', 'entry_channel_KFC', 'entry_channel_KAT', 'entry_channel_KHK', 'entry_channel_Unknown', 
                    'entry_channel_RED', 'entry_channel_KFA', 'entry_channel_Others', 'segment_Particulares', 'segment_Top', 'segment_Universitario']

# Reordenar el dataframe según el orden esperado
clientes_junio = clientes_junio[expected_columns]

# respetamos el listado original de columnas
expected_columns2 = ['gender', 'age', 'salary', 'entry_channel', 'active_customer',
        'segment', 'entry_date_month','em_acount_consecutive_months', 'payroll_consecutive_months',
        'payroll_account_consecutive_months', 'emc_account_consecutive_months',
        'has_account', 'has_pension_plan', 'num_accounts', 'meses_antigüedad',
        'days_since_last_purchase', 'region_encoded']

# Reordenar el dataframe según el orden esperado
junio_procesado = junio_procesado[expected_columns2]
junio_procesado[categoricas] = junio_procesado[categoricas].astype('category')

# %%
def prediccion_junio_modelo(modelo,nombre_modelo,tasa_compra):

    # creamos el dataframe con las predicciones de compra y las probabilidades de compra
    prediccion = pd.DataFrame(modelo.predict(clientes_junio), index = clientes_junio.index, columns = ['Compra_debit_card_'+nombre_modelo])
    probabilidad_compra = pd.DataFrame(modelo.predict_proba(clientes_junio)[:,1], index = clientes_junio.index, columns = ['Probabilidad_compra_'+nombre_modelo+'_'+producto])
    prediccion_junio = prediccion.join(probabilidad_compra, how = 'inner')

    # ajustar las probabilidades usando un factor de escala.La fórmula para ajustar la probabilidad es:

    numerador = prediccion_junio['Probabilidad_compra_'+nombre_modelo+'_'+producto]*tasa_compra
    denominador = prediccion_junio['Probabilidad_compra_'+nombre_modelo+'_'+producto]*tasa_compra + ((1 - prediccion_junio['Probabilidad_compra_'+nombre_modelo+'_'+producto]) * (1 - tasa_compra))

    prediccion_junio['Probabilidad_ajustada_'+nombre_modelo] = numerador/denominador

    return prediccion_junio

# %%
# con el CatBoost hay que ajustar el dataframe de junio de otra manera

def prediccion_junio_modelo_cat(tasa_compra):

       # creamos el dataframe con las predicciones de compra y las probabilidades de compra

       prediccion = pd.DataFrame(model_cat.predict(junio_procesado), index = junio_procesado.index, columns = ['Compra_debit_card_'+'Cat'])
       probabilidad_compra = pd.DataFrame(model_cat.predict_proba(junio_procesado)[:,1], index = junio_procesado.index, columns = ['Probabilidad_compra_'+'Cat_'+producto])
       prediccion_CatBoost = prediccion.join(probabilidad_compra, how = 'inner')

       # ajustar las probabilidades usando un factor de escala.La fórmula para ajustar la probabilidad es:

       numerador = prediccion_CatBoost['Probabilidad_compra_'+'Cat_'+producto]*tasa_compra
       denominador = prediccion_CatBoost['Probabilidad_compra_'+'Cat_'+producto]*tasa_compra + ((1 - prediccion_CatBoost['Probabilidad_compra_'+'Cat_'+producto]) * (1 - tasa_compra))

       prediccion_CatBoost['Probabilidad_ajustada_'+'Cat'] = numerador/denominador

       return prediccion_CatBoost

# %%
prediccion_LGB = prediccion_junio_modelo(model_LGB,'LGB',0.0051)
prediccion_XGBoost = prediccion_junio_modelo(model_XGBoost,'XGB',0.0051)
prediccion_LogReg = prediccion_junio_modelo(log_reg,'LogReg',0.0051)
prediccion_CatBoost = prediccion_junio_modelo_cat(0.051)

# %%
def analisis_predicciones(dataset,nombre_modelo):
    print(f'Número de compradores estimados por el modelo en junio: {dataset['Compra_debit_card_'+nombre_modelo].sum()}')
    print(f'Número de compradores estimados por el modelo ajustado: {dataset[dataset['Probabilidad_ajustada_'+nombre_modelo]>0.5].shape[0]}','\n')

    print(f'Probabilidad más alta calculada por el modelo: {dataset['Probabilidad_compra_'+nombre_modelo+'_debit_card'].max()}')
    print(f'Probabilidad más alta calculada por el modelo tras ajuste: {dataset['Probabilidad_ajustada_'+nombre_modelo].max()}','\n')

    print(f'Probabilidad más baja calculada por el modelo: {dataset['Probabilidad_compra_'+nombre_modelo+'_debit_card'].min()}')
    print(f'Probabilidad más baja calculada por el modelo tras ajuste: {dataset['Probabilidad_ajustada_'+nombre_modelo].min()}')

# %%
analisis_predicciones(prediccion_LGB,'LGB')
# Out:
# Número de compradores estimados por el modelo en junio: 106914
# Número de compradores estimados por el modelo ajustado: 0
#
# Probabilidad más alta calculada por el modelo: 0.9659263888742833
# Probabilidad más alta calculada por el modelo tras ajuste: 0.12687933172153804
#
# Probabilidad más baja calculada por el modelo: 0.028695104753856525
# Probabilidad más baja calculada por el modelo tras ajuste: 0.00015141789950466066

# %%
analisis_predicciones(prediccion_XGBoost,'XGB')
# Out:
# Número de compradores estimados por el modelo en junio: 167971
# Número de compradores estimados por el modelo ajustado: 0
#
# Probabilidad más alta calculada por el modelo: 0.9596331119537354
# Probabilidad más alta calculada por el modelo tras ajuste: 0.10862530022859573
#
# Probabilidad más baja calculada por el modelo: 0.03613932058215141
# Probabilidad más baja calculada por el modelo tras ajuste: 0.00019216444343328476

# %%
analisis_predicciones(prediccion_LogReg,'LogReg')
# Out:
# Número de compradores estimados por el modelo en junio: 111766
# Número de compradores estimados por el modelo ajustado: 24259
#
# Probabilidad más alta calculada por el modelo: 0.9999971082279351
# Probabilidad más alta calculada por el modelo tras ajuste: 0.9994361940668234
#
# Probabilidad más baja calculada por el modelo: 0.0005420815301955127
# Probabilidad más baja calculada por el modelo tras ajuste: 2.7802870372878736e-06

# %%
analisis_predicciones(prediccion_CatBoost,'Cat')
# Out:
# Número de compradores estimados por el modelo en junio: 90474
# Número de compradores estimados por el modelo ajustado: 39789
#
# Probabilidad más alta calculada por el modelo: 0.9843924782961933
# Probabilidad más alta calculada por el modelo tras ajuste: 0.7721846992908973
#
# Probabilidad más baja calculada por el modelo: 0.00574092239945229
# Probabilidad más baja calculada por el modelo tras ajuste: 0.0003102068140655115

# %%
prediccion_LGB = prediccion_LGB.reset_index()
prediccion_XGBoost = prediccion_XGBoost.reset_index()
prediccion_LogReg = prediccion_LogReg.reset_index()
prediccion_CatBoost = prediccion_CatBoost.reset_index()

# %% [markdown]
# Viendo que todos los modelo sobre-estiman el número de compradores de el producto en el mes de junio(no se esperan tantos compradores en el mes de junio) y que el ajuste realizado tampoco es capaz de dar un valor coherente (la mayoría de los modelos no predicen ninguna compra tras el ajuste, exceptuando el Logistic Regression), optamos por realizar un ranking basado en la media de la probabilidad obtenida por los cuatro modelos.

# %%
probabilidades_final = prediccion_LGB[['pk_cid','Probabilidad_compra_LGB_debit_card']].merge(prediccion_XGBoost[['pk_cid', 'Probabilidad_compra_XGB_debit_card']], on='pk_cid', how='inner')\
                 .merge(prediccion_LogReg[['pk_cid', 'Probabilidad_compra_LogReg_debit_card']], on='pk_cid', how='inner')\
                 .merge(prediccion_CatBoost[['pk_cid', 'Probabilidad_compra_Cat_debit_card']], on='pk_cid', how='inner')

# %%
calcular_media = ['Probabilidad_compra_LGB_debit_card','Probabilidad_compra_XGB_debit_card','Probabilidad_compra_LogReg_debit_card','Probabilidad_compra_Cat_debit_card']
probabilidades_final['Media_probs'] = probabilidades_final[calcular_media].mean(axis=1)
clientes_potenciales_rank = probabilidades_final[probabilidades_final['Media_probs']>0.9][['pk_cid','Media_probs']].sort_values(by='Media_probs',ascending=False)

# %% [markdown]
# Una vez que tenemos los clientes con mayor probabilidad de compra, hacemos un ranking seleccionando a aquellos que son potenciales compradores, ordenados por probabilidad de comprar el producto.

# %%
clientes_potenciales_rank = clientes_potenciales_rank.reset_index(drop=True)
clientes_potenciales_rank
# Out:
#         pk_cid  Media_probs
# 0      1344718     0.974518
# 1      1436151     0.974433
# 2      1341625     0.974433
# 3      1437312     0.974426
# 4      1373584     0.974402
# ...        ...          ...
# 49256  1421238     0.900006
# 49257  1546158     0.900005
# 49258  1544617     0.900005
# 49259  1546146     0.900005
# 49260  1545754     0.900005
#
# [49261 rows x 2 columns]

# %% [markdown]
# Según el presupuesto de la campaña que queremos realizar escogeremos más o menos clientes de este ranking.

# %%
clusters = pd.read_pickle('pk_cid_cluster.pkl')

# %%
clientes_potenciales_info = clientes_potenciales_rank.merge(info_clientes_2,on = 'pk_cid', how='inner')

# le unimos al dataset la columna cluster
clientes_potenciales_info = clientes_potenciales_info.merge(clusters,on='pk_cid')
clientes_potenciales_info = clientes_potenciales_info[clientes_potenciales_info['pk_partition']=='2019-05-01']
clientes_potenciales_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49261 entries, 4 to 232912
# Data columns (total 68 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   pk_cid                                 49261 non-null  int64
#  1   Media_probs                            49261 non-null  float64
#  2   pk_partition                           49261 non-null  datetime64[ns]
#  3   country_id                             49261 non-null  object
#  4   region_code                            49261 non-null  int32
#  5   gender                                 49261 non-null  object
#  6   age                                    49261 non-null  int64
#  7   deceased                               49261 non-null  object
#  8   salary                                 18345 non-null  float64
#  9   age_group                              49261 non-null  object
#  10  salary_bracket                         18345 non-null  category
#  11  em_acount_consecutive_months           49261 non-null  int64
#  12  debit_card_consecutive_months          49261 non-null  int64
#  13  pension_plan_consecutive_months        49261 non-null  int64
#  14  payroll_consecutive_months             49261 non-null  int64
#  15  payroll_account_consecutive_months     49261 non-null  int64
#  16  emc_account_consecutive_months         49261 non-null  int64
#  17  credit_card_consecutive_months         49261 non-null  int64
#  18  short_term_deposit_consecutive_months  49261 non-null  int64
#  19  long_term_deposit_consecutive_months   49261 non-null  int64
#  20  securities_consecutive_months          49261 non-null  int64
#  21  funds_consecutive_months               49261 non-null  int64
#  22  loans_consecutive_months               49261 non-null  int64
#  23  mortgage_consecutive_months            49261 non-null  int64
#  24  short_term_deposit                     49261 non-null  int64
#  25  loans                                  49261 non-null  int64
#  26  mortgage                               49261 non-null  int64
#  27  funds                                  49261 non-null  int64
#  28  securities                             49261 non-null  int64
#  29  long_term_deposit                      49261 non-null  int64
#  30  em_account_pp                          49261 non-null  int64
#  31  credit_card                            49261 non-null  int64
#  32  payroll                                49261 non-null  int32
#  33  pension_plan                           49261 non-null  int32
#  34  payroll_account                        49261 non-null  int64
#  35  emc_account                            49261 non-null  int64
#  36  debit_card                             49261 non-null  int64
#  37  em_account_p                           49261 non-null  int64
#  38  em_acount                              49261 non-null  int64
#  39  total_products                         49261 non-null  int64
#  40  total_products_no_account              49261 non-null  int64
#  41  spent_on_account                       49261 non-null  float64
#  42  spent_on_payment_card                  49261 non-null  float64
#  43  spent_on_pension_plan                  49261 non-null  float64
#  44  spent_on_investment                    49261 non-null  float64
#  45  spent_on_loan                          49261 non-null  float64
#  46  has_account                            49261 non-null  int64
#  47  has_payment_card                       49261 non-null  int64
#  48  has_pension_plan                       49261 non-null  int32
#  49  has_investment                         49261 non-null  int64
#  50  has_loan                               49261 non-null  int64
#  51  has_credit_card_debt                   49261 non-null  int64
#  52  num_accounts                           49261 non-null  int64
#  53  num_debt_products                      49261 non-null  int64
#  54  entry_date                             49261 non-null  datetime64[ns]
#  55  entry_channel                          49261 non-null  object
#  56  active_customer                        49261 non-null  float64
#  57  segment                                49261 non-null  object
#  58  meses_antigüedad                       49261 non-null  int64
#  59  total_spend                            49261 non-null  float64
#  60  ultima_compra                          49261 non-null  datetime64[ns]
#  61  days_since_last_purchase               49261 non-null  int64
#  62  months_since_last_purchase             49261 non-null  int64
#  63  product_posesion                       49261 non-null  bool
#  64  max_products                           49261 non-null  int64
#  65  entry_date_year                        49261 non-null  int32
#  66  entry_date_month                       49261 non-null  int32
#  67  cluster                                49261 non-null  int32
# dtypes: bool(1), category(1), datetime64[ns](3), float64(9), int32(7), int64(41), object(6)
# memory usage: 24.0+ MB

# %%
clientes_potenciales_info.head()
# Out:
#      pk_cid  Media_probs pk_partition country_id  region_code gender  age  \
# 4   1344718     0.974518   2019-05-01         ES           46      V   36
# 9   1436151     0.974433   2019-05-01         ES           34      V   31
# 14  1341625     0.974433   2019-05-01         ES           28      V   21
# 19  1437312     0.974426   2019-05-01         ES           28      H   45
# 24  1373584     0.974402   2019-05-01         ES           11      V   32
#
#    deceased     salary age_group salary_bracket  em_acount_consecutive_months  \
# 4         N  128633.40     35-44           high                             0
# 9         N   60665.04     25-34            low                             0
# 14        N   61459.71     18-24            low                             0
# 19        N  105076.62     45-54         medium                             0
# 24        N   78272.73     25-34         medium                             0
#
#     debit_card_consecutive_months  pension_plan_consecutive_months  \
# 4                               0                                4
# 9                               0                                9
# 14                              0                                1
# 19                              0                                3
# 24                              0                                1
#
#     payroll_consecutive_months  payroll_account_consecutive_months  \
# 4                            4                                  17
# 9                            9                                   9
# 14                           1                                  11
# 19                           3                                   5
# 24                           1                                   8
#
#     emc_account_consecutive_months  credit_card_consecutive_months  \
# 4                                0                               0
# 9                                0                               0
# 14                               0                               0
# 19                               0                               0
# 24                               0                               0
#
#     short_term_deposit_consecutive_months  \
# 4                                       0
# 9                                       0
# 14                                      0
# 19                                      0
# 24                                      0
#
#     long_term_deposit_consecutive_months  securities_consecutive_months  \
# 4                                      0                              0
# 9                                      0                              0
# 14                                     0                              0
# 19                                     0                              0
# 24                                     0                              0
#
#     funds_consecutive_months  loans_consecutive_months  \
# 4                          0                         0
# 9                          0                         0
# 14                         0                         0
# 19                         0                         0
# 24                         0                         0
#
#     mortgage_consecutive_months  short_term_deposit  loans  mortgage  funds  \
# 4                             0                   0      0         0      0
# 9                             0                   0      0         0      0
# 14                            0                   0      0         0      0
# 19                            0                   0      0         0      0
# 24                            0                   0      0         0      0
#
#     securities  long_term_deposit  em_account_pp  credit_card  payroll  \
# 4            0                  0              0            0        1
# 9            0                  0              0            0        1
# 14           0                  0              0            0        1
# 19           0                  0              0            0        1
# 24           0                  0              0            0        1
#
#     pension_plan  payroll_account  emc_account  debit_card  em_account_p  \
# 4              1                1            0           0             0
# 9              1                1            0           0             0
# 14             1                1            0           0             0
# 19             1                1            0           0             0
# 24             1                1            0           0             0
#
#     em_acount  total_products  total_products_no_account  spent_on_account  \
# 4           0               3                          1             139.9
# 9           0               3                          1             139.9
# 14          0               3                          1             139.9
# 19          0               3                          1             139.9
# 24          0               3                          1             139.9
#
#     spent_on_payment_card  spent_on_pension_plan  spent_on_investment  \
# 4                     0.0                5976.44                  0.0
# 9                     0.0                5976.44                  0.0
# 14                    0.0                5976.44                  0.0
# 19                    0.0                5976.44                  0.0
# 24                    0.0                5976.44                  0.0
#
#     spent_on_loan  has_account  has_payment_card  has_pension_plan  \
# 4             0.0            1                 0                 1
# 9             0.0            1                 0                 1
# 14            0.0            1                 0                 1
# 19            0.0            1                 0                 1
# 24            0.0            1                 0                 1
#
#     has_investment  has_loan  has_credit_card_debt  num_accounts  \
# 4                0         0                     0             2
# 9                0         0                     0             2
# 14               0         0                     0             2
# 19               0         0                     0             2
# 24               0         0                     0             2
#
#     num_debt_products entry_date entry_channel  active_customer  \
# 4                   0 2017-10-01           KHK              1.0
# 9                   0 2018-08-01           KHN              1.0
# 14                  0 2017-10-01           RED              1.0
# 19                  0 2018-08-01           KHM              1.0
# 24                  0 2017-12-01           RED              1.0
#
#                segment  meses_antigüedad  total_spend ultima_compra  \
# 4    02 - PARTICULARES                19         56.1    2018-09-01
# 9    02 - PARTICULARES                 9       7974.7    2019-04-01
# 14  03 - UNIVERSITARIO                19       8335.6    2018-09-01
# 19   02 - PARTICULARES                 9       7534.1    2019-03-01
# 24   02 - PARTICULARES                17       4790.1    2018-09-01
#
#     days_since_last_purchase  months_since_last_purchase  product_posesion  \
# 4                        273                           9              True
# 9                         61                           2              True
# 14                       273                           9              True
# 19                        92                           3              True
# 24                       273                           9              True
#
#     max_products  entry_date_year  entry_date_month  cluster
# 4              4             2017                10        0
# 9              4             2018                 8        4
# 14             4             2017                10        3
# 19             3             2018                 8        2
# 24             3             2017                12        4

# %%
clientes_potenciales_info.to_excel('top_debit.xlsx', index=False)

# %%
def analizar_top_compradores_graficas(dataframe,num_compradores):
    
    df_cluster = dataframe.iloc[:num_compradores]
    # Crear la figura con subplots (6 filas y 2 columnas)
    fig, axes = plt.subplots(7, 2, figsize=(15, 20))
    fig.suptitle(f'Análisis del top {num_compradores} compradores debit_card', fontsize=20)

    # 1. Gráfico tipo pie para gender
    df_cluster['gender'].value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'pink'], ax=axes[0, 0])
    axes[0, 0].set_title('Género')
    axes[0, 0].set_ylabel('')

    # 2. Gráfico de distribución para age
    sns.histplot(df_cluster['age'], kde=True, color='blue', ax=axes[0, 1])
    axes[0, 1].set_title('Edad')

    # 3. Gráfico countplot para total_products
    sns.countplot(x='total_products', data=df_cluster, hue='total_products', palette='Set2', ax=axes[1, 0])
    axes[1, 0].set_title('Total de productos')
    axes[1, 0].legend().remove()

    # 4. Gráfico countplot para total_products_no_account
    sns.countplot(x='total_products_no_account', data=df_cluster, hue='total_products_no_account', palette='Set2', ax=axes[1, 1])
    axes[1, 1].set_title('Total de productos (sin cuenta)')
    axes[1, 1].legend().remove()

    # 5. Gráfico tipo pie para has_payment_card
    df_cluster['has_payment_card'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'], ax=axes[2, 0])
    axes[2, 0].set_title('Tarjeta de pago')
    axes[2, 0].set_ylabel('')

    # 6. Gráfico countplot para num_accounts
    sns.countplot(x='num_accounts', data=df_cluster, hue='num_accounts', palette='Set2', ax=axes[2, 1])
    axes[2, 1].set_title('Número de cuentas')
    axes[2, 1].legend().remove()

    # 7. Gráfico countplot para entry_channel
    sns.countplot(y='entry_channel', data=df_cluster, order=df_cluster['entry_channel'].value_counts().head(10).index, palette='Set2', ax=axes[3, 0])
    axes[3, 0].set_title('Canal de entrada')
    axes[3, 0].legend().remove()

    # 8. Gráfico KDE para meses_antigüedad
    sns.kdeplot(df_cluster['meses_antigüedad'].dropna(), ax=axes[3, 1], fill=True)
    axes[3, 1].set_title('KDE de meses_antigüedad')

    # 9. Gráfico KDE para total_spend excluyendo outliers
    q75_total_spend = np.percentile(df_cluster['total_spend'].dropna(), 75)
    total_spend_filtrado = df_cluster['total_spend'].dropna()[df_cluster['total_spend'] <= q75_total_spend]
    sns.kdeplot(total_spend_filtrado, ax=axes[4, 0], fill=True)
    axes[4, 0].set_title('KDE de total_spend (excluyendo outliers)')

    # 10. Gráfico KDE para months_since_last_purchase
    sns.kdeplot(df_cluster['months_since_last_purchase'].dropna(), ax=axes[4, 1], fill=True)
    axes[4, 1].set_title('KDE de months_since_last_purchase')

    # 11. Gráfico KDE para salary excluyendo outliers (valores por encima del percentil 75)
    q75_salary = np.percentile(df_cluster['salary'].dropna(), 75)
    salary_filtrado = df_cluster['salary'].dropna()[df_cluster['salary'] <= q75_salary]
    sns.kdeplot(salary_filtrado, ax=axes[5, 0], fill=True)
    axes[5, 0].set_title('KDE de salary (excluyendo outliers)')

    # 12. Gráfico tipo pie para active_customer
    df_cluster['active_customer'].value_counts().plot.pie(autopct='%1.1f%%', colors=['yellowgreen', 'lightcoral'], ax=axes[5, 1])
    axes[5, 1].set_title('Cliente activo')
    axes[5, 1].set_ylabel('')

    # 13. Gráfico tipo pie para segment
    df_cluster['segment'].value_counts().plot.pie(autopct='%1.1f%%', colors=['gold', 'lightblue', 'lightgreen'], ax=axes[6, 0])
    axes[6, 0].set_title('Segmento')

    # 14. Gráfico countplot para clusters
    sns.countplot(y='cluster', data=df_cluster, order=df_cluster['cluster'].value_counts().index, palette='Set2', ax=axes[6, 1])
    axes[6, 1].set_title('Clusters')
    axes[6, 1].legend().remove()

    # Ajustar los espacios entre los subplots
    plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajustar el espacio para que no se solapen los títulos
    plt.show()

# %%
analizar_top_compradores_graficas(clientes_potenciales_info,3500)
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_14748\409992995.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='entry_channel', data=df_cluster, order=df_cluster['entry_channel'].value_counts().head(10).index, palette='Set2', ax=axes[3, 0])
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_14748\409992995.py:72: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='cluster', data=df_cluster, order=df_cluster['cluster'].value_counts().index, palette='Set2', ax=axes[6, 1])
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
porcentajes = pd.DataFrame(clientes_potenciales_info['cluster'].value_counts()).rename(columns={'count':'Num_clientes'}).reset_index(drop=True)
porcentajes['porcentajes'] = (porcentajes['Num_clientes']/porcentajes['Num_clientes'].sum())*100
porcentajes
# Out:
#    Num_clientes  porcentajes
# 0         14303    29.035139
# 1         10789    21.901707
# 2          9851    19.997564
# 3          8826    17.916810
# 4          2080     4.222407
# 5          1782     3.617466
# 6          1630     3.308906
